# %%
import configparser
import re
import requests
import scram
import requests
from hszinc import parse
import hszinc
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""Functions to interact with SkySpark database using Axon queries

Module includes the following functions:
request        Send Axon request to SkySpark, return resulting text
__name__       Simple console to send REST request to SkySpark

Created on Sun Nov 19 15:29:51 2017
Last updated on 2019-08-23

@author: rvitti
"""



# Define constants
CONFIG_FILE = "./spyspark.cfg"
MAX_ATTEMPTS = 3

# Define global module variables, in particular config object
config = configparser.ConfigParser()
result_list = config.read(CONFIG_FILE)
if not result_list:
    raise Exception("Missing config file spyspark.cfg")
host_addr = config['Host']['Address']


# Exception raised if empty result is received from SkySpark
class AxonException(Exception):
    pass


def about() -> str:
    uri = host_addr + "about"
    return request(uri)


def axon_request(query: str, result_type: str = "text/zinc") -> str:
    uri = host_addr + "eval"
    
    # Encode special characters
    query = query.replace("\\$","\\\\\$").replace('"', '\\\"')
    # Encode request as Zinc
    data = f"""ver:"3.0"\nexpr\n"{query}"\n""".encode('utf-8')

    return request(uri, data, result_type, request_type="text/zinc")


def his_write(data) -> str:
    uri = host_addr + "hisWrite"
    return request(uri, data)


def commit(data) -> str:
    uri = host_addr + "commit"
    return request(uri, data)


def request(request_uri: str, data: str = None,
            result_type: str = "text/zinc",
            request_type: str = "text/zinc") -> str:
    """Process REST operation, return resulting text
    
    Use SkySpark REST API with uri provided as first argument.
    Use authorization token stored in spyspark.cfg. If
    an authorization issue is detected, attempt to re-authorize. If other
    HTTP issues are detected, raise Exception. Return result as string.
    
    If the Axon query returns 'empty\n', a custom AxonException is raised.
    This can occur if there are no results or if the query is bad.
    
    Keyword arguments:
    request_uri  -- REST Uri to use with REST operation
    data         -- Data to use with POST request, or None for GET
    result_type  -- Requested MIME type in which to receive results
                    (default: "text/zinc" for Zinc format)
    request_type -- MIME type in which the request data is provided
    """
    # Attempt to send request; if an authorization issue is detected,
    # retry after updating the authorization token
    for i in range(0, MAX_ATTEMPTS):
        auth_token = scram.current_token()
        headers= {"authorization": "BEARER authToken="+auth_token,
                  "accept": result_type,
                  "content-type": request_type}
        if data is None:
            r = request.get(request_uri, headers=headers)
        else:
            r = requests.post(request_uri, data=data, headers=headers)
        if r.status_code == 200:
            if r.text != "empty\n":
                if result_type == "text/csv":
                    text = re.sub('â\x9c\x93','True',r.text)    # Checkmarks
                    text = re.sub('Â','',text)
                    return text
                else:
                    return r.text
            else:
                raise AxonException("Empty result, check query")
        if r.status_code == 400:    # Missing required header
            raise Exception("HTTP request is missing a required header")
        if r.status_code == 404:    # Invalid URI
            raise Exception("URI does not map to a valid operation URI")    
        if r.status_code == 406:    # Invalid "accept" header
            raise Exception("Unsupported MIME type requested")
        if r.status_code == 403:    # Authorization issue, try to reauthorize
            scram.update_token()
        else:
            raise Exception("HTTP error: %d" % r.status_code)



if __name__ == '__main__':
    """Simple console to send REST request to SkySpark and display results"""
    ref = "https://skyfoundry.com/doc/docSkySpark/Axon"
    sample = "read(point and siteRef->dis==\"Building 77\" and " + \
             "equipRef->dis==\"AHU-33\" and discharge and air " + \
             "and temp and sensor).hisRead(yesterday))\n" +\
             "Enter 'q' or 'quit' to exit"
    query = ""
    while query.lower() != "quit" and query.lower() != "q":
        query = input("Enter Axon query:\n>")
        response = axon_request(query)
        if query.lower() == "help":
            print("""\nReference: %s\nExample: %s""" % (ref, sample))
        elif query.lower() != "quit" and query.lower() != "q":
            try:
                #print(axon_request(query))
                print('hello')
                data = axon_request(query)
                with open('datfile.txt','w') as file:
                    file.write(data)
            except AxonException as e:
                print(e.args[0]+'\n')
# Out:
# Enter Axon query:
# > readAll(bellaCurValPolling)
# hello
# Enter Axon query:
# > q

# %%
def read_file(file_name):
    try:
        with open(file_name, 'r') as file:
            content = file.read()
        return content
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")
        return None

def parse_zinc_output(zinc_output):
    try:
        grid = hszinc.parse(zinc_output)
        return grid
    except Exception as e:
        print(f"Failed to parse Zinc output: {e}")
        return None        
def main():
    file_name = "datfile.txt"  # Update with your file name
    
    # Read the text file
    zinc_output = read_file(file_name)
    if zinc_output is None:
        return
    
    print("Zinc Output:")
    print(zinc_output)

    # Parse the Zinc output
    grid = parse_zinc_output(zinc_output)
    if grid is None:
        return
    
    print("\nParsed Grid:")
    for row in grid:
        print(row)

    export_to_csv(grid, 'parsedfile.csv')

    plot_data(grid)

import csv

def export_to_csv(grid, csv_file_name):
    try:
        with open(csv_file_name, 'w', newline='') as csvfile:
            writer = csv.writer(csvfile)
            
            # Write the header
            header = grid.column.keys()
            writer.writerow(header)
            
            # Write the rows
            for row in grid:
                writer.writerow([row.get(col, '') for col in header])
                
        print(f"Data successfully exported to {csv_file_name}")
    except Exception as e:
        print(f"An error occurred while writing to the CSV file: {e}")



def plot_data(grid):
    try:
        # Assuming the grid has columns 'time' and 'value'
        times = [row['ts'] for row in grid]
        values = [row['v0'] for row in grid]

        plt.figure(figsize=(10, 5))
        plt.plot(times, values, marker='o', linestyle='-', color='b')
        plt.xlabel('Time')
        plt.ylabel('Value')
        plt.title('Line Graph of Parsed Data')
        plt.grid(True)
        plt.show()
    except Exception as e:
        print(f"An error occurred while plotting the data: {e}")

if __name__ == "__main__":
    main()
# Out:
# Zinc Output:
# ver:"3.0"
# id,air,bacnetConnRef,bacnetCur,bacnetCurName,bacnetDesc,bacnetHis,bacnetHisName,bacnetLogBufferSize,bacnetLogCovIncrement,bacnetLogInterval,bacnetPoint,bellaCurValPolling,chilled,cmd,connRef,cur,curStatus,curVal,disMacro,disable,discharge,equipRef,his,hisCollectInterval,hisCollectWriteFreq,hisEnd,hisMode,hisSize,hisStart,hisStatus,humidity,kind,leaving,locationRef,mixed,navName,outside,point,preheat,return,sensor,siteRef,sp,spaceRef,temp,tmp,tz,unit,water,writeLevel,writeStatus,zone,mod
# @p:integration:r:267ea201-0d8e905e "71-AHU-39 Return Air Temperature",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001385","NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 PREHEAT TEMP","Return Air Temperature","TL3002771","NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 PREHEAT TEMP.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",62.811588287353516Â°F,"\$equipRef \$navName",,,@p:integration:r:267bd1f9-ed5ccb3e "71-AHU-39",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2268813,2020-06-19T09:52:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Return Air Temperature",,M,,M,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7befc-7ae06237 "B71 BELLA Lab Rm 131 (Control)",M,,"Los_Angeles","Â°F",,,,,2024-10-28T00:22:53.408Z
# @p:integration:r:267d5138-e31feaaa "71-AHU-37 Supply Air Temperature",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001341","NAE7/BACnet Trunk 2.71 AHU 37.71 AHU 37 SAT","Discharge Air Temperature","TL3002739","NAE7/BACnet Trunk 2.71 AHU 37.71 AHU 37 SAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",67.7739486694336Â°F,"\$equipRef \$navName",,M,@p:integration:r:267bd1e8-4c2565f9 "71-AHU-37",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2270469,2020-06-18T06:18:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Supply Air Temperature",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b7c4-69cdffba "B71 BELLA Lab",M,,"Los_Angeles","Â°F",,,,,2024-10-28T00:22:53.436Z
# @p:integration:r:267ea201-196a07a3 "B71 BELLA Lab Lab 146C ERC [Exp Cave] Zone Temperature (Cave)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3002374","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 EXPERIMENT CAVE ZAT","Zone Temperature","TL3002759","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 EXPERIMENT CAVE ZAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",72.31693267822266Â°F,"\$equipRef \$navName",,,@p:integration:r:2ca7314e-9dfe75ee "B71 BELLA Lab Lab 146C ERC [Exp Cave]",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2268819,2020-06-19T09:53:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Zone Temperature (Cave)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-a8c73d66 "B71 BELLA Lab Lab 146C",M,,"Los_Angeles","Â°F",,,,M,2024-10-28T00:22:53.438Z
# @p:integration:r:267ea201-276dec1f "71-AHU-39 Zone Temperature",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001388","NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 ZAT","Zone Temperature","TL3002773","NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 ZAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",70.21957397460938Â°F,"\$equipRef \$navName",,,@p:integration:r:267bd1f9-ed5ccb3e "71-AHU-39",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2268798,2020-06-19T09:52:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Zone Temperature",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7befc-7ae06237 "B71 BELLA Lab Rm 131 (Control)",M,,"Los_Angeles","Â°F",,,,M,2024-10-28T00:22:53.439Z
# @p:integration:r:2683b862-3c26638a "B71 BELLA Lab Lab 146 ERC [Zone 1 (NE)] Supply Air Temperature (Laser 1)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3002347","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 1 SAT","Cold Deck Temperature","TL3002746","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 1 SAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",68.89019775390625Â°F,"\$equipRef \$navName",,M,@p:integration:r:2ca72ffd-a09ddce9 "B71 BELLA Lab Lab 146 ERC [Zone 1 (NE)]",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2264476,2020-06-22T09:55:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Supply Air Temperature (Laser 1)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-ac90d516 "B71 BELLA Lab Lab 146",M,,"Los_Angeles","Â°F",,,,M,2024-10-28T00:22:53.445Z
# @p:integration:r:2ca74be8-6b8f8d0b "71-AHU-36 Supply Air Temperature Setpoint",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AV3001315","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SAT SP","CS Input (Float)","TL3002814","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SAT SP.Trend1",144_records,0.20000000298023224,0min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",55Â°F,"\$equipRef \$navName",,M,@p:integration:r:267bd1d7-5c2d62ae "71-AHU-36",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,"cov",70361,2022-11-02T16:16:07-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Supply Air Temperature Setpoint",,M,,,,@p:integration:r:2288ede8-e064f7db "71",M,@p:integration:r:2dc7b7c4-69cdffba "B71 BELLA Lab",M,2023-09-27,"Los_Angeles","Â°F",,,,,2024-10-28T00:22:53.456Z
# @p:integration:r:267e623c-5e7f6985 "71-AHU-39 Mixed Air Temperature",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001382","NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 MAT","Mixed Air Temperature","TL3002770","NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 MAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",61.762001037597656Â°F,"\$equipRef \$navName",,,@p:integration:r:267bd1f9-ed5ccb3e "71-AHU-39",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2270254,2020-06-18T09:51:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",M,"Mixed Air Temperature",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7befc-7ae06237 "B71 BELLA Lab Rm 131 (Control)",M,,"Los_Angeles","Â°F",,,,,2024-10-28T00:22:53.457Z
# @p:integration:r:2683b862-24c6d3f1 "B71 BELLA Lab Lab 146 ERC [Beam Focus (S)] Supply Air Temperature (Beam Focus)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3002361","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 BEAM FOCUS SAT","DISCHARGE AIR Temperature","TL3002754","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 BEAM FOCUS SAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",71.17726135253906Â°F,"\$equipRef \$navName",,M,@p:integration:r:2ca7314e-58ccd2ff "B71 BELLA Lab Lab 146 ERC [Beam Focus (S)]",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2264477,2020-06-22T09:55:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Supply Air Temperature (Beam Focus)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-ac90d516 "B71 BELLA Lab Lab 146",M,,"Los_Angeles","Â°F",,,,M,2024-10-28T00:22:53.459Z
# @p:integration:r:267ea201-da2ebace "71-AHU-36 Leaving Air Temperature (CHW Coil)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001325","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 CLG VLV DA TEMP","Discharge Air Temperature","TL3002724","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 CLG VLV DA TEMP.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",52.53693389892578Â°F,"\$equipRef \$navName",,M,@p:integration:r:267bd1d7-5c2d62ae "71-AHU-36",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2268821,2020-06-19T09:53:00-07:00 Los_Angeles,"unknown",,"Number",M,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Leaving Air Temperature (CHW Coil)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b7c4-69cdffba "B71 BELLA Lab",M,2023-09-27,"Los_Angeles","Â°F",,,,,2024-10-28T00:22:53.46Z
# @p:integration:r:267d5139-144b9aaa "71-AHU-38 Supply Air Temperature",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001375","NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 SAT","Discharge Air Temperature","TL3002769","NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 SAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",73.73503875732422Â°F,"\$equipRef \$navName",,M,@p:integration:r:267bd1f1-30e50564 "71-AHU-38",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2270468,2020-06-18T06:18:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Supply Air Temperature",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b7c4-69cdffba "B71 BELLA Lab",M,,"Los_Angeles","Â°F",,,,,2024-10-28T00:22:53.466Z
# @p:integration:r:2683b862-fe6a7368 "B71 BELLA Lab Lab 146C ERC [Exp Cave] Supply Air Temperature (Cave)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3002362","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 EXPERIMENT CAVE SAT","Temperature","TL3002755","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 EXPERIMENT CAVE SAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",68.22176361083984Â°F,"\$equipRef \$navName",,M,@p:integration:r:2ca7314e-9dfe75ee "B71 BELLA Lab Lab 146C ERC [Exp Cave]",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2264496,2020-06-22T09:56:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Supply Air Temperature (Cave)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-a8c73d66 "B71 BELLA Lab Lab 146C",M,,"Los_Angeles","Â°F",,,,M,2024-10-28T00:22:53.495Z
# @p:integration:r:267ea201-8f32486c "B71 BELLA Lab Lab 146 ERC [Zone 1 (NE)] Zone Temperature (Laser 1)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3002349","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 1 TEMP","Zone Temperature","TL3002749","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 1 TEMP.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",70.9516830444336Â°F,"\$equipRef \$navName",,,@p:integration:r:2ca72ffd-a09ddce9 "B71 BELLA Lab Lab 146 ERC [Zone 1 (NE)]",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2268818,2020-06-19T09:52:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Zone Temperature (Laser 1)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-ac90d516 "B71 BELLA Lab Lab 146",M,,"Los_Angeles","Â°F",,,,M,2024-10-28T00:22:53.499Z
# @p:integration:r:267ea201-ddf21d90 "B71 BELLA Lab Lab 146 ERC [Beam Focus (S)] Zone Temperature (Beam Focus)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3002365","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 BEAM FOCUS ZAT","Zone Temperature","TL3002758","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 BEAM FOCUS ZAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",71.02857971191406Â°F,"\$equipRef \$navName",,,@p:integration:r:2ca7314e-58ccd2ff "B71 BELLA Lab Lab 146 ERC [Beam Focus (S)]",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2268813,2020-06-19T09:53:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Zone Temperature (Beam Focus)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-ac90d516 "B71 BELLA Lab Lab 146",M,,"Los_Angeles","Â°F",,,,M,2024-10-28T00:22:53.515Z
# @p:integration:r:267ea201-ec8e91ee "B71 BELLA Lab Lab 146 ERC [Zone 2 (NW)] Zone Temperature (Laser 2)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3002350","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 2 TEMP","Zone Temperature","TL3002750","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 2 TEMP.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",70.99494934082031Â°F,"\$equipRef \$navName",,,@p:integration:r:2ca72ffd-0ba18638 "B71 BELLA Lab Lab 146 ERC [Zone 2 (NW)]",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2268812,2020-06-19T09:52:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Zone Temperature (Laser 2)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-ac90d516 "B71 BELLA Lab Lab 146",M,,"Los_Angeles","Â°F",,,,M,2024-10-28T00:22:53.516Z
# @p:integration:r:267ea201-eff8bf7b "B71 BELLA Lab Lab 146 ERC [Zone 4 (SW)] Zone Temperature (Laser 4)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3002364","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 LASER BAY ZN 4 ZAT","Zone Temperature","TL3002757","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 LASER BAY ZN 4 ZAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",70.9156494140625Â°F,"\$equipRef \$navName",,,@p:integration:r:2ca72ffd-882283f6 "B71 BELLA Lab Lab 146 ERC [Zone 4 (SW)]",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2268814,2020-06-19T09:53:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Zone Temperature (Laser 4)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-ac90d516 "B71 BELLA Lab Lab 146",M,,"Los_Angeles","Â°F",,,,M,2024-10-28T00:22:53.521Z
# @p:integration:r:24c357ca-63fe7fab "B71 CHW Plant Primary CHW Supply Temperature",,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3000214","NAE7/N2 Trunk 1.71_ARU8_CT4.CHW_ST","Chilled Water Supply Temperature","TL3000663","NAE7/N2 Trunk 1.71_ARU8_CT4.CHW_ST.Trend1",144_records,,1min,M,M,M,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",42.71875Â°F,"\$equipRef \$navName",,,@p:integration:r:296a3ba6-0404f8a3 "B71 CHW Plant Primary",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,1728858,2019-07-17T21:25:00-07:00 Los_Angeles,"unknown",,"Number",M,@p:integration:r:2288edfc-23aecc39 "B71 CHW",,"CHW Supply Temperature",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2288edfc-23aecc39 "B71 CHW",M,,"Los_Angeles","Â°F",M,,,,2024-10-28T00:22:53.526Z
# @p:integration:r:2683b862-e2bc50aa "B71 BELLA Lab Lab 146 ERC [Zone 4 (SW)] Supply Air Temperature (Laser 4)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3002359","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 LASER BAY ZN 4 SAT","Discharge Air Temperature","TL3002752","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 LASER BAY ZN 4 SAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",73.32166290283203Â°F,"\$equipRef \$navName",,M,@p:integration:r:2ca72ffd-882283f6 "B71 BELLA Lab Lab 146 ERC [Zone 4 (SW)]",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2264491,2020-06-22T09:55:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Supply Air Temperature (Laser 4)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-ac90d516 "B71 BELLA Lab Lab 146",M,,"Los_Angeles","Â°F",,,,M,2024-10-28T00:22:53.538Z
# @p:integration:r:267d5138-e6f96a0f "71-AHU-36 Supply Air Temperature",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001321","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SAT","Discharge Air Temperature","TL3002733","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",55.081573486328125Â°F,"\$equipRef \$navName",,M,@p:integration:r:267bd1d7-5c2d62ae "71-AHU-36",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2270501,2020-06-18T06:18:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Supply Air Temperature",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b7c4-69cdffba "B71 BELLA Lab",M,,"Los_Angeles","Â°F",,,,,2024-10-28T00:22:53.543Z
# @p:integration:r:2683b862-3b054f74 "B71 BELLA Lab Lab 146 ERC [Zone 2 (NW)] Supply Air Temperature (Laser 2)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3002346","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 2 SAT","Discharge Air Temperature","TL3002747","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 2 SAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",69.6110610961914Â°F,"\$equipRef \$navName",,M,@p:integration:r:2ca72ffd-0ba18638 "B71 BELLA Lab Lab 146 ERC [Zone 2 (NW)]",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2264478,2020-06-22T09:55:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Supply Air Temperature (Laser 2)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-ac90d516 "B71 BELLA Lab Lab 146",M,,"Los_Angeles","Â°F",,,,M,2024-10-28T00:22:53.554Z
# @p:integration:r:267ea201-8cb9e4d8 "71 Clean Room Zone Temperature (Clean Rm)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001347","NAE7/BACnet Trunk 2.71 AHU 37.71 CLEAN RM TEMP","Zone Temperature","TL3002742","NAE7/BACnet Trunk 2.71 AHU 37.71 CLEAN RM TEMP.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",71.15817260742188Â°F,"\$equipRef \$navName",,,@p:integration:r:2ca7309e-f6330990 "71 Clean Room",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2268798,2020-06-19T09:52:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Zone Temperature (Clean Rm)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-ac90d516 "B71 BELLA Lab Lab 146",M,,"Los_Angeles","Â°F",,,,M,2024-10-28T00:22:53.555Z
# @p:integration:r:267e8317-2318784e "71-AHU-34 Zone Temperature",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3000090","NAE7/N2 Trunk 1.71_AHU34.ZAT","Zone Temperature","TL3008907","NAE7/N2 Trunk 1.71_AHU34.ZAT.Trend2",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",69.05242919921875Â°F,"\$equipRef \$navName",,,@p:integration:r:267bcd2d-e15fd59e "71-AHU-34",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2268798,2020-06-19T09:52:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Zone Temperature",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:29cd07f7-ab30dec0 "71-AHU-34",M,,"Los_Angeles","Â°F",,,,M,2024-10-28T00:22:53.559Z
# @p:integration:r:267d5625-8d219c71 "71-AHU-36 Outside Air Relative Humidity",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001284","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 OA HUMID","Outdoor Air Humidity","TL3002735","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 OA HUMID.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",35.182254791259766%RH,"\$equipRef \$navName",,,@p:integration:r:267bd1d7-5c2d62ae "71-AHU-36",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2270472,2020-06-18T06:18:00-07:00 Los_Angeles,"unknown",M,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Outside Air Relative Humidity",M,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b7c4-69cdffba "B71 BELLA Lab",,,"Los_Angeles","%RH",,,,,2024-10-28T00:22:53.563Z
# @p:integration:r:2683be06-9d05efdb "71 Clean Room Zone Temperature",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AV3001314","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 37 CLEAN RM ZAT","CS Input (Float)","TL3002804","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 37 CLEAN RM ZAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",71.15817260742188Â°F,"\$equipRef \$navName",,,@p:integration:r:2ca7309e-f6330990 "71 Clean Room",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,1553575,2020-06-21T12:20:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Zone Temperature",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-ac90d516 "B71 BELLA Lab Lab 146",M,,"Los_Angeles","Â°F",,,,M,2024-10-28T00:22:53.565Z
# @p:integration:r:2683b862-d6db65c4 "B71 BELLA Lab Lab 146 ERC [Zone 3 (E)] Supply Air Temperature (Laser 3)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3002348","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 3 SAT","DISCHARGE AIR Temperature","TL3002748","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 3 SAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",72.06110382080078Â°F,"\$equipRef \$navName",,M,@p:integration:r:2ca72ffd-5996755a "B71 BELLA Lab Lab 146 ERC [Zone 3 (E)]",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2264488,2020-06-22T09:55:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Supply Air Temperature (Laser 3)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-ac90d516 "B71 BELLA Lab Lab 146",M,,"Los_Angeles","Â°F",,,,M,2024-10-28T00:22:53.569Z
# @p:integration:r:267ea201-ca73ecb9 "71-AHU-38 Zone Temperature",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001370","NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 ZAT","Zone Temperature","TL3002768","NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 ZAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",73.0668716430664Â°F,"\$equipRef \$navName",,,@p:integration:r:267bd1f1-30e50564 "71-AHU-38",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2268813,2020-06-19T09:53:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Zone Temperature",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b7c4-69cdffba "B71 BELLA Lab",M,,"Los_Angeles","Â°F",,,,M,2024-10-28T00:22:53.576Z
# @p:integration:r:2683b862-5868b3e6 "B71 BELLA Lab Lab 126A,B ERC (Staging/Gowning) Supply Air Temperature (STAGING GWNING)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3002360","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 STAGING GWNING SAT","SUPPLY AIR TEMP","TL3002753","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 STAGING GWNING SAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",68.07755279541016Â°F,"\$equipRef \$navName",,M,@p:integration:r:2ca7310f-99857f5f "B71 BELLA Lab Lab 126A,B ERC (Staging/Gowning)",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2264480,2020-06-22T09:55:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Supply Air Temperature (STAGING GWNING)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-665600bf "B71 BELLA Lab Lab 126A,B",M,,"Los_Angeles","Â°F",,,,M,2024-10-28T00:22:53.584Z
# @p:integration:r:2eb3e716-08088939 "71 Bella Vibration Analysis NAE7/Programming.Test.TestAV1",,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AV3024548",,,"TL3024549",,,,,M,M,,M,,M,"ok",2974.98388671875,"\$equipRef \$navName",,,@p:integration:r:29687765-4219ca0f "71 Bella Vibration Analysis",M,1min,15min,2024-10-29T11:50:00-07:00 Los_Angeles,,17,2024-10-29T11:34:00-07:00 Los_Angeles,"unknown",,"Number",,,,"NAE7/Programming.Test.TestAV1",,M,,,,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b7c4-69cdffba "B71 BELLA Lab",,,"Los_Angeles",,,17,"unknown",,2024-10-29T18:49:17.503Z
# @p:integration:r:2ca74be8-4a8b96c1 "71-AHU-36 Preheat Air Temp",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001289","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 PREHEAT TEMP","Preheat Temperature","TL3002722","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 PREHEAT TEMP.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",60.4879150390625Â°F,"\$equipRef \$navName",,,@p:integration:r:267bd1d7-5c2d62ae "71-AHU-36",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,572184,2023-09-27T11:05:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Preheat Air Temp",,M,M,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b7c4-69cdffba "B71 BELLA Lab",M,2023-09-27,"Los_Angeles","Â°F",,,,,2024-10-28T00:22:53.594Z
# @p:integration:r:267ea201-e198290b "B71 BELLA Lab Lab 126A,B ERC (Staging/Gowning) Zone Temperature (STAGING GWNING)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3002363","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 STAGING GWNING ZAT","Zone Temperature","TL3002756","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 STAGING GWNING ZAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",75.20006561279297Â°F,"\$equipRef \$navName",,,@p:integration:r:2ca7310f-99857f5f "B71 BELLA Lab Lab 126A,B ERC (Staging/Gowning)",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2268818,2020-06-19T09:53:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Zone Temperature (STAGING GWNING)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-665600bf "B71 BELLA Lab Lab 126A,B",M,,"Los_Angeles","Â°F",,,,M,2024-10-28T00:22:53.596Z
# @p:integration:r:267e619f-1b6dee0c "71-AHU-38 Outside Air Temperature Lockout",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AV3002632","NAE7/BACnet Trunk 2.71 AHU 38.ECON LOCKOUT DP SETPOINT","CS Input (Float)","TL3009621","NAE7/BACnet Trunk 2.71 AHU 38.ECON LOCKOUT DP SETPOINT.Trend1",144_records,,15min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",65.0999984741211Â°F,"\$equipRef \$navName",M,,@p:integration:r:267bd1f1-30e50564 "71-AHU-38",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,163954,2022-01-06T14:45:00-08:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Outside Air Temperature Lockout",M,M,,,,@p:integration:r:2288ede8-e064f7db "71",M,@p:integration:r:2dc7b7c4-69cdffba "B71 BELLA Lab",M,,"Los_Angeles","Â°F",,,,,2024-10-28T00:22:53.607Z
# @p:integration:r:2683be07-a8a1e51d "71 Clean Room Zone Relative Humidity",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AV3001313","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 37 CLEAN RM ZAH","CS Input (Float)","TL3002805","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 37 CLEAN RM ZAH.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",31.199630737304688%RH,"\$equipRef \$navName",,,@p:integration:r:2ca7309e-f6330990 "71 Clean Room",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,1553575,2020-06-21T12:20:00-07:00 Los_Angeles,"unknown",M,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Zone Relative Humidity",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-ac90d516 "B71 BELLA Lab Lab 146",,,"Los_Angeles","%RH",,,,M,2024-10-28T00:22:53.621Z
# @p:integration:r:267ea201-b86a0389 "71-AHU-37 Return Air Temperature",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3008771","NAE7/BACnet Trunk 2.71 AHU 37.71 AHU 37 RAT","Return Air Temperature","TL3008772","NAE7/BACnet Trunk 2.71 AHU 37.71 AHU 37 RAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",69.42666625976562Â°F,"\$equipRef \$navName",,,@p:integration:r:267bd1e8-4c2565f9 "71-AHU-37",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,1554020,2020-06-18T12:20:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Return Air Temperature",,M,,M,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b7c4-69cdffba "B71 BELLA Lab",M,,"Los_Angeles","Â°F",,,,,2024-10-28T00:22:53.633Z
# @p:integration:r:267ea201-159d86d3 "71-AHU-38 Return Air Temperature",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001364","NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 RAT","Return Air Temperature","TL3002763","NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 RAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",76.5644760131836Â°F,"\$equipRef \$navName",,,@p:integration:r:267bd1f1-30e50564 "71-AHU-38",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2268815,2020-06-19T09:52:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Return Air Temperature",,M,,M,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b7c4-69cdffba "B71 BELLA Lab",M,,"Los_Angeles","Â°F",,,,,2024-10-28T00:22:53.635Z
# @p:integration:r:267ea201-9672c6e7 "71-AHU-36 Outside Air Temperature",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001288","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 OAT","Outdoor Air Temperature","TL3002734","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 OAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",62.230411529541016Â°F,"\$equipRef \$navName",,,@p:integration:r:267bd1d7-5c2d62ae "71-AHU-36",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2268812,2020-06-19T09:53:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Outside Air Temperature",M,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b7c4-69cdffba "B71 BELLA Lab",M,,"Los_Angeles","Â°F",,,,,2024-10-28T00:22:53.641Z
# @p:integration:r:267d5139-4ba5ce20 "71-AHU-39 Supply Air Temperature",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001380","NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 SAT","Discharge Air Temperature","TL3002772","NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 SAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",61.986366271972656Â°F,"\$equipRef \$navName",,M,@p:integration:r:267bd1f9-ed5ccb3e "71-AHU-39",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2270454,2020-06-18T06:17:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Supply Air Temperature",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7befc-7ae06237 "B71 BELLA Lab Rm 131 (Control)",M,,"Los_Angeles","Â°F",,,,,2024-10-28T00:22:53.655Z
# @p:integration:r:267d5139-aee72aca "71-AHU-34 Supply Air Temperature",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3000093","NAE7/N2 Trunk 1.71_AHU34.DAT","Discharge Air Temperature","TL3008908","NAE7/N2 Trunk 1.71_AHU34.DAT.Trend2",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",59.86663818359375Â°F,"\$equipRef \$navName",,M,@p:integration:r:267bcd2d-e15fd59e "71-AHU-34",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2270460,2020-06-18T06:17:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Supply Air Temperature",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:29cd07f7-ab30dec0 "71-AHU-34",M,,"Los_Angeles","Â°F",,,,,2024-10-28T00:22:53.66Z
# @p:integration:r:2683c081-5c3a5d42 "71-AHU-38 Zone Relative Humidity",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001369","NAE7/BACnet Trunk 2.71 AHU 38.71 RM 295 HUMIDITY","Zone Humidity","TL3002767","NAE7/BACnet Trunk 2.71 AHU 38.71 RM 295 HUMIDITY.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",27.400470733642578%RH,"\$equipRef \$navName",,,@p:integration:r:267bd1f1-30e50564 "71-AHU-38",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2264491,2020-06-22T09:55:00-07:00 Los_Angeles,"unknown",M,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Zone Relative Humidity",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b7c4-69cdffba "B71 BELLA Lab",,,"Los_Angeles","%RH",,,,M,2024-10-28T00:22:53.671Z
# @p:integration:r:267e619f-e9e84253 "71-AHU-39 Economizer Outside Air Temperature Lockout",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AV3001378","NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 OA LOCKOUT SP","CS Input (Float)","TL3009623","NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 OA LOCKOUT SP.Trend1",144_records,,30min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",65.0999984741211Â°F,"\$equipRef \$navName",M,,@p:integration:r:268527b1-83c9b917 "71-AHU-39 Economizer",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,117126,2022-01-06T15:00:00-08:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Outside Air Temperature Lockout",M,M,,,,@p:integration:r:2288ede8-e064f7db "71",M,@p:integration:r:2dc7befc-7ae06237 "B71 BELLA Lab Rm 131 (Control)",M,,"Los_Angeles","Â°F",,,,,2024-10-28T00:22:53.678Z
# @p:integration:r:267ea201-8710bdaa "B71 BELLA Lab Lab 146 ERC [Zone 3 (E)] Zone Temperature (Laser 3)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3002351","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 3 TEMP","Zone Temperature","TL3002751","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 3 TEMP.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",70.94218444824219Â°F,"\$equipRef \$navName",,,@p:integration:r:2ca72ffd-5996755a "B71 BELLA Lab Lab 146 ERC [Zone 3 (E)]",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2268796,2020-06-19T09:52:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Zone Temperature (Laser 3)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-ac90d516 "B71 BELLA Lab Lab 146",M,,"Los_Angeles","Â°F",,,,M,2024-10-28T00:22:53.685Z
# @p:integration:r:267e623c-c00e0b8c "71-AHU-38 Mixed Air Temperature",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001362","NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 MAT","Mixed Air Temperature","TL3002760","NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 MAT.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",73.49935913085938Â°F,"\$equipRef \$navName",,,@p:integration:r:267bd1f1-30e50564 "71-AHU-38",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2270259,2020-06-18T09:51:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",M,"Mixed Air Temperature",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b7c4-69cdffba "B71 BELLA Lab",M,,"Los_Angeles","Â°F",,,,,2024-10-28T00:22:53.688Z
# @p:integration:r:267d5625-fc6fe48a "71-AHU-36 Supply Air Relative Humidity",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001319","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SA HUMID","Discharge Air Humidity","TL3002732","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SA HUMID.Trend1",144_records,,1min,M,M,,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",50.33509063720703%RH,"\$equipRef \$navName",,M,@p:integration:r:267bd1d7-5c2d62ae "71-AHU-36",M,1min,15min,2024-10-29T11:44:00-07:00 Los_Angeles,,2270476,2020-06-18T06:17:00-07:00 Los_Angeles,"unknown",M,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Supply Air Relative Humidity",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b7c4-69cdffba "B71 BELLA Lab",,,"Los_Angeles","%RH",,,,,2024-10-28T00:22:53.689Z
#
#
#
# Parsed Grid:
# {'id': Ref('p:integration:r:267ea201-0d8e905e', '71-AHU-39 Return Air Temperature', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3001385', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 PREHEAT TEMP', 'bacnetDesc': 'Return Air Temperature', 'bacnetHis': 'TL3002771', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 PREHEAT TEMP.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'cmd': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(62.811588287353516, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': None, 'equipRef': Ref('p:integration:r:267bd1f9-ed5ccb3e', '71-AHU-39', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 29, 11, 44, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2268813.0, 'hisStart': datetime.datetime(2020, 6, 19, 9, 52, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Return Air Temperature', 'outside': None, 'point': MARKER, 'preheat': None, 'return': MARKER, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7befc-7ae06237', 'B71 BELLA Lab Rm 131 (Control)', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'writeLevel': None, 'writeStatus': None, 'zone': None, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 408000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:267d5138-e31feaaa', '71-AHU-37 Supply Air Temperature', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3001341', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 37.71 AHU 37 SAT', 'bacnetDesc': 'Discharge Air Temperature', 'bacnetHis': 'TL3002739', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 37.71 AHU 37 SAT.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'cmd': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(67.7739486694336, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': MARKER, 'equipRef': Ref('p:integration:r:267bd1e8-4c2565f9', '71-AHU-37', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 29, 11, 44, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2270469.0, 'hisStart': datetime.datetime(2020, 6, 18, 6, 18, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Supply Air Temperature', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7b7c4-69cdffba', 'B71 BELLA Lab', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'writeLevel': None, 'writeStatus': None, 'zone': None, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 436000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:267ea201-196a07a3', 'B71 BELLA Lab Lab 146C ERC [Exp Cave] Zone Temperature (Cave)', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3002374', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 EXPERIMENT CAVE ZAT', 'bacnetDesc': 'Zone Temperature', 'bacnetHis': 'TL3002759', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 EXPERIMENT CAVE ZAT.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'cmd': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(72.31693267822266, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': None, 'equipRef': Ref('p:integration:r:2ca7314e-9dfe75ee', 'B71 BELLA Lab Lab 146C ERC [Exp Cave]', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 29, 11, 44, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2268819.0, 'hisStart': datetime.datetime(2020, 6, 19, 9, 53, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Zone Temperature (Cave)', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7b8d1-a8c73d66', 'B71 BELLA Lab Lab 146C', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'writeLevel': None, 'writeStatus': None, 'zone': MARKER, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 438000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:267ea201-276dec1f', '71-AHU-39 Zone Temperature', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3001388', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 ZAT', 'bacnetDesc': 'Zone Temperature', 'bacnetHis': 'TL3002773', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 ZAT.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'cmd': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(70.21957397460938, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': None, 'equipRef': Ref('p:integration:r:267bd1f9-ed5ccb3e', '71-AHU-39', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 29, 11, 44, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2268798.0, 'hisStart': datetime.datetime(2020, 6, 19, 9, 52, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Zone Temperature', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7befc-7ae06237', 'B71 BELLA Lab Rm 131 (Control)', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'writeLevel': None, 'writeStatus': None, 'zone': MARKER, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 439000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:2683b862-3c26638a', 'B71 BELLA Lab Lab 146 ERC [Zone 1 (NE)] Supply Air Temperature (Laser 1)', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3002347', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 1 SAT', 'bacnetDesc': 'Cold Deck Temperature', 'bacnetHis': 'TL3002746', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 1 SAT.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'cmd': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(68.89019775390625, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': MARKER, 'equipRef': Ref('p:integration:r:2ca72ffd-a09ddce9', 'B71 BELLA Lab Lab 146 ERC [Zone 1 (NE)]', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 29, 11, 44, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2264476.0, 'hisStart': datetime.datetime(2020, 6, 22, 9, 55, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Supply Air Temperature (Laser 1)', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7b8d1-ac90d516', 'B71 BELLA Lab Lab 146', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'writeLevel': None, 'writeStatus': None, 'zone': MARKER, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 445000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:2ca74be8-6b8f8d0b', '71-AHU-36 Supply Air Temperature Setpoint', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AV3001315', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SAT SP', 'bacnetDesc': 'CS Input (Float)', 'bacnetHis': 'TL3002814', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SAT SP.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': 0.20000000298023224, 'bacnetLogInterval': BasicQuantity(0.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'cmd': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(55.0, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': MARKER, 'equipRef': Ref('p:integration:r:267bd1d7-5c2d62ae', '71-AHU-36', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 29, 11, 44, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': 'cov', 'hisSize': 70361.0, 'hisStart': datetime.datetime(2022, 11, 2, 16, 16, 7, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Supply Air Temperature Setpoint', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': None, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': MARKER, 'spaceRef': Ref('p:integration:r:2dc7b7c4-69cdffba', 'B71 BELLA Lab', True), 'temp': MARKER, 'tmp': datetime.date(2023, 9, 27), 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'writeLevel': None, 'writeStatus': None, 'zone': None, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 456000, tzinfo=datetime.timezone.utc)}
# ...
# {'id': Ref('p:integration:r:267d5139-4ba5ce20', '71-AHU-39 Supply Air Temperature', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3001380', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 SAT', 'bacnetDesc': 'Discharge Air Temperature', 'bacnetHis': 'TL3002772', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 SAT.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'cmd': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(61.986366271972656, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': MARKER, 'equipRef': Ref('p:integration:r:267bd1f9-ed5ccb3e', '71-AHU-39', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 29, 11, 44, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2270454.0, 'hisStart': datetime.datetime(2020, 6, 18, 6, 17, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Supply Air Temperature', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7befc-7ae06237', 'B71 BELLA Lab Rm 131 (Control)', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'writeLevel': None, 'writeStatus': None, 'zone': None, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 655000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:267d5139-aee72aca', '71-AHU-34 Supply Air Temperature', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3000093', 'bacnetCurName': 'NAE7/N2 Trunk 1.71_AHU34.DAT', 'bacnetDesc': 'Discharge Air Temperature', 'bacnetHis': 'TL3008908', 'bacnetHisName': 'NAE7/N2 Trunk 1.71_AHU34.DAT.Trend2', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'cmd': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(59.86663818359375, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': MARKER, 'equipRef': Ref('p:integration:r:267bcd2d-e15fd59e', '71-AHU-34', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 29, 11, 44, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2270460.0, 'hisStart': datetime.datetime(2020, 6, 18, 6, 17, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Supply Air Temperature', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:29cd07f7-ab30dec0', '71-AHU-34', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'writeLevel': None, 'writeStatus': None, 'zone': None, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 660000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:2683c081-5c3a5d42', '71-AHU-38 Zone Relative Humidity', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3001369', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 38.71 RM 295 HUMIDITY', 'bacnetDesc': 'Zone Humidity', 'bacnetHis': 'TL3002767', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 38.71 RM 295 HUMIDITY.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'cmd': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(27.400470733642578, '%RH'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': None, 'equipRef': Ref('p:integration:r:267bd1f1-30e50564', '71-AHU-38', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 29, 11, 44, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2264491.0, 'hisStart': datetime.datetime(2020, 6, 22, 9, 55, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': MARKER, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Zone Relative Humidity', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7b7c4-69cdffba', 'B71 BELLA Lab', True), 'temp': None, 'tmp': None, 'tz': 'Los_Angeles', 'unit': '%RH', 'water': None, 'writeLevel': None, 'writeStatus': None, 'zone': MARKER, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 671000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:267e619f-e9e84253', '71-AHU-39 Economizer Outside Air Temperature Lockout', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AV3001378', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 OA LOCKOUT SP', 'bacnetDesc': 'CS Input (Float)', 'bacnetHis': 'TL3009623', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 OA LOCKOUT SP.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(30.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'cmd': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(65.0999984741211, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': MARKER, 'discharge': None, 'equipRef': Ref('p:integration:r:268527b1-83c9b917', '71-AHU-39 Economizer', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 29, 11, 44, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 117126.0, 'hisStart': datetime.datetime(2022, 1, 6, 15, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Outside Air Temperature Lockout', 'outside': MARKER, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': None, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': MARKER, 'spaceRef': Ref('p:integration:r:2dc7befc-7ae06237', 'B71 BELLA Lab Rm 131 (Control)', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'writeLevel': None, 'writeStatus': None, 'zone': None, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 678000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:267ea201-8710bdaa', 'B71 BELLA Lab Lab 146 ERC [Zone 3 (E)] Zone Temperature (Laser 3)', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3002351', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 3 TEMP', 'bacnetDesc': 'Zone Temperature', 'bacnetHis': 'TL3002751', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 3 TEMP.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'cmd': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(70.94218444824219, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': None, 'equipRef': Ref('p:integration:r:2ca72ffd-5996755a', 'B71 BELLA Lab Lab 146 ERC [Zone 3 (E)]', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 29, 11, 44, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2268796.0, 'hisStart': datetime.datetime(2020, 6, 19, 9, 52, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Zone Temperature (Laser 3)', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7b8d1-ac90d516', 'B71 BELLA Lab Lab 146', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'writeLevel': None, 'writeStatus': None, 'zone': MARKER, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 685000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:267e623c-c00e0b8c', '71-AHU-38 Mixed Air Temperature', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3001362', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 MAT', 'bacnetDesc': 'Mixed Air Temperature', 'bacnetHis': 'TL3002760', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 MAT.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'cmd': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(73.49935913085938, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': None, 'equipRef': Ref('p:integration:r:267bd1f1-30e50564', '71-AHU-38', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 29, 11, 44, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2270259.0, 'hisStart': datetime.datetime(2020, 6, 18, 9, 51, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': MARKER, 'navName': 'Mixed Air Temperature', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7b7c4-69cdffba', 'B71 BELLA Lab', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'writeLevel': None, 'writeStatus': None, 'zone': None, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 688000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:267d5625-fc6fe48a', '71-AHU-36 Supply Air Relative Humidity', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3001319', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SA HUMID', 'bacnetDesc': 'Discharge Air Humidity', 'bacnetHis': 'TL3002732', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SA HUMID.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'cmd': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(50.33509063720703, '%RH'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': MARKER, 'equipRef': Ref('p:integration:r:267bd1d7-5c2d62ae', '71-AHU-36', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 29, 11, 44, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2270476.0, 'hisStart': datetime.datetime(2020, 6, 18, 6, 17, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': MARKER, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Supply Air Relative Humidity', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7b7c4-69cdffba', 'B71 BELLA Lab', True), 'temp': None, 'tmp': None, 'tz': 'Los_Angeles', 'unit': '%RH', 'water': None, 'writeLevel': None, 'writeStatus': None, 'zone': None, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 689000, tzinfo=datetime.timezone.utc)}
# Data successfully exported to parsedfile.csv
# An error occurred while plotting the data: 'ts'

# %%
file_name = "datfile.txt"  # Update with your file name
zinc_output = read_file(file_name)
grid = parse_zinc_output(zinc_output)

# Create a list of lists to store the row data
rows = []

# Iterate over the rows in the grid
for row in grid:
    # Convert the row (which is a dictionary) to a list of values

    row_values = [row[col] for col in grid.column.keys()]
    rows.append(row_values)

# Convert the list of lists to a NumPy array
array = np.array(rows)
df = pd.DataFrame(array)
df.to_csv ('parsedfile2.csv')
df
# Out:
#                                                    0       1   \
# 0   @p:integration:r:267ea201-0d8e905e '71-AHU-39 ...  MARKER
# 1   @p:integration:r:267d5138-e31feaaa '71-AHU-37 ...  MARKER
# 2   @p:integration:r:267ea201-196a07a3 'B71 BELLA ...  MARKER
# 3   @p:integration:r:267ea201-276dec1f '71-AHU-39 ...  MARKER
# 4   @p:integration:r:2683b862-3c26638a 'B71 BELLA ...  MARKER
# 5   @p:integration:r:2ca74be8-6b8f8d0b '71-AHU-36 ...  MARKER
# 6   @p:integration:r:267e623c-5e7f6985 '71-AHU-39 ...  MARKER
# 7   @p:integration:r:2683b862-24c6d3f1 'B71 BELLA ...  MARKER
# 8   @p:integration:r:267ea201-da2ebace '71-AHU-36 ...  MARKER
# 9   @p:integration:r:267d5139-144b9aaa '71-AHU-38 ...  MARKER
# 10  @p:integration:r:2683b862-fe6a7368 'B71 BELLA ...  MARKER
# 11  @p:integration:r:267ea201-8f32486c 'B71 BELLA ...  MARKER
# 12  @p:integration:r:267ea201-ddf21d90 'B71 BELLA ...  MARKER
# 13  @p:integration:r:267ea201-ec8e91ee 'B71 BELLA ...  MARKER
# 14  @p:integration:r:267ea201-eff8bf7b 'B71 BELLA ...  MARKER
# 15  @p:integration:r:24c357ca-63fe7fab 'B71 CHW Pl...    None
# 16  @p:integration:r:2683b862-e2bc50aa 'B71 BELLA ...  MARKER
# 17  @p:integration:r:267d5138-e6f96a0f '71-AHU-36 ...  MARKER
# 18  @p:integration:r:2683b862-3b054f74 'B71 BELLA ...  MARKER
# 19  @p:integration:r:267ea201-8cb9e4d8 '71 Clean R...  MARKER
# 20  @p:integration:r:267e8317-2318784e '71-AHU-34 ...  MARKER
# 21  @p:integration:r:267d5625-8d219c71 '71-AHU-36 ...  MARKER
# 22  @p:integration:r:2683be06-9d05efdb '71 Clean R...  MARKER
# 23  @p:integration:r:2683b862-d6db65c4 'B71 BELLA ...  MARKER
# 24  @p:integration:r:267ea201-ca73ecb9 '71-AHU-38 ...  MARKER
# 25  @p:integration:r:2683b862-5868b3e6 'B71 BELLA ...  MARKER
# 26  @p:integration:r:2eb3e716-08088939 '71 Bella V...    None
# 27  @p:integration:r:2ca74be8-4a8b96c1 '71-AHU-36 ...  MARKER
# 28  @p:integration:r:267ea201-e198290b 'B71 BELLA ...  MARKER
# 29  @p:integration:r:267e619f-1b6dee0c '71-AHU-38 ...  MARKER
# 30  @p:integration:r:2683be07-a8a1e51d '71 Clean R...  MARKER
# 31  @p:integration:r:267ea201-b86a0389 '71-AHU-37 ...  MARKER
# 32  @p:integration:r:267ea201-159d86d3 '71-AHU-38 ...  MARKER
# 33  @p:integration:r:267ea201-9672c6e7 '71-AHU-36 ...  MARKER
# 34  @p:integration:r:267d5139-4ba5ce20 '71-AHU-39 ...  MARKER
# 35  @p:integration:r:267d5139-aee72aca '71-AHU-34 ...  MARKER
# 36  @p:integration:r:2683c081-5c3a5d42 '71-AHU-38 ...  MARKER
# 37  @p:integration:r:267e619f-e9e84253 '71-AHU-39 ...  MARKER
# 38  @p:integration:r:267ea201-8710bdaa 'B71 BELLA ...  MARKER
# 39  @p:integration:r:267e623c-c00e0b8c '71-AHU-38 ...  MARKER
# 40  @p:integration:r:267d5625-fc6fe48a '71-AHU-36 ...  MARKER
#
#                                                2          3   \
# 0   @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3001385
# 1   @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3001341
# 2   @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3002374
# 3   @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3001388
# 4   @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3002347
# 5   @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AV3001315
# 6   @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3001382
# 7   @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3002361
# 8   @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3001325
# 9   @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3001375
# 10  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3002362
# 11  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3002349
# 12  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3002365
# 13  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3002350
# 14  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3002364
# 15  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3000214
# 16  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3002359
# 17  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3001321
# 18  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3002346
# 19  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3001347
# 20  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3000090
# 21  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3001284
# 22  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AV3001314
# 23  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3002348
# 24  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3001370
# 25  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3002360
# 26  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AV3024548
# 27  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3001289
# 28  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3002363
# 29  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AV3002632
# 30  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AV3001313
# 31  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3008771
# 32  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3001364
# 33  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3001288
# 34  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3001380
# 35  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3000093
# 36  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3001369
# 37  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AV3001378
# 38  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3002351
# 39  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3001362
# 40  @p:integration:r:241312f3-16ea8cc5 '71-NAE-7'  AI3001319
#
#                                                    4   \
# 0   NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 PREHEA...
# 1         NAE7/BACnet Trunk 2.71 AHU 37.71 AHU 37 SAT
# 2   NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71...
# 3         NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 ZAT
# 4   NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71...
# 5      NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SAT SP
# 6         NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 MAT
# 7   NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71...
# 8   NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 CLG VL...
# 9         NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 SAT
# 10  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71...
# 11  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71...
# 12  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71...
# 13  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71...
# 14  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71...
# 15                 NAE7/N2 Trunk 1.71_ARU8_CT4.CHW_ST
# 16  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71...
# 17        NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SAT
# 18  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71...
# 19     NAE7/BACnet Trunk 2.71 AHU 37.71 CLEAN RM TEMP
# 20                       NAE7/N2 Trunk 1.71_AHU34.ZAT
# 21   NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 OA HUMID
# 22  NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 37 CLEAN ...
# 23  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71...
# 24        NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 ZAT
# 25  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71...
# 26                                               None
# 27  NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 PREHEA...
# 28  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71...
# 29  NAE7/BACnet Trunk 2.71 AHU 38.ECON LOCKOUT DP ...
# 30  NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 37 CLEAN ...
# 31        NAE7/BACnet Trunk 2.71 AHU 37.71 AHU 37 RAT
# 32        NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 RAT
# 33        NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 OAT
# 34        NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 SAT
# 35                       NAE7/N2 Trunk 1.71_AHU34.DAT
# 36   NAE7/BACnet Trunk 2.71 AHU 38.71 RM 295 HUMIDITY
# 37  NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 OA LOC...
# 38  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71...
# 39        NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 MAT
# 40   NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SA HUMID
#
#                                   5          6   \
# 0             Return Air Temperature  TL3002771
# 1          Discharge Air Temperature  TL3002739
# 2                   Zone Temperature  TL3002759
# 3                   Zone Temperature  TL3002773
# 4              Cold Deck Temperature  TL3002746
# 5                   CS Input (Float)  TL3002814
# 6              Mixed Air Temperature  TL3002770
# 7          DISCHARGE AIR Temperature  TL3002754
# 8          Discharge Air Temperature  TL3002724
# 9          Discharge Air Temperature  TL3002769
# 10                       Temperature  TL3002755
# 11                  Zone Temperature  TL3002749
# 12                  Zone Temperature  TL3002758
# 13                  Zone Temperature  TL3002750
# 14                  Zone Temperature  TL3002757
# 15  Chilled Water Supply Temperature  TL3000663
# 16         Discharge Air Temperature  TL3002752
# 17         Discharge Air Temperature  TL3002733
# 18         Discharge Air Temperature  TL3002747
# 19                  Zone Temperature  TL3002742
# 20                  Zone Temperature  TL3008907
# 21              Outdoor Air Humidity  TL3002735
# 22                  CS Input (Float)  TL3002804
# 23         DISCHARGE AIR Temperature  TL3002748
# 24                  Zone Temperature  TL3002768
# 25                   SUPPLY AIR TEMP  TL3002753
# 26                              None  TL3024549
# 27               Preheat Temperature  TL3002722
# 28                  Zone Temperature  TL3002756
# 29                  CS Input (Float)  TL3009621
# 30                  CS Input (Float)  TL3002805
# 31            Return Air Temperature  TL3008772
# 32            Return Air Temperature  TL3002763
# 33           Outdoor Air Temperature  TL3002734
# 34         Discharge Air Temperature  TL3002772
# 35         Discharge Air Temperature  TL3008908
# 36                     Zone Humidity  TL3002767
# 37                  CS Input (Float)  TL3009623
# 38                  Zone Temperature  TL3002751
# 39             Mixed Air Temperature  TL3002760
# 40            Discharge Air Humidity  TL3002732
#
#                                                    7              8     9   \
# 0   NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 PREHEA...  144.0 records  None
# 1   NAE7/BACnet Trunk 2.71 AHU 37.71 AHU 37 SAT.Tr...  144.0 records  None
# 2   NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71...  144.0 records  None
# 3   NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 ZAT.Tr...  144.0 records  None
# 4   NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71...  144.0 records  None
# 5   NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SAT SP...  144.0 records   0.2
# 6   NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 MAT.Tr...  144.0 records  None
# 7   NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71...  144.0 records  None
# 8   NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 CLG VL...  144.0 records  None
# 9   NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 SAT.Tr...  144.0 records  None
# 10  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71...  144.0 records  None
# 11  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71...  144.0 records  None
# 12  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71...  144.0 records  None
# 13  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71...  144.0 records  None
# 14  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71...  144.0 records  None
# 15          NAE7/N2 Trunk 1.71_ARU8_CT4.CHW_ST.Trend1  144.0 records  None
# 16  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71...  144.0 records  None
# 17  NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SAT.Tr...  144.0 records  None
# 18  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71...  144.0 records  None
# 19  NAE7/BACnet Trunk 2.71 AHU 37.71 CLEAN RM TEMP...  144.0 records  None
# 20                NAE7/N2 Trunk 1.71_AHU34.ZAT.Trend2  144.0 records  None
# 21  NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 OA HUM...  144.0 records  None
# 22  NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 37 CLEAN ...  144.0 records  None
# 23  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71...  144.0 records  None
# 24  NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 ZAT.Tr...  144.0 records  None
# 25  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71...  144.0 records  None
# 26                                               None           None  None
# 27  NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 PREHEA...  144.0 records  None
# 28  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71...  144.0 records  None
# 29  NAE7/BACnet Trunk 2.71 AHU 38.ECON LOCKOUT DP ...  144.0 records  None
# 30  NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 37 CLEAN ...  144.0 records  None
# 31  NAE7/BACnet Trunk 2.71 AHU 37.71 AHU 37 RAT.Tr...  144.0 records  None
# 32  NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 RAT.Tr...  144.0 records  None
# 33  NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 OAT.Tr...  144.0 records  None
# 34  NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 SAT.Tr...  144.0 records  None
# 35                NAE7/N2 Trunk 1.71_AHU34.DAT.Trend2  144.0 records  None
# 36  NAE7/BACnet Trunk 2.71 AHU 38.71 RM 295 HUMIDI...  144.0 records  None
# 37  NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 OA LOC...  144.0 records  None
# 38  NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71...  144.0 records  None
# 39  NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 MAT.Tr...  144.0 records  None
# 40  NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SA HUM...  144.0 records  None
#
#     ...                                                 44      45  \
# 0   ...  @p:integration:r:2dc7befc-7ae06237 'B71 BELLA ...  MARKER
# 1   ...  @p:integration:r:2dc7b7c4-69cdffba 'B71 BELLA ...  MARKER
# 2   ...  @p:integration:r:2dc7b8d1-a8c73d66 'B71 BELLA ...  MARKER
# 3   ...  @p:integration:r:2dc7befc-7ae06237 'B71 BELLA ...  MARKER
# 4   ...  @p:integration:r:2dc7b8d1-ac90d516 'B71 BELLA ...  MARKER
# 5   ...  @p:integration:r:2dc7b7c4-69cdffba 'B71 BELLA ...  MARKER
# 6   ...  @p:integration:r:2dc7befc-7ae06237 'B71 BELLA ...  MARKER
# 7   ...  @p:integration:r:2dc7b8d1-ac90d516 'B71 BELLA ...  MARKER
# 8   ...  @p:integration:r:2dc7b7c4-69cdffba 'B71 BELLA ...  MARKER
# 9   ...  @p:integration:r:2dc7b7c4-69cdffba 'B71 BELLA ...  MARKER
# 10  ...  @p:integration:r:2dc7b8d1-a8c73d66 'B71 BELLA ...  MARKER
# 11  ...  @p:integration:r:2dc7b8d1-ac90d516 'B71 BELLA ...  MARKER
# 12  ...  @p:integration:r:2dc7b8d1-ac90d516 'B71 BELLA ...  MARKER
# 13  ...  @p:integration:r:2dc7b8d1-ac90d516 'B71 BELLA ...  MARKER
# 14  ...  @p:integration:r:2dc7b8d1-ac90d516 'B71 BELLA ...  MARKER
# 15  ...       @p:integration:r:2288edfc-23aecc39 'B71 CHW'  MARKER
# 16  ...  @p:integration:r:2dc7b8d1-ac90d516 'B71 BELLA ...  MARKER
# 17  ...  @p:integration:r:2dc7b7c4-69cdffba 'B71 BELLA ...  MARKER
# 18  ...  @p:integration:r:2dc7b8d1-ac90d516 'B71 BELLA ...  MARKER
# 19  ...  @p:integration:r:2dc7b8d1-ac90d516 'B71 BELLA ...  MARKER
# 20  ...     @p:integration:r:29cd07f7-ab30dec0 '71-AHU-34'  MARKER
# 21  ...  @p:integration:r:2dc7b7c4-69cdffba 'B71 BELLA ...    None
# 22  ...  @p:integration:r:2dc7b8d1-ac90d516 'B71 BELLA ...  MARKER
# 23  ...  @p:integration:r:2dc7b8d1-ac90d516 'B71 BELLA ...  MARKER
# 24  ...  @p:integration:r:2dc7b7c4-69cdffba 'B71 BELLA ...  MARKER
# 25  ...  @p:integration:r:2dc7b8d1-665600bf 'B71 BELLA ...  MARKER
# 26  ...  @p:integration:r:2dc7b7c4-69cdffba 'B71 BELLA ...    None
# 27  ...  @p:integration:r:2dc7b7c4-69cdffba 'B71 BELLA ...  MARKER
# 28  ...  @p:integration:r:2dc7b8d1-665600bf 'B71 BELLA ...  MARKER
# 29  ...  @p:integration:r:2dc7b7c4-69cdffba 'B71 BELLA ...  MARKER
# 30  ...  @p:integration:r:2dc7b8d1-ac90d516 'B71 BELLA ...    None
# 31  ...  @p:integration:r:2dc7b7c4-69cdffba 'B71 BELLA ...  MARKER
# 32  ...  @p:integration:r:2dc7b7c4-69cdffba 'B71 BELLA ...  MARKER
# 33  ...  @p:integration:r:2dc7b7c4-69cdffba 'B71 BELLA ...  MARKER
# 34  ...  @p:integration:r:2dc7befc-7ae06237 'B71 BELLA ...  MARKER
# 35  ...     @p:integration:r:29cd07f7-ab30dec0 '71-AHU-34'  MARKER
# 36  ...  @p:integration:r:2dc7b7c4-69cdffba 'B71 BELLA ...    None
# 37  ...  @p:integration:r:2dc7befc-7ae06237 'B71 BELLA ...  MARKER
# 38  ...  @p:integration:r:2dc7b8d1-ac90d516 'B71 BELLA ...  MARKER
# 39  ...  @p:integration:r:2dc7b7c4-69cdffba 'B71 BELLA ...  MARKER
# 40  ...  @p:integration:r:2dc7b7c4-69cdffba 'B71 BELLA ...    None
#
#             46           47    48      49    50       51      52  \
# 0         None  Los_Angeles   Â°F    None  None     None    None
# 1         None  Los_Angeles   Â°F    None  None     None    None
# 2         None  Los_Angeles   Â°F    None  None     None  MARKER
# 3         None  Los_Angeles   Â°F    None  None     None  MARKER
# 4         None  Los_Angeles   Â°F    None  None     None  MARKER
# 5   2023-09-27  Los_Angeles   Â°F    None  None     None    None
# 6         None  Los_Angeles   Â°F    None  None     None    None
# 7         None  Los_Angeles   Â°F    None  None     None  MARKER
# 8   2023-09-27  Los_Angeles   Â°F    None  None     None    None
# 9         None  Los_Angeles   Â°F    None  None     None    None
# 10        None  Los_Angeles   Â°F    None  None     None  MARKER
# 11        None  Los_Angeles   Â°F    None  None     None  MARKER
# 12        None  Los_Angeles   Â°F    None  None     None  MARKER
# 13        None  Los_Angeles   Â°F    None  None     None  MARKER
# 14        None  Los_Angeles   Â°F    None  None     None  MARKER
# 15        None  Los_Angeles   Â°F  MARKER  None     None    None
# 16        None  Los_Angeles   Â°F    None  None     None  MARKER
# 17        None  Los_Angeles   Â°F    None  None     None    None
# 18        None  Los_Angeles   Â°F    None  None     None  MARKER
# 19        None  Los_Angeles   Â°F    None  None     None  MARKER
# 20        None  Los_Angeles   Â°F    None  None     None  MARKER
# 21        None  Los_Angeles   %RH    None  None     None    None
# 22        None  Los_Angeles   Â°F    None  None     None  MARKER
# 23        None  Los_Angeles   Â°F    None  None     None  MARKER
# 24        None  Los_Angeles   Â°F    None  None     None  MARKER
# 25        None  Los_Angeles   Â°F    None  None     None  MARKER
# 26        None  Los_Angeles  None    None  17.0  unknown    None
# 27  2023-09-27  Los_Angeles   Â°F    None  None     None    None
# 28        None  Los_Angeles   Â°F    None  None     None  MARKER
# 29        None  Los_Angeles   Â°F    None  None     None    None
# 30        None  Los_Angeles   %RH    None  None     None  MARKER
# 31        None  Los_Angeles   Â°F    None  None     None    None
# 32        None  Los_Angeles   Â°F    None  None     None    None
# 33        None  Los_Angeles   Â°F    None  None     None    None
# 34        None  Los_Angeles   Â°F    None  None     None    None
# 35        None  Los_Angeles   Â°F    None  None     None    None
# 36        None  Los_Angeles   %RH    None  None     None  MARKER
# 37        None  Los_Angeles   Â°F    None  None     None    None
# 38        None  Los_Angeles   Â°F    None  None     None  MARKER
# 39        None  Los_Angeles   Â°F    None  None     None    None
# 40        None  Los_Angeles   %RH    None  None     None    None
#
#                                  53
# 0  2024-10-28 00:22:53.408000+00:00
# 1  2024-10-28 00:22:53.436000+00:00
# 2  2024-10-28 00:22:53.438000+00:00
# 3  2024-10-28 00:22:53.439000+00:00
# 4  2024-10-28 00:22:53.445000+00:00
# 5  2024-10-28 00:22:53.456000+00:00
# 6  2024-10-28 00:22:53.457000+00:00
# 7  2024-10-28 00:22:53.459000+00:00
# 8  2024-10-28 00:22:53.460000+00:00
# 9  2024-10-28 00:22:53.466000+00:00
# 10 2024-10-28 00:22:53.495000+00:00
# 11 2024-10-28 00:22:53.499000+00:00
# 12 2024-10-28 00:22:53.515000+00:00
# 13 2024-10-28 00:22:53.516000+00:00
# 14 2024-10-28 00:22:53.521000+00:00
# 15 2024-10-28 00:22:53.526000+00:00
# 16 2024-10-28 00:22:53.538000+00:00
# 17 2024-10-28 00:22:53.543000+00:00
# 18 2024-10-28 00:22:53.554000+00:00
# 19 2024-10-28 00:22:53.555000+00:00
# 20 2024-10-28 00:22:53.559000+00:00
# 21 2024-10-28 00:22:53.563000+00:00
# 22 2024-10-28 00:22:53.565000+00:00
# 23 2024-10-28 00:22:53.569000+00:00
# 24 2024-10-28 00:22:53.576000+00:00
# 25 2024-10-28 00:22:53.584000+00:00
# 26 2024-10-29 18:49:17.503000+00:00
# 27 2024-10-28 00:22:53.594000+00:00
# 28 2024-10-28 00:22:53.596000+00:00
# 29 2024-10-28 00:22:53.607000+00:00
# 30 2024-10-28 00:22:53.621000+00:00
# 31 2024-10-28 00:22:53.633000+00:00
# 32 2024-10-28 00:22:53.635000+00:00
# 33 2024-10-28 00:22:53.641000+00:00
# 34 2024-10-28 00:22:53.655000+00:00
# 35 2024-10-28 00:22:53.660000+00:00
# 36 2024-10-28 00:22:53.671000+00:00
# 37 2024-10-28 00:22:53.678000+00:00
# 38 2024-10-28 00:22:53.685000+00:00
# 39 2024-10-28 00:22:53.688000+00:00
# 40 2024-10-28 00:22:53.689000+00:00
#
# [41 rows x 54 columns]

# %%
# Cleanup of Extracted Data
df2 = df.loc[:,[0,36,29,17,18]]
df2.columns = ["Name", "Description","Update_Time","Status","Value"]
df2["System_Time"] = dt.datetime.now()
df2["System_Time"] = df2["System_Time"].dt.tz_localize('America/Los_Angeles')
df2["Update_Time"] = df2['Update_Time'].dt.tz_convert('America/Los_Angeles')
df2['Data_Age'] = df2['System_Time']  - df2['Update_Time']
df2
df3 = df2
df3
def extract_number_and_unit(temp_string):
    temp_string = str(temp_string)
    pattern =  r"([-+]?\d*\.\d+|\d+)\s*([^\d\s]+)"
    match = re.search(pattern, temp_string)
    if match:
        number = match.group(1)
        unit = match.group(2).replace('Â°F', 'F')  # Remove the unwanted character
        return number, unit
    return None, None

df3[['Value', 'Unit']]=df3['Value'].apply(lambda x:pd.Series(extract_number_and_unit(x)))

df3 = df3.iloc[:,[0,1,3,4,7,2,5,6]]
df3
df3.to_csv('parsedfile3.csv')

# %%
df3 = df2
df3
def extract_number_and_unit(temp_string):
    temp_string = str(temp_string)
    pattern =  r"([-+]?\d*\.\d+|\d+)\s*([^\d\s]+)"
    match = re.search(pattern, temp_string)
    if match:
        number = match.group(1)
        unit = match.group(2).replace('Â°F', 'F')  # Remove the unwanted character
        return number, unit
    return None, None

df3[['Value', 'Unit']]=df3['Value'].apply(lambda x:pd.Series(extract_number_and_unit(x)))

df3 = df3.iloc[:,[0,1,3,4,7,2,5,6]]
df3
df3.to_csv('parsedfile3.csv')
