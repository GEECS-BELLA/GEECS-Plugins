# %%
import configparser
import re
import requests
import scram
import requests
from hszinc import parse
import hszinc
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""Functions to interact with SkySpark database using Axon queries

Module includes the following functions:
request        Send Axon request to SkySpark, return resulting text
__name__       Simple console to send REST request to SkySpark

Created on Sun Nov 19 15:29:51 2017
Last updated on 2019-08-23

@author: rvitti
"""



# Define constants
CONFIG_FILE = "./spyspark.cfg"
MAX_ATTEMPTS = 3

# Define global module variables, in particular config object
config = configparser.ConfigParser()
result_list = config.read(CONFIG_FILE)
if not result_list:
    raise Exception("Missing config file spyspark.cfg")
host_addr = config['Host']['Address']


# Exception raised if empty result is received from SkySpark
class AxonException(Exception):
    pass


def about() -> str:
    uri = host_addr + "about"
    return request(uri)


def axon_request(query: str, result_type: str = "text/zinc") -> str:
    uri = host_addr + "eval"
    
    # Encode special characters
    query = query.replace("\\$","\\\\\$").replace('"', '\\\"')
    # Encode request as Zinc
    data = f"""ver:"3.0"\nexpr\n"{query}"\n""".encode('utf-8')

    return request(uri, data, result_type, request_type="text/zinc")


def his_write(data) -> str:
    uri = host_addr + "hisWrite"
    return request(uri, data)


def commit(data) -> str:
    uri = host_addr + "commit"
    return request(uri, data)


def request(request_uri: str, data: str = None,
            result_type: str = "text/zinc",
            request_type: str = "text/zinc") -> str:
    """Process REST operation, return resulting text
    
    Use SkySpark REST API with uri provided as first argument.
    Use authorization token stored in spyspark.cfg. If
    an authorization issue is detected, attempt to re-authorize. If other
    HTTP issues are detected, raise Exception. Return result as string.
    
    If the Axon query returns 'empty\n', a custom AxonException is raised.
    This can occur if there are no results or if the query is bad.
    
    Keyword arguments:
    request_uri  -- REST Uri to use with REST operation
    data         -- Data to use with POST request, or None for GET
    result_type  -- Requested MIME type in which to receive results
                    (default: "text/zinc" for Zinc format)
    request_type -- MIME type in which the request data is provided
    """
    # Attempt to send request; if an authorization issue is detected,
    # retry after updating the authorization token
    for i in range(0, MAX_ATTEMPTS):
        auth_token = scram.current_token()
        headers= {"authorization": "BEARER authToken="+auth_token,
                  "accept": result_type,
                  "content-type": request_type}
        if data is None:
            r = request.get(request_uri, headers=headers)
        else:
            r = requests.post(request_uri, data=data, headers=headers)
        if r.status_code == 200:
            if r.text != "empty\n":
                if result_type == "text/csv":
                    text = re.sub('â\x9c\x93','True',r.text)    # Checkmarks
                    text = re.sub('Â','',text)
                    return text
                else:
                    return r.text
            else:
                raise AxonException("Empty result, check query")
        if r.status_code == 400:    # Missing required header
            raise Exception("HTTP request is missing a required header")
        if r.status_code == 404:    # Invalid URI
            raise Exception("URI does not map to a valid operation URI")    
        if r.status_code == 406:    # Invalid "accept" header
            raise Exception("Unsupported MIME type requested")
        if r.status_code == 403:    # Authorization issue, try to reauthorize
            scram.update_token()
        else:
            raise Exception("HTTP error: %d" % r.status_code)



if __name__ == '__main__':
    """Simple console to send REST request to SkySpark and display results"""
    ref = "https://skyfoundry.com/doc/docSkySpark/Axon"
    sample = "read(point and siteRef->dis==\"Building 77\" and " + \
             "equipRef->dis==\"AHU-33\" and discharge and air " + \
             "and temp and sensor).hisRead(yesterday))\n" +\
             "Enter 'q' or 'quit' to exit"
    query = ""
    while query.lower() != "quit" and query.lower() != "q":
        query = input("Enter Axon query:\n>")
        response = axon_request(query)
        if query.lower() == "help":
            print("""\nReference: %s\nExample: %s""" % (ref, sample))
        elif query.lower() != "quit" and query.lower() != "q":
            try:
                #print(axon_request(query))
                print('hello')
                data = axon_request(query)
                with open('datfile.txt','w') as file:
                    file.write(data)
            except AxonException as e:
                print(e.args[0]+'\n')
# Out:
# Enter Axon query:
# > readAll(bellaCurValPolling)
# hello
# Enter Axon query:
# > readAll(bellaCurValPolling)
# hello
# Enter Axon query:
# > q

# %%
def read_file(file_name):
    try:
        with open(file_name, 'r') as file:
            content = file.read()
        return content
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")
        return None

def parse_zinc_output(zinc_output):
    try:
        grid = hszinc.parse(zinc_output)
        return grid
    except Exception as e:
        print(f"Failed to parse Zinc output: {e}")
        return None        
def main():
    file_name = "datfile.txt"  # Update with your file name
    
    # Read the text file
    zinc_output = read_file(file_name)
    if zinc_output is None:
        return
    
    print("Zinc Output:")
    print(zinc_output)

    # Parse the Zinc output
    grid = parse_zinc_output(zinc_output)
    if grid is None:
        return
    
    print("\nParsed Grid:")
    for row in grid:
        print(row)

    export_to_csv(grid, 'parsedfile.csv')

    plot_data(grid)

import csv

def export_to_csv(grid, csv_file_name):
    try:
        with open(csv_file_name, 'w', newline='') as csvfile:
            writer = csv.writer(csvfile)
            
            # Write the header
            header = grid.column.keys()
            writer.writerow(header)
            
            # Write the rows
            for row in grid:
                writer.writerow([row.get(col, '') for col in header])
                
        print(f"Data successfully exported to {csv_file_name}")
    except Exception as e:
        print(f"An error occurred while writing to the CSV file: {e}")



def plot_data(grid):
    try:
        # Assuming the grid has columns 'time' and 'value'
        times = [row['ts'] for row in grid]
        values = [row['v0'] for row in grid]

        plt.figure(figsize=(10, 5))
        plt.plot(times, values, marker='o', linestyle='-', color='b')
        plt.xlabel('Time')
        plt.ylabel('Value')
        plt.title('Line Graph of Parsed Data')
        plt.grid(True)
        plt.show()
    except Exception as e:
        print(f"An error occurred while plotting the data: {e}")

if __name__ == "__main__":
    main()
# Out:
# Zinc Output:
# ver:"3.0"
# id,air,bacnetConnRef,bacnetCur,bacnetCurName,bacnetDesc,bacnetHis,bacnetHisName,bacnetLogBufferSize,bacnetLogCovIncrement,bacnetLogInterval,bacnetPoint,bellaCurValPolling,chilled,connRef,cur,curStatus,curVal,disMacro,disable,discharge,equipRef,his,hisCollectInterval,hisCollectWriteFreq,hisEnd,hisMode,hisSize,hisStart,hisStatus,humidity,kind,leaving,locationRef,mixed,navName,outside,point,preheat,return,sensor,siteRef,sp,spaceRef,temp,tmp,tz,unit,water,zone,mod
# @p:integration:r:267d5139-144b9aaa "71-AHU-38 Supply Air Temperature",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001375","NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 SAT","Discharge Air Temperature","TL3002769","NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 SAT.Trend1",144_records,,1min,M,M,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",69.5362777709961Â°F,"\$equipRef \$navName",,M,@p:integration:r:267bd1f1-30e50564 "71-AHU-38",M,1min,15min,2024-10-28T11:16:00-07:00 Los_Angeles,,2269000,2020-06-18T06:18:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Supply Air Temperature",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b7c4-69cdffba "B71 BELLA Lab",M,,"Los_Angeles","Â°F",,,2024-10-28T00:22:53.466Z
# @p:integration:r:267ea201-8f32486c "B71 BELLA Lab Lab 146 ERC [Zone 1 (NE)] Zone Temperature (Laser 1)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3002349","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 1 TEMP","Zone Temperature","TL3002749","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 1 TEMP.Trend1",144_records,,1min,M,M,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",71.1180648803711Â°F,"\$equipRef \$navName",,,@p:integration:r:2ca72ffd-a09ddce9 "B71 BELLA Lab Lab 146 ERC [Zone 1 (NE)]",M,1min,15min,2024-10-28T11:16:00-07:00 Los_Angeles,,2267350,2020-06-19T09:52:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Zone Temperature (Laser 1)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-ac90d516 "B71 BELLA Lab Lab 146",M,,"Los_Angeles","Â°F",,M,2024-10-28T00:22:53.499Z
# @p:integration:r:2683b862-fe6a7368 "B71 BELLA Lab Lab 146C ERC [Exp Cave] Supply Air Temperature (Cave)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3002362","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 EXPERIMENT CAVE SAT","Temperature","TL3002755","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 EXPERIMENT CAVE SAT.Trend1",144_records,,1min,M,M,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",68.19474029541016Â°F,"\$equipRef \$navName",,M,@p:integration:r:2ca7314e-9dfe75ee "B71 BELLA Lab Lab 146C ERC [Exp Cave]",M,1min,15min,2024-10-28T11:16:00-07:00 Los_Angeles,,2263028,2020-06-22T09:56:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Supply Air Temperature (Cave)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-a8c73d66 "B71 BELLA Lab Lab 146C",M,,"Los_Angeles","Â°F",,M,2024-10-28T00:22:53.495Z
# @p:integration:r:2683b862-5868b3e6 "B71 BELLA Lab Lab 126A,B ERC (Staging/Gowning) Supply Air Temperature (STAGING GWNING)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3002360","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 STAGING GWNING SAT","SUPPLY AIR TEMP","TL3002753","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 STAGING GWNING SAT.Trend1",144_records,,1min,M,M,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",67.86781311035156Â°F,"\$equipRef \$navName",,M,@p:integration:r:2ca7310f-99857f5f "B71 BELLA Lab Lab 126A,B ERC (Staging/Gowning)",M,1min,15min,2024-10-28T11:16:00-07:00 Los_Angeles,,2263012,2020-06-22T09:55:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Supply Air Temperature (STAGING GWNING)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-665600bf "B71 BELLA Lab Lab 126A,B",M,,"Los_Angeles","Â°F",,M,2024-10-28T00:22:53.584Z
# @p:integration:r:267e8317-2318784e "71-AHU-34 Zone Temperature",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3000090","NAE7/N2 Trunk 1.71_AHU34.ZAT","Zone Temperature","TL3008907","NAE7/N2 Trunk 1.71_AHU34.ZAT.Trend2",144_records,,1min,M,M,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",69.623291015625Â°F,"\$equipRef \$navName",,,@p:integration:r:267bcd2d-e15fd59e "71-AHU-34",M,1min,15min,2024-10-28T11:16:00-07:00 Los_Angeles,,2267330,2020-06-19T09:52:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Zone Temperature",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:29cd07f7-ab30dec0 "71-AHU-34",M,,"Los_Angeles","Â°F",,M,2024-10-28T00:22:53.559Z
# @p:integration:r:267ea201-8710bdaa "B71 BELLA Lab Lab 146 ERC [Zone 3 (E)] Zone Temperature (Laser 3)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3002351","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 3 TEMP","Zone Temperature","TL3002751","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 3 TEMP.Trend1",144_records,,1min,M,M,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",71.13362121582031Â°F,"\$equipRef \$navName",,,@p:integration:r:2ca72ffd-5996755a "B71 BELLA Lab Lab 146 ERC [Zone 3 (E)]",M,1min,15min,2024-10-28T11:16:00-07:00 Los_Angeles,,2267328,2020-06-19T09:52:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Zone Temperature (Laser 3)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-ac90d516 "B71 BELLA Lab Lab 146",M,,"Los_Angeles","Â°F",,M,2024-10-28T00:22:53.685Z
# @p:integration:r:267ea201-e198290b "B71 BELLA Lab Lab 126A,B ERC (Staging/Gowning) Zone Temperature (STAGING GWNING)",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3002363","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 STAGING GWNING ZAT","Zone Temperature","TL3002756","NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 STAGING GWNING ZAT.Trend1",144_records,,1min,M,M,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",74.93162536621094Â°F,"\$equipRef \$navName",,,@p:integration:r:2ca7310f-99857f5f "B71 BELLA Lab Lab 126A,B ERC (Staging/Gowning)",M,1min,15min,2024-10-28T11:16:00-07:00 Los_Angeles,,2267350,2020-06-19T09:53:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Zone Temperature (STAGING GWNING)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-665600bf "B71 BELLA Lab Lab 126A,B",M,,"Los_Angeles","Â°F",,M,2024-10-28T00:22:53.596Z
# @p:integration:r:267ea201-0d8e905e "71-AHU-39 Return Air Temperature",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001385","NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 PREHEAT TEMP","Return Air Temperature","TL3002771","NAE7/BACnet Trunk 2.71 AHU 39.71 AHU 39 PREHEAT TEMP.Trend1",144_records,,1min,M,M,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",65.27330017089844Â°F,"\$equipRef \$navName",,,@p:integration:r:267bd1f9-ed5ccb3e "71-AHU-39",M,1min,15min,2024-10-28T11:16:00-07:00 Los_Angeles,,2267345,2020-06-19T09:52:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Return Air Temperature",,M,,M,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7befc-7ae06237 "B71 BELLA Lab Rm 131 (Control)",M,,"Los_Angeles","Â°F",,,2024-10-28T00:22:53.408Z
# @p:integration:r:267d5625-8d219c71 "71-AHU-36 Outside Air Relative Humidity",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001284","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36
M,1min,15min,2024-10-28T11:16:00-07:00 Los_Angeles,,2263008,2020-06-22T09:55:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Supply Air Temperature (Laser 1)",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b8d1-ac90d516 "B71 BELLA Lab Lab 146",M,,"Los_Angeles","Â°F",,M,2024-10-28T00:22:53.445Z
# @p:integration:r:267d5138-e6f96a0f "71-AHU-36 Supply Air Temperature",M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3001321","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SAT","Discharge Air Temperature","TL3002733","NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SAT.Trend1",144_records,,1min,M,M,,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",54.96949005126953Â°F,"\$equipRef \$navName",,M,@p:integration:r:267bd1d7-5c2d62ae "71-AHU-36",M,1min,15min,2024-10-28T11:16:00-07:00 Los_Angeles,,2269033,2020-06-18T06:18:00-07:00 Los_Angeles,"unknown",,"Number",,@p:integration:r:267bcaad-329ce41f "B71 AHUs & Exhaust",,"Supply Air Temperature",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2dc7b7c4-69cdffba "B71 BELLA Lab",M,,"Los_Angeles","Â°F",,,2024-10-28T00:22:53.543Z
# @p:integration:r:24c357ca-63fe7fab "B71 CHW Plant Primary CHW Supply Temperature",,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7","AI3000214","NAE7/N2 Trunk 1.71_ARU8_CT4.CHW_ST","Chilled Water Supply Temperature","TL3000663","NAE7/N2 Trunk 1.71_ARU8_CT4.CHW_ST.Trend1",144_records,,1min,M,M,M,@p:integration:r:241312f3-16ea8cc5 "71-NAE-7",M,"ok",44.9375Â°F,"\$equipRef \$navName",,,@p:integration:r:296a3ba6-0404f8a3 "B71 CHW Plant Primary",M,1min,15min,2024-10-28T11:16:00-07:00 Los_Angeles,,1727390,2019-07-17T21:25:00-07:00 Los_Angeles,"unknown",,"Number",M,@p:integration:r:2288edfc-23aecc39 "B71 CHW",,"CHW Supply Temperature",,M,,,M,@p:integration:r:2288ede8-e064f7db "71",,@p:integration:r:2288edfc-23aecc39 "B71 CHW",M,,"Los_Angeles","Â°F",M,,2024-10-28T00:22:53.526Z
#
#
#
# Parsed Grid:
# {'id': Ref('p:integration:r:267d5139-144b9aaa', '71-AHU-38 Supply Air Temperature', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3001375', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 SAT', 'bacnetDesc': 'Discharge Air Temperature', 'bacnetHis': 'TL3002769', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 38.71 AHU 38 SAT.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(69.5362777709961, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': MARKER, 'equipRef': Ref('p:integration:r:267bd1f1-30e50564', '71-AHU-38', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 28, 11, 16, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2269000.0, 'hisStart': datetime.datetime(2020, 6, 18, 6, 18, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Supply Air Temperature', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7b7c4-69cdffba', 'B71 BELLA Lab', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'zone': None, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 466000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:267ea201-8f32486c', 'B71 BELLA Lab Lab 146 ERC [Zone 1 (NE)] Zone Temperature (Laser 1)', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3002349', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 1 TEMP', 'bacnetDesc': 'Zone Temperature', 'bacnetHis': 'TL3002749', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 1 TEMP.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(71.1180648803711, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': None, 'equipRef': Ref('p:integration:r:2ca72ffd-a09ddce9', 'B71 BELLA Lab Lab 146 ERC [Zone 1 (NE)]', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 28, 11, 16, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2267350.0, 'hisStart': datetime.datetime(2020, 6, 19, 9, 52, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Zone Temperature (Laser 1)', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7b8d1-ac90d516', 'B71 BELLA Lab Lab 146', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'zone': MARKER, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 499000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:2683b862-fe6a7368', 'B71 BELLA Lab Lab 146C ERC [Exp Cave] Supply Air Temperature (Cave)', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3002362', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 EXPERIMENT CAVE SAT', 'bacnetDesc': 'Temperature', 'bacnetHis': 'TL3002755', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 EXPERIMENT CAVE SAT.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(68.19474029541016, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': MARKER, 'equipRef': Ref('p:integration:r:2ca7314e-9dfe75ee', 'B71 BELLA Lab Lab 146C ERC [Exp Cave]', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 28, 11, 16, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2263028.0, 'hisStart': datetime.datetime(2020, 6, 22, 9, 56, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Supply Air Temperature (Cave)', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7b8d1-a8c73d66', 'B71 BELLA Lab Lab 146C', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'zone': MARKER, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 495000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:2683b862-5868b3e6', 'B71 BELLA Lab Lab 126A,B ERC (Staging/Gowning) Supply Air Temperature (STAGING GWNING)', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3002360', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 STAGING GWNING SAT', 'bacnetDesc': 'SUPPLY AIR TEMP', 'bacnetHis': 'TL3002753', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 4-7.71 STAGING GWNING SAT.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(67.86781311035156, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': MARKER, 'equipRef': Ref('p:integration:r:2ca7310f-99857f5f', 'B71 BELLA Lab Lab 126A,B ERC (Staging/Gowning)', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 28, 11, 16, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2263012.0, 'hisStart': datetime.datetime(2020, 6, 22, 9, 55, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Supply Air Temperature (STAGING GWNING)', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7b8d1-665600bf', 'B71 BELLA Lab Lab 126A,B', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'zone': MARKER, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 584000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:267e8317-2318784e', '71-AHU-34 Zone Temperature', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3000090', 'bacnetCurName': 'NAE7/N2 Trunk 1.71_AHU34.ZAT', 'bacnetDesc': 'Zone Temperature', 'bacnetHis': 'TL3008907', 'bacnetHisName': 'NAE7/N2 Trunk 1.71_AHU34.ZAT.Trend2', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(69.623291015625, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': None, 'equipRef': Ref('p:integration:r:267bcd2d-e15fd59e', '71-AHU-34', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 28, 11, 16, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2267330.0, 'hisStart': datetime.datetime(2020, 6, 19, 9, 52, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Zone Temperature', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:29cd07f7-ab30dec0', '71-AHU-34', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'zone': MARKER, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 559000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:267ea201-8710bdaa', 'B71 BELLA Lab Lab 146 ERC [Zone 3 (E)] Zone Temperature (Laser 3)', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3002351', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 3 TEMP', 'bacnetDesc': 'Zone Temperature', 'bacnetHis': 'TL3002751', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 3 TEMP.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(71.13362121582031, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': None, 'equipRef': Ref('p:integration:r:2ca72ffd-5996755a', 'B71 BELLA Lab Lab 146 ERC [Zone 3 (E)]', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 28, 11, 16, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2267328.0, 'hisStart': datetime.datetime(2020, 6, 19, 9, 52, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Zone Temperature (Laser 3)', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7b8d1-ac90d516', 'B71 BELLA Lab Lab 146', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'zone': MARKER, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 685000, tzinfo=datetime.timezone.utc)}
# ...
# {'id': Ref('p:integration:r:2683be07-a8a1e51d', '71 Clean Room Zone Relative Humidity', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AV3001313', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 37 CLEAN RM ZAH', 'bacnetDesc': 'CS Input (Float)', 'bacnetHis': 'TL3002805', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 37 CLEAN RM ZAH.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(47.308040618896484, '%RH'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': None, 'equipRef': Ref('p:integration:r:2ca7309e-f6330990', '71 Clean Room', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 28, 11, 16, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 1552107.0, 'hisStart': datetime.datetime(2020, 6, 21, 12, 20, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': MARKER, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Zone Relative Humidity', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7b8d1-ac90d516', 'B71 BELLA Lab Lab 146', True), 'temp': None, 'tmp': None, 'tz': 'Los_Angeles', 'unit': '%RH', 'water': None, 'zone': MARKER, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 621000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:2683be06-9d05efdb', '71 Clean Room Zone Temperature', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AV3001314', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 37 CLEAN RM ZAT', 'bacnetDesc': 'CS Input (Float)', 'bacnetHis': 'TL3002804', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 37 CLEAN RM ZAT.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(71.55989837646484, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': None, 'equipRef': Ref('p:integration:r:2ca7309e-f6330990', '71 Clean Room', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 28, 11, 16, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 1552107.0, 'hisStart': datetime.datetime(2020, 6, 21, 12, 20, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Zone Temperature', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7b8d1-ac90d516', 'B71 BELLA Lab Lab 146', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'zone': MARKER, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 565000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:267d5625-fc6fe48a', '71-AHU-36 Supply Air Relative Humidity', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3001319', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SA HUMID', 'bacnetDesc': 'Discharge Air Humidity', 'bacnetHis': 'TL3002732', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SA HUMID.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(88.02095794677734, '%RH'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': MARKER, 'equipRef': Ref('p:integration:r:267bd1d7-5c2d62ae', '71-AHU-36', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 28, 11, 16, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2269008.0, 'hisStart': datetime.datetime(2020, 6, 18, 6, 17, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': MARKER, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Supply Air Relative Humidity', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7b7c4-69cdffba', 'B71 BELLA Lab', True), 'temp': None, 'tmp': None, 'tz': 'Los_Angeles', 'unit': '%RH', 'water': None, 'zone': None, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 689000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:267ea201-8cb9e4d8', '71 Clean Room Zone Temperature (Clean Rm)', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3001347', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 37.71 CLEAN RM TEMP', 'bacnetDesc': 'Zone Temperature', 'bacnetHis': 'TL3002742', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 37.71 CLEAN RM TEMP.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(71.55989837646484, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': None, 'equipRef': Ref('p:integration:r:2ca7309e-f6330990', '71 Clean Room', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 28, 11, 16, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2267330.0, 'hisStart': datetime.datetime(2020, 6, 19, 9, 52, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Zone Temperature (Clean Rm)', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7b8d1-ac90d516', 'B71 BELLA Lab Lab 146', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'zone': MARKER, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 555000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:2683b862-3c26638a', 'B71 BELLA Lab Lab 146 ERC [Zone 1 (NE)] Supply Air Temperature (Laser 1)', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3002347', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 1 SAT', 'bacnetDesc': 'Cold Deck Temperature', 'bacnetHis': 'TL3002746', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 37 REHEAT ZN 1-3.71 LASER BAY ZN 1 SAT.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(69.0125961303711, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': MARKER, 'equipRef': Ref('p:integration:r:2ca72ffd-a09ddce9', 'B71 BELLA Lab Lab 146 ERC [Zone 1 (NE)]', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 28, 11, 16, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2263008.0, 'hisStart': datetime.datetime(2020, 6, 22, 9, 55, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Supply Air Temperature (Laser 1)', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7b8d1-ac90d516', 'B71 BELLA Lab Lab 146', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'zone': MARKER, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 445000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:267d5138-e6f96a0f', '71-AHU-36 Supply Air Temperature', True), 'air': MARKER, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3001321', 'bacnetCurName': 'NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SAT', 'bacnetDesc': 'Discharge Air Temperature', 'bacnetHis': 'TL3002733', 'bacnetHisName': 'NAE7/BACnet Trunk 2.71 AHU 36.71 AHU 36 SAT.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': None, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(54.96949005126953, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': MARKER, 'equipRef': Ref('p:integration:r:267bd1d7-5c2d62ae', '71-AHU-36', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 28, 11, 16, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 2269033.0, 'hisStart': datetime.datetime(2020, 6, 18, 6, 18, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': None, 'locationRef': Ref('p:integration:r:267bcaad-329ce41f', 'B71 AHUs & Exhaust', True), 'mixed': None, 'navName': 'Supply Air Temperature', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2dc7b7c4-69cdffba', 'B71 BELLA Lab', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': None, 'zone': None, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 543000, tzinfo=datetime.timezone.utc)}
# {'id': Ref('p:integration:r:24c357ca-63fe7fab', 'B71 CHW Plant Primary CHW Supply Temperature', True), 'air': None, 'bacnetConnRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'bacnetCur': 'AI3000214', 'bacnetCurName': 'NAE7/N2 Trunk 1.71_ARU8_CT4.CHW_ST', 'bacnetDesc': 'Chilled Water Supply Temperature', 'bacnetHis': 'TL3000663', 'bacnetHisName': 'NAE7/N2 Trunk 1.71_ARU8_CT4.CHW_ST.Trend1', 'bacnetLogBufferSize': BasicQuantity(144.0, 'records'), 'bacnetLogCovIncrement': None, 'bacnetLogInterval': BasicQuantity(1.0, 'min'), 'bacnetPoint': MARKER, 'bellaCurValPolling': MARKER, 'chilled': MARKER, 'connRef': Ref('p:integration:r:241312f3-16ea8cc5', '71-NAE-7', True), 'cur': MARKER, 'curStatus': 'ok', 'curVal': BasicQuantity(44.9375, 'Â°F'), 'disMacro': '$equipRef $navName', 'disable': None, 'discharge': None, 'equipRef': Ref('p:integration:r:296a3ba6-0404f8a3', 'B71 CHW Plant Primary', True), 'his': MARKER, 'hisCollectInterval': BasicQuantity(1.0, 'min'), 'hisCollectWriteFreq': BasicQuantity(15.0, 'min'), 'hisEnd': datetime.datetime(2024, 10, 28, 11, 16, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisMode': None, 'hisSize': 1727390.0, 'hisStart': datetime.datetime(2019, 7, 17, 21, 25, tzinfo=<DstTzInfo 'America/Los_Angeles' PDT-1 day, 17:00:00 DST>), 'hisStatus': 'unknown', 'humidity': None, 'kind': 'Number', 'leaving': MARKER, 'locationRef': Ref('p:integration:r:2288edfc-23aecc39', 'B71 CHW', True), 'mixed': None, 'navName': 'CHW Supply Temperature', 'outside': None, 'point': MARKER, 'preheat': None, 'return': None, 'sensor': MARKER, 'siteRef': Ref('p:integration:r:2288ede8-e064f7db', '71', True), 'sp': None, 'spaceRef': Ref('p:integration:r:2288edfc-23aecc39', 'B71 CHW', True), 'temp': MARKER, 'tmp': None, 'tz': 'Los_Angeles', 'unit': 'Â°F', 'water': MARKER, 'zone': None, 'mod': datetime.datetime(2024, 10, 28, 0, 22, 53, 526000, tzinfo=datetime.timezone.utc)}
# An error occurred while writing to the CSV file: [Errno 13] Permission denied: 'parsedfile.csv'
# An error occurred while plotting the data: 'ts'

# %%
file_name = "datfile.txt"  # Update with your file name
zinc_output = read_file(file_name)
grid = parse_zinc_output(zinc_output)

# Create a list of lists to store the row data
rows = []

# Iterate over the rows in the grid
for row in grid:
    # Convert the row (which is a dictionary) to a list of values

    row_values = [row[col] for col in grid.column.keys()]
    rows.append(row_values)

# Convert the list of lists to a NumPy array
array = np.array(rows)
df = pd.DataFrame(array)

# %%
# Cleanup of Extracted Data
df2 = df.loc[:,[35,5,25,16, 17]]
df2.columns = ["Name", "Description","Update_Time","Status","Value"]
df2["System_Time"] = dt.datetime.now()
df2["System_Time"] = df2["System_Time"].dt.tz_localize('America/Los_Angeles')
df2["Update_Time"] = df2['Update_Time'].dt.tz_convert('America/Los_Angeles')
df2['Data_Age'] = df2['System_Time']  - df2['Update_Time']
df2
# Out:
#                                        Name                       Description  \
# 0                    Supply Air Temperature         Discharge Air Temperature
# 1                Zone Temperature (Laser 1)                  Zone Temperature
# 2             Supply Air Temperature (Cave)                       Temperature
# 3   Supply Air Temperature (STAGING GWNING)                   SUPPLY AIR TEMP
# 4                          Zone Temperature                  Zone Temperature
# 5                Zone Temperature (Laser 3)                  Zone Temperature
# 6         Zone Temperature (STAGING GWNING)                  Zone Temperature
# 7                    Return Air Temperature            Return Air Temperature
# 8             Outside Air Relative Humidity              Outdoor Air Humidity
# 9                Zone Temperature (Laser 4)                  Zone Temperature
# 10          Outside Air Temperature Lockout                  CS Input (Float)
# 11                         Zone Temperature                  Zone Temperature
# 12            Zone Temperature (Beam Focus)                  Zone Temperature
# 13                   Return Air Temperature            Return Air Temperature
# 14                   Supply Air Temperature         Discharge Air Temperature
# 15                    Mixed Air Temperature             Mixed Air Temperature
# 16      Supply Air Temperature (Beam Focus)         DISCHARGE AIR Temperature
# 17                   Return Air Temperature            Return Air Temperature
# 18                         Preheat Air Temp               Preheat Temperature
# 19       Leaving Air Temperature (CHW Coil)         Discharge Air Temperature
# 20                   Zone Relative Humidity                     Zone Humidity
# 21         Supply Air Temperature (Laser 4)         Discharge Air Temperature
# 22                    Mixed Air Temperature             Mixed Air Temperature
# 23                  Outside Air Temperature           Outdoor Air Temperature
# 24               Zone Temperature (Laser 2)                  Zone Temperature
# 25                   Supply Air Temperature         Discharge Air Temperature
# 26                   Supply Air Temperature         Discharge Air Temperature
# 27          Supply Air Temperature Setpoint                  CS Input (Float)
# 28                  Zone Temperature (Cave)                  Zone Temperature
# 29         Supply Air Temperature (Laser 2)         Discharge Air Temperature
# 30          Outside Air Temperature Lockout                  CS Input (Float)
# 31                         Zone Temperature                  Zone Temperature
# 32         Supply Air Temperature (Laser 3)         DISCHARGE AIR Temperature
# 33                   Zone Relative Humidity                  CS Input (Float)
# 34                         Zone Temperature                  CS Input (Float)
# 35             Supply Air Relative Humidity            Discharge Air Humidity
# 36              Zone Temperature (Clean Rm)                  Zone Temperature
# 37         Supply Air Temperature (Laser 1)             Cold Deck Temperature
2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 2  2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 3  2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 4  2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 5  2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 6  2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 7  2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 8  2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 9  2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 10 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 11 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 12 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 13 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 14 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 15 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 16 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 17 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 18 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 19 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 20 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 21 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 22 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 23 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 24 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 25 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 26 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 27 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 28 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 29 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 30 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 31 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 32 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 33 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 34 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 35 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 36 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 37 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 38 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177
# 39 2024-10-28 11:26:45.916177-07:00 0 days 00:10:45.916177

# %%
df3 = df2

df3
def extract_number_and_unit(temp_string):
    temp_string = str(temp_string)
    pattern =  r"([-+]?\d*\.\d+|\d+)\s*([^\d\s]+)"
    match = re.search(pattern, temp_string)
    if match:
        number = match.group(1)
        unit = match.group(2).replace('Â°F', 'F')  # Remove the unwanted character
        return number, unit
    return None, None

df3[['Value', 'Unit']]=df3['Value'].apply(lambda x:pd.Series(extract_number_and_unit(x)))

df3 = df3.iloc[:,[0,1,3,4,7,2,5,6]]
df3
# Out:
#                                        Name                       Description  \
# 0                    Supply Air Temperature         Discharge Air Temperature
# 1                Zone Temperature (Laser 1)                  Zone Temperature
# 2             Supply Air Temperature (Cave)                       Temperature
# 3   Supply Air Temperature (STAGING GWNING)                   SUPPLY AIR TEMP
# 4                          Zone Temperature                  Zone Temperature
# 5                Zone Temperature (Laser 3)                  Zone Temperature
# 6         Zone Temperature (STAGING GWNING)                  Zone Temperature
# 7                    Return Air Temperature            Return Air Temperature
# 8             Outside Air Relative Humidity              Outdoor Air Humidity
# 9                Zone Temperature (Laser 4)                  Zone Temperature
# 10          Outside Air Temperature Lockout                  CS Input (Float)
# 11                         Zone Temperature                  Zone Temperature
# 12            Zone Temperature (Beam Focus)                  Zone Temperature
# 13                   Return Air Temperature            Return Air Temperature
# 14                   Supply Air Temperature         Discharge Air Temperature
# 15                    Mixed Air Temperature             Mixed Air Temperature
# 16      Supply Air Temperature (Beam Focus)         DISCHARGE AIR Temperature
# 17                   Return Air Temperature            Return Air Temperature
# 18                         Preheat Air Temp               Preheat Temperature
# 19       Leaving Air Temperature (CHW Coil)         Discharge Air Temperature
# 20                   Zone Relative Humidity                     Zone Humidity
# 21         Supply Air Temperature (Laser 4)         Discharge Air Temperature
# 22                    Mixed Air Temperature             Mixed Air Temperature
# 23                  Outside Air Temperature           Outdoor Air Temperature
# 24               Zone Temperature (Laser 2)                  Zone Temperature
# 25                   Supply Air Temperature         Discharge Air Temperature
# 26                   Supply Air Temperature         Discharge Air Temperature
# 27          Supply Air Temperature Setpoint                  CS Input (Float)
# 28                  Zone Temperature (Cave)                  Zone Temperature
# 29         Supply Air Temperature (Laser 2)         Discharge Air Temperature
# 30          Outside Air Temperature Lockout                  CS Input (Float)
# 31                         Zone Temperature                  Zone Temperature
# 32         Supply Air Temperature (Laser 3)         DISCHARGE AIR Temperature
# 33                   Zone Relative Humidity                  CS Input (Float)
# 34                         Zone Temperature                  CS Input (Float)
# 35             Supply Air Relative Humidity            Discharge Air Humidity
# 36              Zone Temperature (Clean Rm)                  Zone Temperature
# 37         Supply Air Temperature (Laser 1)             Cold Deck Temperature
# 38                   Supply Air Temperature         Discharge Air Temperature
# 39                   CHW Supply Temperature  Chilled Water Supply Temperature
#
#    Status               Value Unit               Update_Time  \
