# %%
import time
import numpy as np
from GEECSPythonAPI import GEECSDevice

# %%
##List of of device names
caenSteeringMagnetsNames=['U_S1H','U_S1V','U_S2H','U_S2V',"U_S3H","U_S3V","U_S4H","U_S4V"]
caenSteeringMagnets=dict({})

#loop to make a dict of initialized device objects stored in a dict
for name in caenSteeringMagnetsNames:
    caenSteeringMagnets[name]=GEECSDevice(device_name=name)
    caenSteeringMagnets[name].device_initialize()

#some math to create a list of an exponentially decaying sine wave    
degaussAmp=4.9
x=np.linspace(0,16,129)
y=degaussAmp*np.sin(2*np.pi*x)*np.exp(-x/4)

#loop for executing degauss commands. top level loop goes throught current values to set. 
#The second loop goes through and checks the values. 
allGetVals=np.array([])
for value in y:    
    
    #this loop just sends all the commands (waits until command is accepted, i.e. "no error")
    #It doesn't wait to get a value back. This allows the commands to get sent out "asynchronously"
    for obj in caenSteeringMagnets:
        caenSteeringMagnets[obj].set_only_udp("Current",value)
    
    #this loop starts by reading the 'slow' udp response from the 'set' command above
    #after that, it sends a get command to retrieve the actual value
    for obj in caenSteeringMagnets:
        msg=caenSteeringMagnets[obj].read_slow_udp()
        val=caenSteeringMagnets[obj].get_and_wait_udp('Current')
        allGetVals=np.append(allGetVals,float(val))
# Out:
# 49831
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>3.358220>>no error,'
# b'U_S1H>>getCurrent>>4.603150>>no error,'
# b'U_S1H>>getCurrent>>3.154800>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>-2.963360>>no error,'
# b'U_S1H>>getCurrent>>-4.062070>>no error,'
# b'U_S1H>>getCurrent>>-2.783950>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>2.615470>>no error,'
# b'U_S1H>>getCurrent>>3.584810>>no error,'
# b'U_S1H>>getCurrent>>2.457010>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>-2.307930>>no error,'
# b'U_S1H>>getCurrent>>-3.163370>>no error,'
# b'U_S1H>>getCurrent>>-2.168070>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>2.036980>>no error,'
# b'U_S1H>>getCurrent>>2.791990>>no error,'
# b'U_S1H>>getCurrent>>1.913480>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>-1.797290>>no error,'
# b'U_S1H>>getCurrent>>-2.463750>>no error,'
# b'U_S1H>>getCurrent>>-1.688420>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>1.586260>>no error,'
# b'U_S1H>>getCurrent>>2.174360>>no error,'
# b'U_S1H>>getCurrent>>1.490290>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>-1.399720>>no error,'
# b'U_S1H>>getCurrent>>-1.918650>>no error,'
# b'U_S1H>>getCurrent>>-1.314890>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>1.235490>>no error,'
# b'U_S1H>>getCurrent>>1.693320>>no error,'
# b'U_S1H>>getCurrent>>1.160580>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>-1.089990>>no error,'
# b'U_S1H>>getCurrent>>-1.494260>>no error,'
# b'U_S1H>>getCurrent>>-1.023880>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>0.962210>>no error,'
# b'U_S1H>>getCurrent>>1.318730>>no error,'
# b'U_S1H>>getCurrent>>0.903950>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>-0.848910>>no error,'
# b'U_S1H>>getCurrent>>-1.163720>>no error,'
# b'U_S1H>>getCurrent>>-0.797360>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>0.749280>>no error,'
# b'U_S1H>>getCurrent>>1.027170>>no error,'
# b'U_S1H>>getCurrent>>0.703970>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>-0.660990>>no error,'
# b'U_S1H>>getCurrent>>-0.906230>>no error,'
# b'U_S1H>>getCurrent>>-0.621010>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>0.583530>>no error,'
# b'U_S1H>>getCurrent>>0.799910>>no error,'
# b'U_S1H>>getCurrent>>0.548160>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>-0.514680>>no error,'
# b'U_S1H>>getCurrent>>-0.705600>>no error,'
# b'U_S1H>>getCurrent>>-0.483420>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>0.454540>>no error,'
# b'U_S1H>>getCurrent>>0.623060>>no error,'
# b'U_S1H>>getCurrent>>0.427030>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>-0.400960>>no error,'
# b'U_S1H>>getCurrent>>-0.549580>>no error,'
# b'U_S1H>>getCurrent>>-0.376460>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>0.353980>>no error,'
# b'U_S1H>>getCurrent>>0.485050>>no error,'
# b'U_S1H>>getCurrent>>0.332480>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>-0.312200>>no error,'
# b'U_S1H>>getCurrent>>-0.428000>>no error,'
# b'U_S1H>>getCurrent>>-0.293250>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>0.275620>>no error,'
# b'U_S1H>>getCurrent>>0.377790>>no error,'
# b'U_S1H>>getCurrent>>0.258970>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>-0.243090>>no error,'
# b'U_S1H>>getCurrent>>-0.333230>>no error,'
# b'U_S1H>>getCurrent>>-0.228290>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>0.214590>>no error,'
# b'U_S1H>>getCurrent>>0.294340>>no error,'
# b'U_S1H>>getCurrent>>0.201650>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>-0.189230>>no error,'
# b'U_S1H>>getCurrent>>-0.259500>>no error,'
# b'U_S1H>>getCurrent>>-0.177670>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>0.167200>>no error,'
# b'U_S1H>>getCurrent>>0.229150>>no error,'
# b'U_S1H>>getCurrent>>0.157030>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>-0.147390>>no error,'
# b'U_S1H>>getCurrent>>-0.201940>>no error,'
# b'U_S1H>>getCurrent>>-0.138380>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>0.130220>>no error,'
# b'U_S1H>>getCurrent>>0.178530>>no error,'
# b'U_S1H>>getCurrent>>0.122360>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>-0.114570>>no error,'
# b'U_S1H>>getCurrent>>-0.157330>>no error,'
# b'U_S1H>>getCurrent>>-0.107640>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>0.101320>>no error,'
# b'U_S1H>>getCurrent>>0.139000>>no error,'
# b'U_S1H>>getCurrent>>0.095310>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>-0.089380>>no error,'
# b'U_S1H>>getCurrent>>-0.122430>>no error,'
# b'U_S1H>>getCurrent>>-0.083830>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>0.078900>>no error,'
# b'U_S1H>>getCurrent>>0.108260>>no error,'
# b'U_S1H>>getCurrent>>0.074280>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'
# b'U_S1H>>getCurrent>>-0.069500>>no error,'
# b'U_S1H>>getCurrent>>-0.095390>>no error,'
# b'U_S1H>>getCurrent>>-0.065340>>no error,'
# b'U_S1H>>getCurrent>>0.000080>>no error,'

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(allGetVals)

ax.set(xlabel='step number', ylabel='current (A)')
ax.grid()

plt.show()
