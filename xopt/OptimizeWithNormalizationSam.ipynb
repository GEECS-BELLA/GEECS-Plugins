# %% [markdown]
# ## First attempt to play with xopt

# %% [markdown]
# ## Load in a BELLA specific config file
# read in a yaml file which has the control variable information and the objective variable information

# %%
# Ignore all warnings
import warnings
warnings.filterwarnings("ignore")

import torch
from xopt.vocs import VOCS
from xopt.evaluator import Evaluator
from xopt.generators.bayesian import ExpectedImprovementGenerator
from xopt import Xopt

import yaml
import pandas as pd
import numpy as np


#define a "yaml file" with no entries for variables. These will be filled in used the "bella_config" yamml file
YAML = """
xopt:
    dump_file: dump.yaml
generator:
    name: upper_confidence_bound
    n_initial: 5
    optim:
        num_restarts: 1
    acq:
        proximal_lengthscales: []

evaluator:
    function: __main__.geecs_measurement

vocs:
    variables:
        {}
    objectives: {f: "MAXIMIZE"}

"""
yaml_output = yaml.safe_load(YAML)

with open("HTU_config.yaml", "r") as stream:
    try:
        bella_config=yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)
        
normalize_ranges=True

ranges=[]
obj_tags=[]

#parse the config file to create a dict with the variables in proper format for xopt
cv_tags=dict(bella_config['control_variables'])
for cv_tag, cv_config in cv_tags.items():
    if cv_config['set']:
        ranges.append(cv_config['range'])
        range_offset=[0,cv_config['range'][1]-cv_config['range'][0]]
        range_norm=[0,1]
        print(range_offset)
        if normalize_ranges:
            yaml_output['vocs']['variables'][cv_tag]=[0,1]
            yaml_output['generator']['acq']['proximal_lengthscales'].append(cv_config['proximal_lengthscale']/range_offset[1])
        else:
            yaml_output['vocs']['variables'][cv_tag]=cv_config['range']
    if cv_config['objective']:
        obj_tags.append(cv_tag)
        
        
# for i in obj_tags:
#     yaml_output['vocs']['objectives'][i]=bella_config['objective_variables'][i]['method']
    
print(yaml_output)

#until I figure out the above, we will need to initialize the requisite Xopt objects
#individually

# vocs = VOCS(
#     variables=yaml_output['vocs']['variables'],
#     objectives=yaml_output['vocs']['objectives'],
# )

# print(vocs)
print(obj_tags)
# Out:
# [0, 2.0]
# [0, 0.4]
# [0, 2.0]
# [0, 0.4]
# {'xopt': {'dump_file': 'dump.yaml'}, 'generator': {'name': 'upper_confidence_bound', 'n_initial': 5, 'optim': {'num_restarts': 1}, 'acq': {'proximal_lengthscales': [0.75, 3.75, 0.75, 3.75]}}, 'evaluator': {'function': '__main__.geecs_measurement'}, 'vocs': {'variables': {'HexY': [0, 1], 'HexV': [0, 1], 'HexZ': [0, 1], 'HexW': [0, 1]}, 'objectives': {'f': 'MAXIMIZE'}}}
# ['Charge']

# %% [markdown]
# ## define the get/set functions for BELLA GEECS

# %%
def client_factory(ip, port, var):
    print('in the client factory for device: ',var)
    client=socket.socket(socket.AF_INET, socket.SOCK_STREAM);
    client.connect((str(ip),int(port)))
    #client.setblocking(0)
    subcriptionstring = bytes('Wait>>'+str(var),'ascii')
    #get length of subscription message
    SubcriptionCmdLength = len(subcriptionstring)
    #Flatten the length of the subscription message length
    sizepack = struct.pack('>i', SubcriptionCmdLength)
    #Send the size of the message followed by the message
    client.sendall( sizepack + subcriptionstring)
    return client   

def get(tag):
    #can change how get is defined but use this function elsewhere
    value=get_tcp_nonblocking(tag)
    return value

def get_until_new(tag):
    attempts=0
    while attempts<6:
        val=get(tag)
        if bella_config['control_variables'][tag]['newDataFlag']==1:
            break
        else:
            time.sleep(0.2)
            attempts=attempts+1
    if attempts>5:
        val=0.0
    return val

def get_tcp_nonblocking(tag):    
    #info('function get1')
    
    #start by trying to check out a socket so that when a process calls  
    #to get the value, you don't have multiple attempts to read/clear the buffer.
    #If the socket isn't currently busy, swith it to "busy" until finished
    if bella_config['control_variables'][tag]['busy']==0: 
        #print("socket was clear when requested")
        bella_config['control_variables'][tag]['busy']=1
        if False: #skipping
            #print('objective function')
            f(x)
            if hasattr(y, '__iter__'):
                return y[0]
            else:
                return y
        else:
            client=bella_config['control_variables'][tag]['tcp_client']
            #print("got client: ",client)
            dt=0
            counter=0
            #note: the dt defined below should be shorter than the timeout in the select.select command
            #The select.select command asks the client if there is any information to transmist. If there
            #is, it returns true. If there is not any information after the timeout, it reports false.
            #Typical response time when a device has information to transmit is well below 1 ms. So, we rely
            # on the timeout to tell us that there is no information on the buffer, and we are waiting on 
            # another iteration of the device's acquire loop.
            while dt<0.0015:
                counter=counter+1
                t0=time.monotonic()
                ready=select.select([client],[],[],.002 ) #last arguement is timeout in seconds
                #print(ready)
                if ready[0]:
                    size = struct.unpack('>i', client.recv(4))[0]  # Extract the msg size from four bytes - mind the encoding
                    str_data = client.recv(size)
                    geecs=str_data.decode('ascii').split(",")
                    #print(geecs)
                    geecs=geecs[-2].split(" ")[0]
                    #print(geecs)
                    if len(geecs)==0:
                        geecs="nan"
                    if geecs=='on':
                        geecs=1
                    if geecs=='off':
                        geecs=0
                    #print(geecs)
                    if type(geecs) ==  str:
                        if any(c.isalpha() for c in geecs):
                            geecs=0
                    bella_config['control_variables'][tag]['actual_value']=geecs
                    #print(bella_config['control_variables'][tag]['value'])
                    bella_config['control_variables'][tag]['newDataFlag']=1
                    #print("chewing through TCP buffer. Device value: ",geecs)
                else:
                    #print("Buffer cleared")
                    if counter==1:
                        geecs=bella_config['control_variables'][tag]['actual_value']
                        bella_config['control_variables'][tag]['newDataFlag']=0
                t1=time.monotonic()
                dt=t1-t0
            bella_config['control_variables'][tag]['busy']=0 #release the socket
            #print("socket released")
    else:
        print("socket was busy when requested")
        geecs=bella_config['control_variables'][tag]['actual_value']
        bella_config['control_variables'][tag]['newDataFlag']=0
        bella_config['control_variables'][tag]['busy']=0
        print("new data: ",newDataFlags[index])
    #print("in get1 gotvalue ans index "+str(gotValues[index])+' '+str(index))
    return geecs

def set_only(tag, set_value):
    if normalize_ranges:
        value=set_value*(bella_config['control_variables'][tag]['range'][1]-bella_config['control_variables'][tag]['range'][0])+bella_config['control_variables'][tag]['range'][0]
        print(value)
    else:
        value=set_value
    #check that the set value is in the range 
    if value>bella_config['control_variables'][tag]['range'][0] and value<bella_config['control_variables'][tag]['range'][1]:
        
        UDP_IP = str(bella_config['control_variables'][tag]['ipaddress'])
        UDP_PORT = int(bella_config['control_variables'][tag]['port'])
        position = round(value,4)
        #MESSAGE = bytes("set"+str(bella_config['control_variables'][tag]['device_variable'])+">>" + str(position), 'ascii')
        MESSAGE = f"set{bella_config['control_variables'][tag]['device_variable']}>>{value:.6f}".encode('ascii')
        sock = socket.socket(socket.AF_INET, # Internet
                socket.SOCK_DGRAM) # UDP
        sock.sendto(MESSAGE, (UDP_IP, UDP_PORT))   
    else:
        print("set value of "+str(value)+"for "+str(tag)+" is not in the range: "+str(bella_config['control_variables'][tag]['range']))

def check_only(tag, set_value):
    if normalize_ranges:
        value=set_value*(bella_config['control_variables'][tag]['range'][1]-bella_config['control_variables'][tag]['range'][0])+bella_config['control_variables'][tag]['range'][0]
        print(value)
    else:
        value=set_value
    attempts=0
    while attempts<3:
        print('attempts loop')
        checkVal=get(tag)
        print("check value is: "+str(checkVal)+" and target value is: "+str(value))
        #tolerance=abs((float(checkVal)-float(value))/float(value))
        tolerance=0.005
        timeout=5
        newCheckVal='NaN';
        #loop to check value while device is moving. if value doesn't reach desired value, re-attempt to send the command
        while tolerance>0.01:
            print('tolerance loop')
            time.sleep(0.75)
            checkVal=get(tag)
            #tolerance=abs((float(checkVal)-float(value))/float(value)) #this doesn't work when set value is 0
            tolerance=0.005
            if newCheckVal==checkVal:
                print('failed to move device',tag)
                attempts+=1
                break
            newCheckVal=checkVal
            print("still moving, check value is: "+str(checkVal)+" and target value is: "+str(value))
        if tolerance<0.01:
            print('successfully moved device',tag)
            attempts=4


def set_and_check(tag, value):
    
    set_only(tag,value)
    check_only(tag,value)



def set1Norm(tag, norm_value):
    #check that the set value is in the range 
    value=norm_value*(bella_config['control_variables'][tag]['range'][1]-bella_config['control_variables'][tag]['range'][0])+bella_config['control_variables'][tag]['range'][0]
    print(value)
#     if value>bella_config['control_variables'][tag]['range'][0] and value<bella_config['control_variables'][tag]['range'][1]:
        
#         attempts=0
#         while attempts<3:
#             print('attempts loop')
#             UDP_IP = str(bella_config['control_variables'][tag]['ipaddress'])
#             UDP_PORT = int(bella_config['control_variables'][tag]['port'])
#             position = round(value,4)
#             #MESSAGE = bytes("set"+str(bella_config['control_variables'][tag]['device_variable'])+">>" + str(position), 'ascii')
#             MESSAGE = f"set{bella_config['control_variables'][tag]['device_variable']}>>{value:.4f}".encode('ascii')
#             sock = socket.socket(socket.AF_INET, # Internet
#                     socket.SOCK_DGRAM) # UDP
#             sock.sendto(MESSAGE, (UDP_IP, UDP_PORT))
#             time.sleep(0.75)
#             checkVal=get(tag)
#             print("check value is: "+str(checkVal)+" and target value is: "+str(value))
#             tolerance=abs((float(checkVal)-float(value))/float(value))
#             timeout=5
#             newCheckVal='NaN';
#             #loop to check value while device is moving. if value doesn't reach desired value, re-attempt to send the command
#             while tolerance>0.01:
#                 print('tolerance loop')
#                 time.sleep(0.75)
#                 checkVal=get(tag)
#                 tolerance=abs((float(checkVal)-float(value))/float(value))
#                 if newCheckVal==checkVal:
#                     print('failed to move device',tag)
#                     attempts+=1
#                     break
#                 newCheckVal=checkVal
#                 print("still moving, check value is: "+str(checkVal)+" and target value is: "+str(value))
#             if tolerance<0.01:
#                 print('successfully moved device',tag)
#                 attempts=4
#     else:
#         print("set value of "+str(value)+"for "+str(tag)+" is not in the range: "+str(bella_config['control_variables'][tag]['range']))

# %%
for cv_tag,cv_config in cv_tags.items():
    print(cv_config)
# Out:
# {'device_name': 'U_Hexapod', 'device_variable': 'ypos', 'range': [17.0, 19.0], 'ipaddress': '0.0.0.0', 'port': 9999, 'busy': 0, 'newDataFlag': 0, 'tcp_client': 'na', 'actual_value': 0.0, 'set': True, 'set_value': 0.0, 'proximal_lengthscale': 1.5, 'objective': False}
# {'device_name': 'U_Hexapod', 'device_variable': 'vangle', 'range': [-0.2, 0.2], 'ipaddress': '0.0.0.0', 'port': 9999, 'busy': 0, 'newDataFlag': 0, 'tcp_client': 'na', 'actual_value': 0.0, 'set': True, 'set_value': 0.0, 'proximal_lengthscale': 1.5, 'objective': False}
# {'device_name': 'U_Hexapod', 'device_variable': 'zpos', 'range': [-1.0, 1.0], 'ipaddress': '0.0.0.0', 'port': 9999, 'busy': 0, 'newDataFlag': 0, 'tcp_client': 'na', 'actual_value': 0.0, 'set': True, 'set_value': 0.0, 'proximal_lengthscale': 1.5, 'objective': False}
# {'device_name': 'U_Hexapod', 'device_variable': 'wangle', 'range': [-0.2, 0.2], 'ipaddress': '0.0.0.0', 'port': 9999, 'busy': 0, 'newDataFlag': 0, 'tcp_client': 'na', 'actual_value': 0.0, 'set': True, 'set_value': 0.0, 'proximal_lengthscale': 1.5, 'objective': False}
# {'device_name': 'U_HP_Daq', 'device_variable': 'AnalogOutput.Channel 1', 'range': [2, 3.0], 'ipaddress': '0.0.0.0', 'port': 9999, 'busy': 0, 'newDataFlag': 0, 'tcp_client': 'na', 'actual_value': 0.0, 'set': False, 'set_value': 0.0, 'proximal_lengthscale': 1.5, 'objective': False}
# {'device_name': 'U_1HzShiftedBox', 'device_variable': 'delay.Channel_C', 'range': [0.0006, 0.00071], 'ipaddress': '0.0.0.0', 'port': 9999, 'busy': 0, 'newDataFlag': 0, 'tcp_client': 'na', 'actual_value': 0.0, 'set': False, 'set_value': 0.0, 'proximal_lengthscale': 1.5, 'objective': False}
# {'device_name': 'U_CompAerotech', 'device_variable': 'Position.Axis1', 'range': [40000.0, 42000.0], 'ipaddress': '0.0.0.0', 'port': 9999, 'busy': 0, 'newDataFlag': 0, 'tcp_client': 'na', 'actual_value': 0.0, 'set': False, 'set_value': 0.0, 'proximal_lengthscale': 500.0, 'objective': False}
# {'device_name': 'UC_TC_Phosphor', 'device_variable': 'MeanCounts', 'ipaddress': '0.0.0.0', 'port': 9999, 'busy': 0, 'newDataFlag': 0, 'tcp_client': 'na', 'actual_value': 0.0, 'method': 'MAXIMIZE', 'objective': True, 'set': False}

# %% [markdown]
# ## get TCP info from database for variables, establish clients, initialize current values
# skip this part if running in simulation mode

# %%
#get TCP info from database
import mysql.connector
import socket
import struct
import time
import select

mydb = mysql.connector.connect(
host=bella_config['database']['ipaddress'],
user=bella_config['database']['user'],
password=bella_config['database']['password'])

selectors=["ipaddress","commport"]
selectorString=",".join(selectors)

mycursor = mydb.cursor()
db_name=bella_config['database']['name']

# for i in cv_tags:
#     #create a sql query command that looks in the 'device' table to find the IP address and port for a given device name
#     mycursor.execute("SELECT "+selectorString+" FROM "+db_name+".device where name="+'"' + bella_config['control_variables'][i]['device_name'] + '"'+";")
#     myresult = list(mycursor.fetchall()[0])
#     print(myresult)
#     bella_config['control_variables'][i]['ipaddress']=myresult[0]
#     bella_config['control_variables'][i]['port']=myresult[1]
#     bella_config['control_variables'][i]['tcp_client']=client_factory(myresult[0],myresult[1],bella_config['control_variables'][i]['device_variable'])
#     time.sleep(1)
#     get(i)
    
for cv_tag,cv_config in cv_tags.items():
    #create a sql query command that looks in the 'device' table to find the IP address and port for a given device name
    select_stmt="SELECT "+selectorString+" FROM "+db_name+".device where name="+'"' + cv_config['device_name'] + '"'+";"

    mycursor.execute(select_stmt)
    myresult = list(mycursor.fetchall()[0])
    print(myresult)
    cv_config['ipaddress']=myresult[0]
    cv_config['port']=myresult[1]
    cv_config['tcp_client']=client_factory(myresult[0],myresult[1],cv_config['device_variable'])
    time.sleep(1)
    get(cv_tag)
    
# for i in obj_tags:
#     #create a sql query command that looks in the 'device' table to find the IP address and port for a given device name
#     mycursor.execute("SELECT "+selectorString+" FROM "+db_name+".device where name="+'"' + bella_config['objective_variables'][i]['device_name'] + '"'+";")
#     myresult = list(mycursor.fetchall()[0])
#     print(myresult)
#     bella_config['objective_variables'][i]['ipaddress']=myresult[0]
#     bella_config['objective_variables'][i]['port']=myresult[1]
#     bella_config['objective_variables'][i]['tcp_client']=client_factory(myresult[0],myresult[1],bella_config['objective_variables'][i]['device_variable'])
#     get(i)
    

    
for cv_tag,cv_config in cv_tags.items():
    print(cv_config['actual_value'])
    
# for i in obj_tags:
#     print(bella_config['objective_variables'][i]['actual_value'])

# for i in cv_tags:
#     bella_config['control_variables'][i]['tcp_client'].close()
# Out:
# ['192.168.8.198', '65063']
# in the client factory for device:  ypos
# ['192.168.8.198', '65063']
# in the client factory for device:  vangle
# ['192.168.8.198', '65063']
# in the client factory for device:  zpos
# ['192.168.8.198', '65063']
# in the client factory for device:  wangle
# ['192.168.7.173', '65115']
# in the client factory for device:  AnalogOutput.Channel 1
# ['192.168.6.79', '64887']
# in the client factory for device:  delay.Channel_C
# ['192.168.6.73', '65119']
# in the client factory for device:  Position.Axis1
# ['192.168.8.195', '65005']
# in the client factory for device:  MeanCounts
# 18.000000
# -0.090000
# 0.000000
# 0.050000
# 0.000000
# 0.000712970000
# 40098.301250
# 3.637878

# %%
####Trying to test fast UDP response
# set_only("JetX",.3)
# ip='192.168.8.198'
# port=65159
# var='JetX'

# import time
# import socket

# for pings in range(10):
#     client_socket = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
#     client_socket.settimeout(1.0)
#     message = b'Wait'
#     addr = (ip, port)

#     start = time.time()
#     client_socket.sendto(message, addr)
#     try:
#         data, server = client_socket.recv(1)
#         end = time.time()
#         elapsed = end - start
#         print(f'{data} {pings} {elapsed}')
#     except socket.timeout:
#         print('REQUEST TIMED OUT')
# Out:
# REQUEST TIMED OUT
# REQUEST TIMED OUT
# REQUEST TIMED OUT
# REQUEST TIMED OUT
# REQUEST TIMED OUT
# REQUEST TIMED OUT
# REQUEST TIMED OUT
# REQUEST TIMED OUT
# REQUEST TIMED OUT
# REQUEST TIMED OUT

# %% [markdown]
# ## define a simulated objective function

# %%
def gaussian(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))

#simulate objective using actual values
# def simulate_objective1():
#     v1=gaussian(float(bella_config['control_variables']['JetX']['actual_value']),5.5,.5)+np.random.normal(0,.05,1)[0]
#     v2=gaussian(float(bella_config['control_variables']['JetY']['actual_value']),-7.0,.5)+np.random.normal(0,.05,1)[0]
#     v3=gaussian(float(bella_config['control_variables']['JetZ']['actual_value']),15.0,1)+np.random.normal(0,.05,1)[0]
#     v4=gaussian(float(bella_config['control_variables']['GratingSeparation']['actual_value']),43.1000,0.0500)+np.random.normal(0,.05,1)[0]
#     res=v1*v2*v4*v4
#     res=float("%.4f" % res)
#     return res



#simulate objective using set values. 
def simulate_objective2_norm(input_dict):
    v1=gaussian(float(input_dict['JetBlade']),0.5,.3)+np.random.normal(0,.05,1)[0]
    v2=gaussian(float(input_dict['LampTiming']),0.2,.5)+np.random.normal(0,.05,1)[0]
    v3=gaussian(float(input_dict['JetZ']),0.4,.1)+np.random.normal(0,.05,1)[0]
    v4=gaussian(float(input_dict['Pressure']),0.9,.25)+np.random.normal(0,.05,1)[0]
    
    v5=0.8*gaussian(float(input_dict['JetBlade']),0.5+.2,.3)+np.random.normal(0,.05,1)[0]
    v6=0.8*gaussian(float(input_dict['LampTiming']),0.2+.2,.5)+np.random.normal(0,.05,1)[0]
    v7=0.8*gaussian(float(input_dict['JetZ']),0.4+.2,.1)+np.random.normal(0,.05,1)[0]
    v8=0.8*gaussian(float(input_dict['Pressure']),0.9-.2,.25)+np.random.normal(0,.05,1)[0]
    res=v1*v2*v3*v4+v5*v6*v7*v8
    res=float("%.6f" % res)
    return res

# %%
outputs=obj_tags

def geecs_measurement(input_dict):
#
## Code below would be for batch send of commands, then check they were executed. But, that needs some work 
#     #Send all the set commands, without waiting for response
#     for i in list(input_dict.keys()):
#         set_val=float(input_dict[i])
#         print('set '+str(i)+' to '+str(set_val))
#         set_only(i,float(set_val))
   
#     #Check that the set commands have finished
#     for i in list(input_dict.keys()):
#         set_val=float(input_dict[i])
#         print('set '+str(i)+' to '+str(set_val))
#         check_only(i,float(set_val))

# # Code below is for set then check immediately. Serilazed commands. 
#     #Send all the set commands, without waiting for response
    for i in list(input_dict.keys()):
        set_val=float(input_dict[i])
        print('set '+str(i)+' to '+str(set_val))
        time.sleep(1.1)
        set_only(i,float(set_val))
        time.sleep(1.1)
        check_only(i,float(set_val))
   

# # use while loop below for simulating the objective function
#     outs=[]
#     counter=0
#     while counter<bella_config['optimization_parameters']['shots_per_step']:
#         for i in outputs:
#             val=simulate_objective2_norm(input_dict)
#             outs.append(val)
#         counter=counter+1

# #Use below for making actual maeasurements on beamline
    outs=[]
    counter=0
    while counter<bella_config['optimization_parameters']['shots_per_step']:
        for i in outputs:
            val=float(get_until_new(i))
            outs.append(val)
        counter=counter+1
        
    print(outs)

###############
## TO DO
###############
## Add some data processing on the resulting on the acquired data.
## for example, remove the extreme values, then maybe take a median
## also need to test with passing all acquired data points rather than some stat

    return {'f': np.median(outs)}

# %%
#close all tcp clients
# for cv_tage in cv_tags:
#     bella_config['control_variables'][i]['tcp_client'].close()
    
# for cv_tag, cv_config in cv_tags.items():
#     cv_config['tcp_client'].close()

geecs_measurement({"HexY":0.5,"HexZ":0.5,"HexV":0.5,"HexW":0.5})
# Out:
# set HexY to 0.5
# 18.0
# 18.0
# attempts loop
# check value is: 17.920700 and target value is: 18.0
# successfully moved device HexY
# set HexZ to 0.5
# 0.0
# 0.0
# attempts loop
# check value is: -0.200000 and target value is: 0.0
# successfully moved device HexZ
# set HexV to 0.5
# 0.0
# 0.0
# attempts loop
# check value is: 0.000000 and target value is: 0.0
# successfully moved device HexV
# set HexW to 0.5
# 0.0
# 0.0
# attempts loop
# check value is: 0.000000 and target value is: 0.0
# successfully moved device HexW
# [4.149667, 4.087978, 4.092245, 4.110789, 4.002878, 4.086689, 4.087789, 4.152844, 1.949767, 4.028633, 4.064845, 4.089978, 4.097211, 1.580689, 3.987345, 4.0828, 4.132589, 4.0736, 1.727422, 4.040767]
# {'f': 4.084744499999999}

# %% [markdown]
# ## Create Xopt objects
# Create the evaluator to evaluate our test function and create a generator that uses
# the Expected Improvement acqusition function to perform Bayesian Optimization.

# %%
from xopt.evaluator import Evaluator
from xopt.generators.bayesian import ExpectedImprovementGenerator
from xopt import Xopt

X = Xopt(config=yaml_output)
X
# Out:
#             Xopt
# ________________________________
# Version: 1.2.1
# Data size: 0
# Config as YAML:
# xopt: {asynch: false, strict: false, dump_file: dump.yaml, max_evaluations: null}
# generator:
#   name: upper_confidence_bound
#   optim: {num_restarts: 1, raw_samples: 20, sequential: true, use_nearby_initial_points: true,
#     max_travel_distances: null}
#   acq:
#     proximal_lengthscales: [0.75, 3.75, 0.75, 3.75]
#     use_transformed_proximal_weights: true
#     monte_carlo_samples: 128
#     beta: 2.0
#   model:
#     function: xopt.generators.bayesian.models.standard.create_standard_model
#     kwargs: {use_conservative_prior_lengthscale: false, use_conservative_prior_mean: false,
#       use_low_noise_prior: false}
#   n_initial: 5
# evaluator:
#   function: __main__.geecs_measurement
#   max_workers: 1
#   function_kwargs: {}
#   vectorized: false
# vocs:
#   variables:
#     HexY: [0.0, 1.0]
#     HexV: [0.0, 1.0]
#     HexZ: [0.0, 1.0]
#     HexW: [0.0, 1.0]
#   constraints: {}
#   objectives: {f: MAXIMIZE}
#   constants: {}
#   linked_variables: {}

# %% [markdown]
# ## Generate and evaluate initial points
# To begin optimization, we must generate some random initial data points. The first call
# to `X.step()` will generate and evaluate a number of randomly points specified by the
#  generator. Note that if we add data to xopt before calling `X.step()` by assigning
#  the data to `X.data`, calls to `X.step()` will ignore the random generation and
#  proceed to generating points via Bayesian optimization.

# %%
X.evaluate_data(pd.DataFrame({"HexY":[0.5,0.4],"HexZ":[0.4,0.5],"HexV":[0.4,0.5],"HexW":[0.4,0.5]}))
#X.evaluate_data(pd.DataFrame({"JetX":[4.1, 5.4],"JetY":[-6.1, -7.1],"JetZ":[10.1, 14.35],'GratingSeparation':[40500.1, 41100.8]}))
# Out:
# set HexY to 0.5
# 18.0
# 18.0
# attempts loop
# check value is: 18.000000 and target value is: 18.0
# successfully moved device HexY
# set HexZ to 0.4
# -0.19999999999999996
# -0.19999999999999996
# attempts loop
# check value is: -0.200000 and target value is: -0.19999999999999996
# successfully moved device HexZ
# set HexV to 0.4
# -0.03999999999999998
# -0.03999999999999998
# attempts loop
# check value is: -0.040000 and target value is: -0.03999999999999998
# successfully moved device HexV
# set HexW to 0.4
# -0.03999999999999998
# -0.03999999999999998
# attempts loop
# check value is: -0.040000 and target value is: -0.03999999999999998
# successfully moved device HexW
# [3.891956, 3.741578, 3.889211, 3.913111, 3.960456, 3.860844, 3.927022, 3.917411, 3.848256, 3.844889, 3.860911, 3.882478, 3.844089, 3.9152, 3.862733, 3.849911, 3.938555, 3.938555, 3.894633, 3.796744]
# set HexY to 0.4
# 17.8
# 17.8
# attempts loop
# check value is: 18.000000 and target value is: 17.8
# successfully moved device HexY
# set HexZ to 0.5
# 0.0
# 0.0
# attempts loop
# check value is: 0.000000 and target value is: 0.0
# successfully moved device HexZ
# set HexV to 0.5
# 0.0
# 0.0
# attempts loop
# check value is: 0.000000 and target value is: 0.0
# successfully moved device HexV
# set HexW to 0.5
# 0.0
# 0.0
# attempts loop
# check value is: -0.040000 and target value is: 0.0
# successfully moved device HexW
# [4.2145, 4.187167, 4.177644, 4.160345, 4.244378, 4.226033, 4.197155, 4.134111, 4.267766, 2.220345, 4.164178, 4.2014, 4.150511, 4.098078, 4.182445, 4.203233, 4.185678, 4.179444, 4.235667, 4.174478]
#    HexY  HexZ  HexV  HexW         f  xopt_runtime  xopt_error
# 1   0.5   0.4   0.4   0.4  3.885845     12.869196       False
# 2   0.4   0.5   0.5   0.5  4.184062     14.086437       False

# %%
# # print initial number of points to be generated
# print(X.generator.options.n_initial)

# # call X.step() to generate + evaluate initial points
# X.step()

# # inspect the gathered data
# X.data

# %% [markdown]
# ## Do bayesian optimization steps
# To perform optimization we simply call `X.step()` in a loop. This allows us to do
# intermediate tasks in between optimization steps, such as examining the model and
# acquisition function at each step (as we demonstrate here).

# %%
import torch
import matplotlib.pyplot as plt
n_steps = 200

# test points for plotting
#test_x = torch.linspace(*X.vocs.bounds.flatten(),50).double()

for i in range(n_steps):
    print('step'+str(i))
    t0=time.monotonic()
    X.step()
    t1=time.monotonic()
    print('step'+str(i)+".1: "+str(t1-t0))
    # get the Gaussian process model from the generator
    model = X.generator.model
    t2=time.monotonic()
    print('step'+str(i)+".2: "+str(t2-t0))
    # get acquisition function from generator
    acq = X.generator.get_acquisition(model)
    t3=time.monotonic()
    print('step'+str(i)+".3: "+str(t3-t0))
    # calculate model posterior and acquisition function at each test point
    # NOTE: need to add a dimension to the input tensor for evaluating the
    # posterior and another for the acquisition function, see
    # https://botorch.org/docs/batching for details
    # NOTE: we use the `torch.no_grad()` environment to speed up computation by
    # skipping calculations for backpropagation
#     with torch.no_grad():
#         posterior = model.posterior(test_x.unsqueeze(1))
#         acq_val = acq(test_x.reshape(-1,1,1))
#     # get mean function and confidence regions
#     mean = posterior.mean
#     l,u = posterior.mvn.confidence_region()
#     # plot model and acquisition function
#     fig,ax = plt.subplots(2,1,sharex="all")
#     # plot model posterior
#     ax[0].plot(test_x, mean, label="Posterior mean")
#     ax[0].fill_between(test_x, l, u,alpha=0.25, label="Posterior confidence region")
#     # add data to model plot
#     ax[0].plot(X.data["x"],X.data["f"],"C1o", label="Training data")
#     # plot true function
#     true_f = sin_function({"x": test_x})["f"]
#     ax[0].plot(test_x, true_f,'--', label="Ground truth")
#     # add legend
#     ax[0].legend()
#     # plot acquisition function
#     ax[1].plot(test_x, acq_val.flatten())
#     ax[0].set_ylabel("f")
#     ax[1].set_ylabel(r"$\alpha(x)$")
#     ax[1].set_xlabel("x")
# Out:
# step0
# set HexV to 0.5075530964713189
# 0.0030212385885275417
# 0.0030212385885275417
# attempts loop
# check value is: 0.003000 and target value is: 0.0030212385885275417
# successfully moved device HexV
# set HexW to 0.7680468889511958
# 0.10721875558047833
# 0.10721875558047833
# attempts loop
# check value is: 0.082500 and target value is: 0.10721875558047833
# successfully moved device HexW
# set HexY to 0.3924470727491418
# 17.784894145498285
# 17.784894145498285
# attempts loop
# check value is: 18.000000 and target value is: 17.784894145498285
# successfully moved device HexY
# set HexZ to 0.7680479667312656
# 0.5360959334625313
# 0.5360959334625313
# attempts loop
# check value is: 0.000000 and target value is: 0.5360959334625313
# successfully moved device HexZ
# [3.144644, 3.099233, 2.2759, 2.910522, 2.910522, 2.952967, 1.806367, 1.806367, 2.126856, 2.993578, 2.942656, 2.515233, 2.963689, 2.974355, 2.974355, 2.886033, 2.922045, 2.818089, 2.9253, 2.833111]
# step0.1: 14.337169582999877
# step0.2: 14.337216707999914
# step0.3: 14.338543374999972
# step1
# set HexV to 0.5350286603928681
# 0.014011464157147241
# 0.014011464157147241
# attempts loop
# check value is: 0.014000 and target value is: 0.014011464157147241
# successfully moved device HexV
# set HexW to 0.6445372896529226
# 0.05781491586116905
# 0.05781491586116905
# attempts loop
# check value is: 0.057800 and target value is: 0.05781491586116905
# successfully moved device HexW
# set HexY to 0.3649715069094019
# 17.729943013818804
# 17.729943013818804
# attempts loop
# check value is: 17.729900 and target value is: 17.729943013818804
# successfully moved device HexY
# set HexZ to 0.21338764676188265
# -0.5732247064762347
# -0.5732247064762347
# attempts loop
# check value is: 0.269100 and target value is: -0.5732247064762347
# successfully moved device HexZ
# [3.638756, 3.680022, 3.684644, 3.667556, 3.555911, 3.555911, 2.126611, 2.937789, 2.862389, 2.802556, 2.863989, 2.830156, 2.898889, 2.898889, 2.882867, 2.818611, 2.910978, 2.885322, 2.8338, 2.785544]
# step1.1: 13.922613708999961
# step1.2: 13.922653791999892
# step1.3: 13.923891208999976
# step2
# set HexV to 0.5426637309623655
# 0.0170654923849462
# 0.0170654923849462
# attempts loop
# check value is: 0.017100 and target value is: 0.0170654923849462
# successfully moved device HexV
# set HexW to 0.27442174303605715
# -0.09023130278557714
# -0.09023130278557714
# attempts loop
# check value is: -0.090200 and target value is: -0.09023130278557714
# successfully moved device HexW
# set HexY to 0.35733637722888517
# 17.71467275445777
# 17.71467275445777
# attempts loop
# check value is: 17.729900 and target value is: 17.71467275445777
# successfully moved device HexY
# set HexZ to 0.5733504860759174
# 0.14670097215183486
# 0.14670097215183486
# attempts loop
# check value is: -0.301700 and target value is: 0.14670097215183486
# successfully moved device HexZ
# [4.314611, 4.505956, 1.5608, 4.727089, 4.740989, 4.740989, 4.715311, 4.775733, 4.704889, 4.725044, 4.752656, 2.814278, 4.726089, 4.742878, 4.748189, 4.691545, 4.706767, 4.669, 4.657467, 4.657467]
# step2.1: 13.852061667000044
# step2.2: 13.852100834000112
# step2.3: 13.853268709000076
# step3
# set HexV to 0.5402964812936245
# 0.016118592517449792
# 0.016118592517449792
# attempts loop
# check value is: 0.016100 and target value is: 0.016118592517449792
# successfully moved device HexV
# set HexW to 0.05122503545987321
# -0.1795099858160507
# -0.1795099858160507
# attempts loop
# check value is: -0.090200 and target value is: -0.1795099858160507
# successfully moved device HexW
# set HexY to 0.35970375324539705
# 17.719407506490793
# 17.719407506490793
# attempts loop
# check value is: 17.729900 and target value is: 17.719407506490793
# successfully moved device HexY
# set HexZ to 0.6947605223103335
# 0.38952104462066695
# 0.38952104462066695
# attempts loop
# check value is: 0.389500 and target value is: 0.38952104462066695
# successfully moved device HexZ
# [4.856144, 4.759889, 2.664489, 4.888622, 4.776489, 4.865067, 4.887789, 4.893456, 4.729244, 4.796067, 4.782011, 4.905844, 4.8476, 4.832445, 4.876144, 4.7688, 4.783489, 4.876611, 4.886611, 4.886611]
# step3.1: 14.120850250000103
# step3.2: 14.1209093330001
# step3.3: 14.122426541000095
# step4
# set HexV to 0.5651591060248314
# 0.026063642409932586
# 0.026063642409932586
# attempts loop
# check value is: 0.026100 and target value is: 0.026063642409932586
# successfully moved device HexV
# set HexW to 0.0
# -0.2
# set value of -0.2for HexW is not in the range: [-0.2, 0.2]
# -0.2
# attempts loop
# check value is: -0.179500 and target value is: -0.2
# successfully moved device HexW
# set HexY to 0.3348411776689454
# 17.66968235533789
# 17.66968235533789
# attempts loop
# check value is: 17.669700 and target value is: 17.66968235533789
# successfully moved device HexY
# set HexZ to 0.5056771021238926
# 0.011354204247785216
# 0.011354204247785216
# attempts loop
# check value is: 0.123000 and target value is: 0.011354204247785216
# successfully moved device HexZ
# [5.061289, 3.845267, 5.0613, 5.0452, 5.068444, 5.072233, 5.069889, 4.932533, 5.106433, 5.105111, 4.991766, 5.087044, 5.051811, 5.072444, 4.983933, 5.074122, 1.834889, 5.090156, 5.0128, 5.034456]
# step4.1: 15.706705458999977
# step4.2: 15.706735125000023
# step4.3: 15.707804291999992
# step5
# set HexV to 0.5391923656125556
# 0.015676946245022222
# 0.015676946245022222
# attempts loop
# check value is: 0.015700 and target value is: 0.015676946245022222
# successfully moved device HexV
# set HexW to 0.0
# -0.2
# set value of -0.2for HexW is not in the range: [-0.2, 0.2]
# -0.2
# attempts loop
# check value is: -0.179500 and target value is: -0.2
# successfully moved device HexW
# set HexY to 0.19785999626435036
# 17.3957199925287
# 17.3957199925287
# attempts loop
# check value is: 17.396900 and target value is: 17.3957199925287
# successfully moved device HexY
# set HexZ to 0.5768444130913511
# 0.1536888261827023
# 0.1536888261827023
# attempts loop
# check value is: 0.119600 and target value is: 0.1536888261827023
# successfully moved device HexZ
# [4.953778, 4.905066, 4.889789, 4.9018, 4.903489, 4.874378, 4.818634, 4.929789, 4.916044, 4.9032, 5.025656, 4.851267, 4.858211, 4.850056, 4.878978, 4.872689, 4.853922, 4.950411, 4.863322, 4.888222]
# step5.1: 14.351966041000196
# step5.2: 14.352016291000155
# step5.3: 14.353679791000104
# step6
# set HexV to 0.6925064678003513
# 0.07700258712014052
# 0.07700258712014052
# attempts loop
# check value is: 0.077000 and target value is: 0.07700258712014052
# successfully moved device HexV
# set HexW to 0.0
# -0.2
# set value of -0.2for HexW is not in the range: [-0.2, 0.2]
# -0.2
# attempts loop
# check value is: -0.179500 and target value is: -0.2
# successfully moved device HexW
# set HexY to 0.2684160665502808
# 17.53683213310056
# 17.53683213310056
# attempts loop
# check value is: 17.536800 and target value is: 17.53683213310056
# successfully moved device HexY
# set HexZ to 0.5771936433462216
# 0.15438728669244317
# 0.15438728669244317
# attempts loop
# check value is: 0.154400 and target value is: 0.15438728669244317
# successfully moved device HexZ
# [4.912344, 4.886833, 4.915978, 4.897378, 4.948522, 4.9326, 4.951611, 5.011344, 2.265322, 4.965578, 4.794544, 4.816245, 4.859433, 4.937622, 4.916667, 4.916667, 1.733944, 4.898567, 4.891033, 4.891033]
# step6.1: 14.134359791999941
# step6.2: 14.134382749999986
# step6.3: 14.135013500000014
# step7
# set HexV to 0.691678943352641
# 0.0766715773410564
# 0.0766715773410564
# attempts loop
# check value is: 0.076700 and target value is: 0.0766715773410564
# successfully moved device HexV
# set HexW to 0.0
# -0.2
# set value of -0.2for HexW is not in the range: [-0.2, 0.2]
# -0.2
# attempts loop
# check value is: -0.179500 and target value is: -0.2
# successfully moved device HexW
# set HexY to 0.2711428420715014
# 17.542285684143003
# 17.542285684143003
# attempts loop
# check value is: 17.542300 and target value is: 17.542285684143003
# successfully moved device HexY
# set HexZ to 0.40883309864942924
# -0.18233380270114152
# -0.18233380270114152
# attempts loop
# check value is: -0.108900 and target value is: -0.18233380270114152
# successfully moved device HexZ
# [1.502578, 4.852255, 4.8433, 4.881489, 4.805778, 4.780355, 4.913333, 4.813722, 4.816611, 4.812156, 4.805978, 4.884666, 4.743356, 4.816811, 4.855367, 4.883744, 4.884655, 2.994422, 4.866511, 4.820478]
# step7.1: 14.823440542000071
# step7.2: 14.82346941700007
# step7.3: 14.824207000000115
# step8
# set HexV to 0.6799724394692799
# 0.07198897578771196
# 0.07198897578771196
# attempts loop
# check value is: 0.072000 and target value is: 0.07198897578771196
# successfully moved device HexV
# set HexW to 0.0
# -0.2
# set value of -0.2for HexW is not in the range: [-0.2, 0.2]
# -0.2
# attempts loop
# check value is: -0.179500 and target value is: -0.2
# successfully moved device HexW
# set HexY to 0.4091181726326932
# 17.818236345265387
# 17.818236345265387
# attempts loop
# check value is: 17.816900 and target value is: 17.818236345265387
# successfully moved device HexY
# set HexZ to 0.529951561459088
# 0.0599031229181759
# 0.0599031229181759
# attempts loop
# check value is: 0.059900 and target value is: 0.0599031229181759
# successfully moved device HexZ
# [4.933011, 4.9146, 4.951578, 4.951578, 4.902867, 4.961267, 4.424011, 4.938211, 4.927578, 4.969711, 4.940644, 5.043678, 4.956533, 4.922778, 4.9777, 4.990789, 4.987467, 4.963267, 5.032367, 4.972456]
# step8.1: 15.128043250000019
# step8.2: 15.128088250000019
# step8.3: 15.128624000000173
# step9
# set HexV to 0.6325427478448973
# 0.053017099137958934
# 0.053017099137958934
# attempts loop
# check value is: 0.053000 and target value is: 0.053017099137958934
# successfully moved device HexV
# set HexW to 0.0906703978782404
# -0.16373184084870385
# -0.16373184084870385
# attempts loop
# check value is: -0.163700 and target value is: -0.16373184084870385
# successfully moved device HexW
# set HexY to 0.37088224678934817
# 17.741764493578696
# 17.741764493578696
# attempts loop
# check value is: 17.741800 and target value is: 17.741764493578696
# successfully moved device HexY
# set HexZ to 0.5239464489322421
# 0.04789289786448414
# 0.04789289786448414
# attempts loop
# check value is: 0.047900 and target value is: 0.04789289786448414
# successfully moved device HexZ
# [1.3492, 5.005434, 5.033233, 5.043833, 5.032845, 5.051189, 5.096145, 4.974122, 5.053256, 5.037389, 5.100678, 5.133911, 1.752, 5.094656, 4.9769, 5.088233, 5.099578, 5.021878, 4.985133, 5.008033]
# step9.1: 14.691257124999993
# step9.2: 14.69128595899997
# step9.3: 14.692081500000086
# step10
# set HexV to 0.5629226172116125
# 0.025169046884644997
# 0.025169046884644997
# attempts loop
# check value is: 0.025200 and target value is: 0.025169046884644997
# successfully moved device HexV
# set HexW to 0.0
# -0.2
# set value of -0.2for HexW is not in the range: [-0.2, 0.2]
# -0.2
# attempts loop
# check value is: -0.163700 and target value is: -0.2
# successfully moved device HexW
# set HexY to 0.3903824159891914
# 17.780764831978384
# 17.780764831978384
# attempts loop
# check value is: 17.780800 and target value is: 17.780764831978384
# successfully moved device HexY
# set HexZ to 0.5759886546168522
# 0.15197730923370445
# 0.15197730923370445
# attempts loop
# check value is: 0.145900 and target value is: 0.15197730923370445
# successfully moved device HexZ
# [4.964722, 4.915133, 4.995611, 2.189633, 4.981266, 5.002411, 5.023445, 5.087245, 4.994444, 5.016833, 5.034433, 5.060289, 2.122467, 4.999434, 2.040411, 5.048789, 4.992778, 5.020322, 4.994267, 4.980744]
# step10.1: 15.156926458000044
# step10.2: 15.156953708000174
# step10.3: 15.15764012500017
# step11
# set HexV to 0.544723195283236
# 0.017889278113294382
# 0.017889278113294382
# attempts loop
# check value is: 0.017900 and target value is: 0.017889278113294382
# successfully moved device HexV
# set HexW to 0.037537263410893335
# -0.18498509463564267
# -0.18498509463564267
# attempts loop
# check value is: -0.185000 and target value is: -0.18498509463564267
# successfully moved device HexW
# set HexY to 0.39186792042569524
# 17.783735840851392
# 17.783735840851392
# attempts loop
# check value is: 17.783700 and target value is: 17.783735840851392
# successfully moved device HexY
# set HexZ to 0.4726801929639186
# -0.05463961407216278
# -0.05463961407216278
# attempts loop
# check value is: -0.054600 and target value is: -0.05463961407216278
# successfully moved device HexZ
# [4.936955, 5.011867, 4.9168, 4.933411, 4.995111, 4.926689, 4.972322, 4.950022, 4.913922, 4.918478, 4.941889, 4.929456, 4.972778, 5.009689, 4.942622, 4.953022, 4.943444, 4.971478, 4.993933, 4.974411]
# step11.1: 14.713096333000067
# step11.2: 14.713130667000087
# step11.3: 14.713964708000049
# step12
# set HexV to 0.5553009900660307
# 0.022120396026412303
# 0.022120396026412303
# attempts loop
# check value is: 0.022100 and target value is: 0.022120396026412303
# successfully moved device HexV
# set HexW to 0.062185469904793574
# -0.17512581203808258
# -0.17512581203808258
# attempts loop
# check value is: -0.175100 and target value is: -0.17512581203808258
# successfully moved device HexW
# set HexY to 0.3306159420341767
# 17.661231884068354
# 17.661231884068354
# attempts loop
# check value is: 17.661200 and target value is: 17.661231884068354
# successfully moved device HexY
# set HexZ to 0.5367296799829027
# 0.07345935996580533
# 0.07345935996580533
# attempts loop
# check value is: 0.073500 and target value is: 0.07345935996580533
# successfully moved device HexZ
# [5.026744, 5.113567, 4.666689, 5.059311, 5.060911, 5.088356, 5.087022, 5.043766, 5.017367, 5.1313, 5.020867, 5.119855, 5.138033, 5.105489, 4.990022, 5.140856, 5.113133, 5.113133, 5.0142, 5.028411]
# step12.1: 14.266967540999985
# step12.2: 14.266993040999978
# step12.3: 14.267583040999853
# step13
# set HexV to 0.5679021646433394
# 0.027160865857335764
# 0.027160865857335764
# attempts loop
# check value is: 0.027200 and target value is: 0.027160865857335764
# successfully moved device HexV
# set HexW to 0.07399828280734609
# -0.17040068687706156
# -0.17040068687706156
# attempts loop
# check value is: -0.170400 and target value is: -0.17040068687706156
# successfully moved device HexW
# set HexY to 0.2958534840490841
# 17.59170696809817
# 17.59170696809817
# attempts loop
# check value is: 17.591700 and target value is: 17.59170696809817
# successfully moved device HexY
# set HexZ to 0.4994095059743779
# -0.001180988051244225
# -0.001180988051244225
# attempts loop
# check value is: -0.001200 and target value is: -0.001180988051244225
# successfully moved device HexZ
# [4.980145, 5.010322, 4.9849, 5.053222, 4.915645, 5.029811, 5.012556, 5.045933, 5.010167, 5.122244, 5.043766, 5.073767, 5.079578, 5.003289, 2.753456, 5.047322, 5.097044, 5.066811, 4.937955, 4.998611]
# step13.1: 15.80888737500004
# step13.2: 15.815970707999895
# step13.3: 15.817595165999819
# step14
# set HexV to 0.5640333119977349
# 0.02561332479909395
# 0.02561332479909395
# attempts loop
# check value is: 0.025600 and target value is: 0.02561332479909395
# successfully moved device HexV
# set HexW to 0.019411029570017255
# -0.1922355881719931
# -0.1922355881719931
# attempts loop
# check value is: -0.192200 and target value is: -0.1922355881719931
# successfully moved device HexW
# set HexY to 0.31147814059925566
# 17.622956281198512
# 17.622956281198512
# attempts loop
# check value is: 17.623000 and target value is: 17.622956281198512
# successfully moved device HexY
# set HexZ to 0.5557503648131664
# 0.11150072962633284
# 0.11150072962633284
# attempts loop
# check value is: 0.111500 and target value is: 0.11150072962633284
# successfully moved device HexZ
# [3.264622, 5.101, 5.0151, 5.082133, 5.1868, 5.117422, 5.180411, 5.0375, 5.120333, 5.055989, 5.1069, 5.052878, 5.058011, 5.059667, 5.095489, 5.077711, 5.053433, 5.132022, 5.137189, 5.078811]
# step14.1: 14.348118916000203
# step14.2: 14.348144791000095
# step14.3: 14.348647791000076
# step15
# set HexV to 0.5241105206311393
# 0.00964420825245571
# 0.00964420825245571
# attempts loop
# check value is: 0.025600 and target value is: 0.00964420825245571
# successfully moved device HexV
# set HexW to 0.0
# -0.2
# set value of -0.2for HexW is not in the range: [-0.2, 0.2]
# -0.2
# attempts loop
# check value is: -0.192200 and target value is: -0.2
# successfully moved device HexW
# set HexY to 0.31266060622723446
# 17.62532121245447
# 17.62532121245447
# attempts loop
# check value is: 17.625300 and target value is: 17.62532121245447
# successfully moved device HexY
# set HexZ to 0.5500537487559076
# 0.10010749751181525
# 0.10010749751181525
# attempts loop
# check value is: 0.100100 and target value is: 0.10010749751181525
# successfully moved device HexZ
# [5.046389, 5.026889, 5.158744, 5.105589, 5.028122, 5.012256, 5.065455, 5.065455, 5.0885, 5.038911, 5.078967, 5.156411, 5.019389, 5.126522, 4.999278, 5.0112, 5.108533, 5.0735, 5.114756, 5.131267]
# step15.1: 14.610954582999966
# step15.2: 14.610976499999879
# step15.3: 14.611472332999938
# step16
# set HexV to 0.5350174907078973
# 0.014006996283158907
# 0.014006996283158907
# attempts loop
# check value is: 0.014000 and target value is: 0.014006996283158907
# successfully moved device HexV
# set HexW to 0.040307293776822115
# -0.18387708248927118
# -0.18387708248927118
# attempts loop
# check value is: -0.183900 and target value is: -0.18387708248927118
# successfully moved device HexW
# set HexY to 0.317703607837271
# 17.63540721567454
# 17.63540721567454
# attempts loop
# check value is: 17.635400 and target value is: 17.63540721567454
# successfully moved device HexY
# set HexZ to 0.5624836437658401
# 0.1249672875316803
# 0.1249672875316803
# attempts loop
# check value is: 0.125000 and target value is: 0.1249672875316803
# successfully moved device HexZ
# [5.120422, 5.072567, 5.041333, 5.091633, 5.056478, 5.097411, 5.106622, 5.022022, 5.033467, 5.096045, 5.035722, 1.362478, 5.153022, 5.106566, 5.058856, 5.088489, 1.977289, 5.150845, 5.081211, 5.039522]
# step16.1: 14.134772416000033
# step16.2: 14.134793749999972
# step16.3: 14.135292166
# step17
# set HexV to 0.5556832934046232
# 0.022273317361849287
# 0.022273317361849287
# attempts loop
# check value is: 0.022300 and target value is: 0.022273317361849287
# successfully moved device HexV
# set HexW to 0.028934382151102125
# -0.18842624713955916
# -0.18842624713955916
# attempts loop
# check value is: -0.188400 and target value is: -0.18842624713955916
# successfully moved device HexW
# set HexY to 0.3238203465929617
# 17.647640693185924
# 17.647640693185924
# attempts loop
# check value is: 17.647600 and target value is: 17.647640693185924
# successfully moved device HexY
# set HexZ to 0.5430126827806283
# 0.08602536556125662
# 0.08602536556125662
# attempts loop
# check value is: 0.086000 and target value is: 0.08602536556125662
# successfully moved device HexZ
# [5.067945, 5.064667, 5.054533, 5.090722, 5.118211, 5.039333, 5.093833, 4.994433, 5.061345, 5.080411, 5.060189, 5.138844, 4.985067, 5.047645, 5.0176, 5.029622, 5.153611, 5.020611, 5.018278, 5.031078]
# step17.1: 14.382068000000118
# step17.2: 14.382091040999967
# step17.3: 14.382706625000083
# step18
# set HexV to 0.5690567538263245
# 0.027622701530529786
# 0.027622701530529786
# attempts loop
# check value is: 0.027600 and target value is: 0.027622701530529786
# successfully moved device HexV
# set HexW to 0.03139731374766889
# -0.18744107450093245
# -0.18744107450093245
# attempts loop
# check value is: -0.187400 and target value is: -0.18744107450093245
# successfully moved device HexW
# set HexY to 0.3249499160135076
# 17.649899832027014
# 17.649899832027014
# attempts loop
# check value is: 17.649900 and target value is: 17.649899832027014
# successfully moved device HexY
# set HexZ to 0.5470107496142667
# 0.09402149922853331
# 0.09402149922853331
# attempts loop
# check value is: 0.094000 and target value is: 0.09402149922853331
# successfully moved device HexZ
# [5.094234, 5.002356, 5.053855, 5.088622, 5.089366, 5.049867, 5.048889, 5.079, 5.0895, 5.051744, 5.030411, 5.0463, 5.075056, 5.067167, 5.067167, 5.110344, 5.0925, 5.055955, 5.129556, 5.068811]
# step18.1: 14.914564250000012
# step18.2: 14.914594707999868
# step18.3: 14.915124540999841
# step19
# set HexV to 0.5742819784039328
# 0.02971279136157312
# 0.02971279136157312
# attempts loop
# check value is: 0.029700 and target value is: 0.02971279136157312
# successfully moved device HexV
# set HexW to 0.02765991612458554
# -0.1889360335501658
# -0.1889360335501658
# attempts loop
# check value is: -0.188900 and target value is: -0.1889360335501658
# successfully moved device HexW
# set HexY to 0.32613099555642283
# 17.652261991112844
# 17.652261991112844
# attempts loop
# check value is: 17.652300 and target value is: 17.652261991112844
# successfully moved device HexY
# set HexZ to 0.5391270250849433
# 0.07825405016988651
# 0.07825405016988651
# attempts loop
# check value is: 0.078300 and target value is: 0.07825405016988651
# successfully moved device HexZ
# [1.453411, 2.920067, 5.0809, 5.056056, 5.017334, 5.081478, 5.0227, 5.064889, 5.084667, 5.120433, 5.057989, 5.027411, 5.069478, 5.130533, 5.047567, 5.089, 5.028833, 5.080756, 5.131567, 1.293478]
# step19.1: 15.141134416999876
# step19.2: 15.141160124999942
# step19.3: 15.14168037499985
# step20
# set HexV to 0.5688825435084129
# 0.027553017403365188
# 0.027553017403365188
# attempts loop
# check value is: 0.027600 and target value is: 0.027553017403365188
# successfully moved device HexV
# set HexW to 0.05234995132439335
# -0.17906001947024267
# -0.17906001947024267
# attempts loop
# check value is: -0.179100 and target value is: -0.17906001947024267
# successfully moved device HexW
# set HexY to 0.3238821087635193
# 17.64776421752704
# 17.64776421752704
# attempts loop
# check value is: 17.647800 and target value is: 17.64776421752704
# successfully moved device HexY
# set HexZ to 0.5628061338320335
# 0.12561226766406697
# 0.12561226766406697
# attempts loop
# check value is: 0.125600 and target value is: 0.12561226766406697
# successfully moved device HexZ
# [5.108122, 5.048078, 5.055478, 5.088589, 5.063089, 5.0142, 5.095756, 5.126989, 5.0827, 5.0827, 5.092467, 5.024633, 5.053089, 5.139011, 5.114456, 1.637233, 5.036189, 5.070034, 5.132611, 5.066011]
# step20.1: 15.891015333000041
# step20.2: 15.891045124999891
# step20.3: 15.891661999999997
# step21
# set HexV to 0.5640270520647694
# 0.025610820825907765
# 0.025610820825907765
# attempts loop
# check value is: 0.025600 and target value is: 0.025610820825907765
# successfully moved device HexV
# set HexW to 0.059876843168384396
# -0.17604926273264626
# -0.17604926273264626
# attempts loop
# check value is: -0.176000 and target value is: -0.17604926273264626
# successfully moved device HexW
# set HexY to 0.3205680040973578
# 17.641136008194717
# 17.641136008194717
# attempts loop
# check value is: 17.641100 and target value is: 17.641136008194717
# successfully moved device HexY
# set HexZ to 0.568981004730052
# 0.13796200946010395
# 0.13796200946010395
# attempts loop
# check value is: 0.138000 and target value is: 0.13796200946010395
# successfully moved device HexZ
# [5.043867, 5.011678, 4.970733, 5.073022, 5.073433, 5.073433, 5.048555, 5.088233, 5.085411, 5.056433, 5.102622, 5.024467, 5.098256, 5.028822, 3.301733, 5.098055, 5.043889, 5.064478, 5.036422, 4.331178]
# step21.1: 15.513093042000037
# step21.2: 15.51311729200006
# step21.3: 15.513627125000085
# step22
# set HexV to 0.548395627195782
# 0.019358250878312833
# 0.019358250878312833
# attempts loop
# check value is: 0.019400 and target value is: 0.019358250878312833
# successfully moved device HexV
# set HexW to 0.0
# -0.2
# set value of -0.2for HexW is not in the range: [-0.2, 0.2]
# -0.2
# attempts loop
# check value is: -0.176000 and target value is: -0.2
# successfully moved device HexW
# set HexY to 0.3177194760461851
# 17.635438952092372
# 17.635438952092372
# attempts loop
# check value is: 17.635400 and target value is: 17.635438952092372
# successfully moved device HexY
# set HexZ to 0.5686390678811937
# 0.13727813576238734
# 0.13727813576238734
# attempts loop
# check value is: 0.137300 and target value is: 0.13727813576238734
# successfully moved device HexZ
# [5.125633, 5.069978, 5.122066, 4.997589, 5.017833, 4.988444, 5.085256, 5.055156, 5.098866, 5.070367, 1.247911, 5.057667, 5.007478, 5.043056, 5.055655, 5.035878, 5.0385, 4.999267, 5.1175, 5.030822]
# step22.1: 14.848072957999875
# step22.2: 14.848100624999915
# step22.3: 14.848641166999869
# step23
# set HexV to 0.523748375237828
# 0.009499350095131198
# 0.009499350095131198
# attempts loop
# check value is: 0.019400 and target value is: 0.009499350095131198
# successfully moved device HexV
# set HexW to 0.03184301179717016
# -0.18726279528113193
# -0.18726279528113193
# attempts loop
# check value is: -0.187300 and target value is: -0.18726279528113193
# successfully moved device HexW
# set HexY to 0.31892294945208965
# 17.637845898904178
# 17.637845898904178
# attempts loop
# check value is: 17.637800 and target value is: 17.637845898904178
# successfully moved device HexY
# set HexZ to 0.538988462930219
# 0.07797692586043792
# 0.07797692586043792
# attempts loop
# check value is: 0.078000 and target value is: 0.07797692586043792
# successfully moved device HexZ
# [2.751422, 5.120511, 5.064478, 5.0301, 5.0286, 5.162722, 5.006344, 5.022033, 5.063978, 5.051455, 5.151211, 5.023556, 5.059967, 4.974756, 5.002533, 5.123389, 5.0459, 5.016056, 4.973689, 5.064289]
# step23.1: 14.35432475000016
# step23.2: 14.35435275000009
# step23.3: 14.354988542000001
# step24
# set HexV to 0.5486020579284597
# 0.019440823171383903
# 0.019440823171383903
# attempts loop
# check value is: 0.019400 and target value is: 0.019440823171383903
# successfully moved device HexV
# set HexW to 0.01760613855498551
# -0.19295754457800582
# -0.19295754457800582
# attempts loop
# check value is: -0.193000 and target value is: -0.19295754457800582
# successfully moved device HexW
# set HexY to 0.3168894996470522
# 17.633778999294105
# 17.633778999294105
# attempts loop
# check value is: 17.633800 and target value is: 17.633778999294105
# successfully moved device HexY
# set HexZ to 0.5401355478019946
# 0.08027109560398915
# 0.08027109560398915
# attempts loop
# check value is: 0.080300 and target value is: 0.08027109560398915
# successfully moved device HexZ
# [5.071378, 2.973267, 5.054544, 5.057911, 5.024667, 4.975234, 4.977567, 5.1671, 5.115244, 5.057, 5.1434, 5.095244, 5.128144, 5.025389, 5.082045, 2.018, 5.055033, 5.051622, 5.058856, 5.093855]
# step24.1: 15.118315583999902
# step24.2: 15.118342291999852
# step24.3: 15.11886570899992
# step25
# set HexV to 0.5709503589297262
# 0.028380143571890504
# 0.028380143571890504
# attempts loop
# check value is: 0.028400 and target value is: 0.028380143571890504
# successfully moved device HexV
# set HexW to 0.030705141787175615
# -0.18771794328512975
# -0.18771794328512975
# attempts loop
# check value is: -0.187700 and target value is: -0.18771794328512975
# successfully moved device HexW
# set HexY to 0.32187413587282565
# 17.64374827174565
# 17.64374827174565
# attempts loop
# check value is: 17.643700 and target value is: 17.64374827174565
# successfully moved device HexY
# set HexZ to 0.5397610256958637
# 0.07952205139172741
# 0.07952205139172741
# attempts loop
# check value is: 0.079500 and target value is: 0.07952205139172741
# successfully moved device HexZ
# [5.094678, 5.134711, 5.043189, 5.140278, 5.088622, 5.086111, 5.091755, 5.063078, 5.082911, 5.068955, 5.063522, 5.070256, 5.061367, 5.106555, 5.008878, 1.632456, 5.010056, 3.272233, 4.9897, 5.063944]
# step25.1: 14.184116915999994
# step25.2: 14.184141833000012
# step25.3: 14.184641874999897
# step26
# set HexV to 0.5841729023218907
# 0.03366916092875627
# 0.03366916092875627
# attempts loop
# check value is: 0.033700 and target value is: 0.03366916092875627
# successfully moved device HexV
# set HexW to 0.03586230912082031
# -0.1856550763516719
# -0.1856550763516719
# attempts loop
# check value is: -0.185700 and target value is: -0.1856550763516719
# successfully moved device HexW
# set HexY to 0.32652359521020935
# 17.65304719042042
# 17.65304719042042
# attempts loop
# check value is: 17.653000 and target value is: 17.65304719042042
# successfully moved device HexY
# set HexZ to 0.53693659882179
# 0.07387319764358002
# 0.07387319764358002
# attempts loop
# check value is: 0.073900 and target value is: 0.07387319764358002
# successfully moved device HexZ
# [1.513622, 5.031889, 5.031178, 5.072444, 5.043922, 5.097211, 5.014167, 5.025411, 5.039022, 5.039022, 5.087855, 5.054289, 5.049167, 5.149289, 5.054234, 5.038989, 5.0801, 5.045956, 5.060155, 5.055678]
# step26.1: 14.233543125000097
# step26.2: 14.233586709000065
# step26.3: 14.23488295900006
# step27
# set HexV to 0.5849779330863212
# 0.033991173234528466
# 0.033991173234528466
# attempts loop
# check value is: 0.034000 and target value is: 0.033991173234528466
# successfully moved device HexV
# set HexW to 0.044646058493107335
# -0.18214157660275707
# -0.18214157660275707
# attempts loop
# check value is: -0.182100 and target value is: -0.18214157660275707
# successfully moved device HexW
# set HexY to 0.3285991076234717
# 17.657198215246943
# 17.657198215246943
# attempts loop
# check value is: 17.657200 and target value is: 17.657198215246943
# successfully moved device HexY
# set HexZ to 0.5456228125812475
# 0.0912456251624949
# 0.0912456251624949
# attempts loop
# check value is: 0.073900 and target value is: 0.0912456251624949
# successfully moved device HexZ
# [5.146333, 5.155811, 5.0986, 5.137167, 4.994222, 4.994222, 5.086945, 5.134278, 5.067245, 1.784211, 5.095067, 5.017066, 5.1489, 5.067622, 4.990878, 5.104344, 5.008567, 5.001111, 5.049167, 5.115878]
# step27.1: 14.289081916999976
# step27.2: 14.289104207999799
# step27.3: 14.289649332999943
# step28
# set HexV to 0.5867093996722392
# 0.034683759868895686
# 0.034683759868895686
# attempts loop
# check value is: 0.034700 and target value is: 0.034683759868895686
# successfully moved device HexV
# set HexW to 0.049085066744137575
# -0.180365973302345
# -0.180365973302345
# attempts loop
# check value is: -0.180400 and target value is: -0.180365973302345
# successfully moved device HexW
# set HexY to 0.32954567520741485
# 17.65909135041483
# 17.65909135041483
# attempts loop
# check value is: 17.659100 and target value is: 17.65909135041483
# successfully moved device HexY
# set HexZ to 0.5492728406343572
# 0.09854568126871444
# 0.09854568126871444
# attempts loop
# check value is: 0.073900 and target value is: 0.09854568126871444
# successfully moved device HexZ
# [5.048811, 2.450356, 5.145722, 5.058533, 5.1132, 4.753278, 5.064956, 5.096334, 5.091489, 5.040534, 5.125134, 5.089311, 5.079945, 5.044633, 5.106111, 5.081911, 5.017544, 5.027867, 5.020078, 5.020089]
# step28.1: 14.640664457999947
# step28.2: 14.640713249999862
# step28.3: 14.641997082999978
# step29
# set HexV to 0.5872893760635777
# 0.034915750425431075
# 0.034915750425431075
# attempts loop
# check value is: 0.034700 and target value is: 0.034915750425431075
# successfully moved device HexV
# set HexW to 0.03913761161258765
# -0.18434495535496495
# -0.18434495535496495
# attempts loop
# check value is: -0.184300 and target value is: -0.18434495535496495
# successfully moved device HexW
# set HexY to 0.33037634522416653
# 17.660752690448334
# 17.660752690448334
# attempts loop
# check value is: 17.660800 and target value is: 17.660752690448334
# successfully moved device HexY
# set HexZ to 0.5379550776781208
# 0.07591015535624157
# 0.07591015535624157
# attempts loop
# check value is: 0.075900 and target value is: 0.07591015535624157
# successfully moved device HexZ
# [4.994211, 5.092222, 5.049067, 5.032478, 5.054422, 5.173456, 5.027811, 5.0764, 5.097011, 5.100278, 5.124256, 5.061511, 5.077044, 5.018789, 5.056967, 5.027611, 4.993245, 5.068378, 5.034534, 4.983111]
# step29.1: 15.5463823340001
# step29.2: 15.546443917000033
# step29.3: 15.54782175000014
# step30
# set HexV to 0.5836806278338728
# 0.0334722511335491
# 0.0334722511335491
# attempts loop
# check value is: 0.033500 and target value is: 0.0334722511335491
# successfully moved device HexV
# set HexW to 0.052932603757467375
# -0.17882695849701305
# -0.17882695849701305
# attempts loop
# check value is: -0.178800 and target value is: -0.17882695849701305
# successfully moved device HexW
# set HexY to 0.3293822015047648
# 17.65876440300953
# 17.65876440300953
# attempts loop
# check value is: 17.658800 and target value is: 17.65876440300953
# successfully moved device HexY
# set HexZ to 0.557292541230179
# 0.11458508246035803
# 0.11458508246035803
# attempts loop
# check value is: 0.114600 and target value is: 0.11458508246035803
# successfully moved device HexZ
# [5.058411, 4.982067, 5.014256, 5.126155, 3.451133, 5.053844, 1.536311, 5.093978, 5.080256, 5.044822, 5.128833, 5.040344, 5.029411, 5.035255, 5.131344, 5.071589, 5.0579, 5.040844, 5.088411, 5.062533]
# step30.1: 15.223838999999998
# step30.2: 15.223885749999909
# step30.3: 15.225141874999963
# step31
# set HexV to 0.5808528257476739
# 0.03234113029906957
# 0.03234113029906957
# attempts loop
# check value is: 0.032300 and target value is: 0.03234113029906957
# successfully moved device HexV
# set HexW to 0.034070359456932056
# -0.18637185621722718
# -0.18637185621722718
# attempts loop
# check value is: -0.186400 and target value is: -0.18637185621722718
# successfully moved device HexW
# set HexY to 0.329155399018136
# 17.658310798036272
# 17.658310798036272
# attempts loop
# check value is: 17.658300 and target value is: 17.658310798036272
# successfully moved device HexY
# set HexZ to 0.5378622211001797
# 0.07572444220035934
# 0.07572444220035934
# attempts loop
# check value is: 0.075700 and target value is: 0.07572444220035934
# successfully moved device HexZ
# [5.056944, 5.042345, 5.026711, 5.043655, 5.030389, 5.038055, 2.688844, 5.146711, 5.028844, 4.973644, 5.044167, 5.075489, 4.983122, 5.048544, 5.164166, 5.029422, 5.056778, 5.056778, 5.108522, 5.039211]
# step31.1: 15.083577084000126
# step31.2: 15.083629083999995
# step31.3: 15.084945334000167
# step32
# set HexV to 0.5716296050373089
# 0.028651842014923545
# 0.028651842014923545
# attempts loop
# check value is: 0.028700 and target value is: 0.028651842014923545
# successfully moved device HexV
# set HexW to 0.04796855676819445
# -0.18081257729272224
# -0.18081257729272224
# attempts loop
# check value is: -0.180800 and target value is: -0.18081257729272224
# successfully moved device HexW
# set HexY to 0.32540809366962
# 17.650816187339238
# 17.650816187339238
# attempts loop
# check value is: 17.650800 and target value is: 17.650816187339238
# successfully moved device HexY
# set HexZ to 0.559858956977318
# 0.11971791395463605
# 0.11971791395463605
# attempts loop
# check value is: 0.119700 and target value is: 0.11971791395463605
# successfully moved device HexZ
# [5.063111, 1.303744, 5.040433, 5.057956, 5.023355, 5.025322, 5.039344, 5.088078, 5.1069, 4.988489, 5.099566, 5.095267, 5.039344, 5.060978, 5.087234, 5.021056, 5.079844, 5.040878, 5.015444, 5.029856]
# step32.1: 15.847603166999988
# step32.2: 15.84766829199998
# step32.3: 15.849045625000144
# step33
# set HexV to 0.566390981878241
# 0.026556392751296398
# 0.026556392751296398
# attempts loop
# check value is: 0.026600 and target value is: 0.026556392751296398
# successfully moved device HexV
# set HexW to 0.011127668397361191
# -0.19554893264105552
# -0.19554893264105552
# attempts loop
# check value is: -0.195500 and target value is: -0.19554893264105552
# successfully moved device HexW
# set HexY to 0.32000880092471923
# 17.64001760184944
# 17.64001760184944
# attempts loop
# check value is: 17.640000 and target value is: 17.64001760184944
# successfully moved device HexY
# set HexZ to 0.5399717964807899
# 0.07994359296157971
# 0.07994359296157971
# attempts loop
# check value is: 0.079900 and target value is: 0.07994359296157971
# successfully moved device HexZ
# [5.101733, 5.082789, 5.083522, 5.1319, 3.6872, 5.030233, 5.142745, 5.129911, 5.122311, 5.050911, 5.117445, 5.100633, 5.076544, 5.039556, 5.080667, 5.1007, 5.097256, 5.160045, 5.110956, 5.024766]
# step33.1: 14.468672541999922
# step33.2: 14.468730833000109
# step33.3: 14.470082833000106
# step34
# set HexV to 0.565172149773215
# 0.02606885990928598
# 0.02606885990928598
# attempts loop
# check value is: 0.026100 and target value is: 0.02606885990928598
# successfully moved device HexV
# set HexW to 0.0
# -0.2
# set value of -0.2for HexW is not in the range: [-0.2, 0.2]
# -0.2
# attempts loop
# check value is: -0.195500 and target value is: -0.2
# successfully moved device HexW
# set HexY to 0.3133177779474985
# 17.626635555894996
# 17.626635555894996
# attempts loop
# check value is: 17.626600 and target value is: 17.626635555894996
# successfully moved device HexY
# set HexZ to 0.5337879257178261
# 0.06757585143565215
# 0.06757585143565215
# attempts loop
# check value is: 0.067600 and target value is: 0.06757585143565215
# successfully moved device HexZ
# [5.089833, 5.003122, 5.158711, 5.063544, 5.029322, 5.079033, 5.154833, 5.013922, 5.120744, 5.120744, 5.068511, 5.093911, 5.026433, 5.142334, 5.1417, 4.986956, 5.023811, 5.048745, 5.055278, 4.827055]
# step34.1: 14.490183916999968
# step34.2: 14.490225250000094
# step34.3: 14.49144529199998
# step35
# set HexV to 0.5629650590071777
# 0.025186023602871088
# 0.025186023602871088
# attempts loop
# check value is: 0.026100 and target value is: 0.025186023602871088
# successfully moved device HexV
# set HexW to 0.0
# -0.2
# set value of -0.2for HexW is not in the range: [-0.2, 0.2]
# -0.2
# attempts loop
# check value is: -0.195500 and target value is: -0.2
# successfully moved device HexW
# set HexY to 0.3109794868020128
# 17.621958973604027
# 17.621958973604027
# attempts loop
# check value is: 17.622000 and target value is: 17.621958973604027
# successfully moved device HexY
# set HexZ to 0.5351518988875285
# 0.07030379777505691
# 0.07030379777505691
# attempts loop
# check value is: 0.070300 and target value is: 0.07030379777505691
# successfully moved device HexZ
# [5.021733, 5.048056, 5.1165, 2.689856, 5.071256, 5.105578, 5.049, 5.050589, 5.083145, 1.505689, 5.128589, 5.0307, 5.112889, 5.039811, 5.144245, 5.0584, 5.0654, 5.140189, 5.0501, 5.0984]
# step35.1: 14.701196624999966
# step35.2: 14.701245249999829
# step35.3: 14.702491082999813
# step36
# set HexV to 0.5606124946042327
# 0.024244997841693067
# 0.024244997841693067
# attempts loop
# check value is: 0.024200 and target value is: 0.024244997841693067
# successfully moved device HexV
# set HexW to 0.0
# -0.2
# set value of -0.2for HexW is not in the range: [-0.2, 0.2]
# -0.2
# attempts loop
# check value is: -0.195500 and target value is: -0.2
# successfully moved device HexW
# set HexY to 0.31281627583401395
# 17.625632551668026
# 17.625632551668026
# attempts loop
# check value is: 17.625600 and target value is: 17.625632551668026
# successfully moved device HexY
# set HexZ to 0.5417403645936333
# 0.08348072918726657
# 0.08348072918726657
# attempts loop
# check value is: 0.083500 and target value is: 0.08348072918726657
# successfully moved device HexZ
# [5.048622, 5.074934, 5.0567, 5.092055, 4.973866, 5.111089, 5.025133, 5.061356, 5.021022, 5.051378, 5.110578, 5.092945, 5.123689, 5.152589, 5.111156, 5.108133, 5.081089, 1.5812, 5.094211, 5.026667]
# step36.1: 15.088907708000079
# step36.2: 15.088972333000129
# step36.3: 15.090318375000152
# step37
# set HexV to 0.5590137263169345
# 0.023605490526773798
# 0.023605490526773798
# attempts loop
# check value is: 0.023600 and target value is: 0.023605490526773798
# successfully moved device HexV
# set HexW to 0.0
# -0.2
# set value of -0.2for HexW is not in the range: [-0.2, 0.2]
# -0.2
# attempts loop
# check value is: -0.195500 and target value is: -0.2
# successfully moved device HexW
# set HexY to 0.3131209257562943
# 17.62624185151259
# 17.62624185151259
# attempts loop
# check value is: 17.626200 and target value is: 17.62624185151259
# successfully moved device HexY
# set HexZ to 0.5463528084593364
# 0.09270561691867285
# 0.09270561691867285
# attempts loop
# check value is: 0.092700 and target value is: 0.09270561691867285
# successfully moved device HexZ
# [5.093534, 5.045133, 5.070378, 5.044767, 4.982622, 5.049544, 5.096766, 5.015278, 5.0451, 3.2838, 3.2838, 5.185111, 5.080956, 5.124545, 4.9996, 5.000722, 5.077856, 5.097067, 2.252511, 5.095789]
# step37.1: 15.173627041999907
# step37.2: 15.173647542000026
# step37.3: 15.174154499999986
# step38
# set HexV to 0.5551665694041261
# 0.022066627761650442
# 0.022066627761650442
# attempts loop
# check value is: 0.022100 and target value is: 0.022066627761650442
# successfully moved device HexV
# set HexW to 0.0
# -0.2
# set value of -0.2for HexW is not in the range: [-0.2, 0.2]
# -0.2
# attempts loop
# check value is: -0.195500 and target value is: -0.2
# successfully moved device HexW
# set HexY to 0.3117969625056895
# 17.623593925011377
# 17.623593925011377
# attempts loop
# check value is: 17.626200 and target value is: 17.623593925011377
# successfully moved device HexY
# set HexZ to 0.5304420810938393
# 0.06088416218767856
# 0.06088416218767856
# attempts loop
# check value is: 0.060900 and target value is: 0.06088416218767856
# successfully moved device HexZ
# [5.064556, 5.050667, 5.043011, 5.111644, 5.035333, 5.057722, 4.998122, 5.042756, 5.052422, 5.042511, 5.1061, 5.124622, 5.039744, 5.0739, 5.0426, 5.097456, 5.084311, 5.106544, 5.136322, 5.080567]
# step38.1: 14.83052637500009
# step38.2: 14.830548958000008
# step38.3: 14.831128290999914
# step39
# set HexV to 0.5539015772822646
# 0.02156063091290586
# 0.02156063091290586
# attempts loop
# check value is: 0.021600 and target value is: 0.02156063091290586
# successfully moved device HexV
# set HexW to 0.01891465178598772
# -0.19243413928560493
# -0.19243413928560493
# attempts loop
# check value is: -0.192400 and target value is: -0.19243413928560493
# successfully moved device HexW
# set HexY to 0.3127778153934423
# 17.625555630786884
# 17.625555630786884
# attempts loop
# check value is: 17.625600 and target value is: 17.625555630786884
# successfully moved device HexY
# set HexZ to 0.5413732531618047
# 0.08274650632360947
# 0.08274650632360947
# attempts loop
# check value is: 0.082700 and target value is: 0.08274650632360947
# successfully moved device HexZ
# [5.046889, 5.035022, 5.0903, 5.167222, 5.084944, 5.038167, 5.098433, 5.022311, 5.090544, 5.054255, 5.050889, 5.075522, 1.245378, 5.051022, 5.105134, 5.095133, 5.121167, 5.040722, 5.080656, 5.081522]
# step39.1: 15.33001979100004
# step39.2: 15.330083541000022
# step39.3: 15.331393082999966
# step40
# set HexV to 0.5522702228056897
# 0.020908089122275875
# 0.020908089122275875
# attempts loop
# check value is: 0.020900 and target value is: 0.020908089122275875
# successfully moved device HexV
# set HexW to 0.02104004415869082
# -0.19158398233652368
# -0.19158398233652368
# attempts loop
# check value is: -0.191600 and target value is: -0.19158398233652368
# successfully moved device HexW
# set HexY to 0.3120636440840731
# 17.624127288168147
# 17.624127288168147
# attempts loop
# check value is: 17.624100 and target value is: 17.624127288168147
# successfully moved device HexY
# set HexZ to 0.5418926839547825
# 0.08378536790956503
# 0.08378536790956503
# attempts loop
# check value is: 0.083800 and target value is: 0.08378536790956503
# successfully moved device HexZ
# [5.045189, 5.119789, 5.104722, 4.971766, 5.047722, 5.054955, 5.128467, 2.0915, 5.082244, 5.120444, 5.031278, 5.108422, 5.188622, 5.097422, 5.087778, 5.129622, 5.148989, 5.004522, 5.081078, 2.846355]
# step40.1: 14.616864917000157
# step40.2: 14.616894083000034
# step40.3: 14.617467208000107
# step41
# set HexV to 0.5498976407399625
# 0.01995905629598499
# 0.01995905629598499
# attempts loop
# check value is: 0.020000 and target value is: 0.01995905629598499
# successfully moved device HexV
# set HexW to 0.021001683924911384
# -0.19159932643003547
# -0.19159932643003547
# attempts loop
# check value is: -0.191600 and target value is: -0.19159932643003547
# successfully moved device HexW
# set HexY to 0.309613499260903
# 17.619226998521807
# 17.619226998521807
# attempts loop
# check value is: 17.619200 and target value is: 17.619226998521807
# successfully moved device HexY
# set HexZ to 0.540443556837211
# 0.08088711367442203
# 0.08088711367442203
# attempts loop
# check value is: 0.080900 and target value is: 0.08088711367442203
# successfully moved device HexZ
# [5.059711, 5.043511, 5.147456, 5.097466, 4.9956, 5.0554, 5.059055, 5.060389, 5.118755, 5.047311, 5.082078, 5.0885, 5.037711, 5.081645, 5.115, 5.079089, 5.025033, 5.043811, 5.096133, 5.075433]
# step41.1: 14.374702542000023
# step41.2: 14.374745708000091
# step41.3: 14.37596954200012
# step42
# set HexV to 0.5480719327239644
# 0.01922877308958576
# 0.01922877308958576
# attempts loop
# check value is: 0.019200 and target value is: 0.01922877308958576
# successfully moved device HexV
# set HexW to 0.0200570636064075
# -0.191977174557437
# -0.191977174557437
# attempts loop
# check value is: -0.192000 and target value is: -0.191977174557437
# successfully moved device HexW
# set HexY to 0.30863708276391133
# 17.617274165527824
# 17.617274165527824
# attempts loop
# check value is: 17.617300 and target value is: 17.617274165527824
# successfully moved device HexY
# set HexZ to 0.5410169448472989
# 0.0820338896945978
# 0.0820338896945978
# attempts loop
# check value is: 0.082000 and target value is: 0.0820338896945978
# successfully moved device HexZ
# [2.261333, 5.108745, 5.083478, 4.954878, 5.068922, 5.091211, 5.010289, 5.002489, 5.093567, 5.123044, 5.121489, 5.062533, 5.091567, 5.091567, 5.129533, 5.079744, 5.115889, 5.156355, 5.105222, 5.080778]
# step42.1: 14.995027041999947
# step42.2: 14.995056292000072
# step42.3: 14.995804375000034
# step43
# set HexV to 0.5400466322341787
# 0.016018652893671492
# 0.016018652893671492
# attempts loop
# check value is: 0.016000 and target value is: 0.016018652893671492
# successfully moved device HexV
# set HexW to 0.002158530094567447
# -0.19913658796217304
# -0.19913658796217304
# attempts loop
# check value is: -0.192000 and target value is: -0.19913658796217304
# successfully moved device HexW
# set HexY to 0.3037651254135058
# 17.60753025082701
# 17.60753025082701
# attempts loop
# check value is: 17.607500 and target value is: 17.60753025082701
# successfully moved device HexY
# set HexZ to 0.5290757993352223
# 0.058151598670444615
# 0.058151598670444615
# attempts loop
# check value is: 0.082000 and target value is: 0.058151598670444615
# successfully moved device HexZ
# [5.091889, 3.693122, 3.833711, 5.104233, 5.051466, 5.074411, 5.090533, 5.123511, 5.081255, 5.082345, 4.994911, 5.090022, 5.101778, 5.042789, 4.988489, 5.098022, 5.0141, 5.078055, 5.122489, 5.033945]
# step43.1: 15.06367924999995
# step43.2: 15.063730207999924
# step43.3: 15.065044124999986
# step44
# set HexV to 0.5292750595210314
# 0.011710023808412545
# 0.011710023808412545
# attempts loop
# check value is: 0.011700 and target value is: 0.011710023808412545
# successfully moved device HexV
# set HexW to 0.0
# -0.2
# set value of -0.2for HexW is not in the range: [-0.2, 0.2]
# -0.2
# attempts loop
# check value is: -0.199100 and target value is: -0.2
# successfully moved device HexW
# set HexY to 0.2967442889431961
# 17.593488577886394
# 17.593488577886394
# attempts loop
# check value is: 17.593500 and target value is: 17.593488577886394
# successfully moved device HexY
# set HexZ to 0.5206023740068937
# 0.04120474801378737
# 0.04120474801378737
# attempts loop
# check value is: 0.041200 and target value is: 0.04120474801378737
# successfully moved device HexZ
# [3.261689, 5.048133, 5.048133, 2.750744, 5.056489, 5.1112, 5.021934, 2.589756, 5.108045, 5.073455, 5.013078, 1.487989, 5.065011, 5.0756, 5.082366, 4.976, 5.044633, 5.0097, 5.031755, 5.190311]
# step44.1: 14.652986083000087
# step44.2: 14.653045250000105
# step44.3: 14.654360624999981
# step45
# set HexV to 0.5266148802317067
# 0.010645952092682653
# 0.010645952092682653
# attempts loop
# check value is: 0.010600 and target value is: 0.010645952092682653
# successfully moved device HexV
# set HexW to 0.01333156694886499
# -0.19466737322045402
# -0.19466737322045402
# attempts loop
# check value is: -0.199100 and target value is: -0.19466737322045402
# successfully moved device HexW
# set HexY to 0.3051450510737958
# 17.61029010214759
# 17.61029010214759
# attempts loop
# check value is: 17.610300 and target value is: 17.61029010214759
# successfully moved device HexY
# set HexZ to 0.5556822748873531
# 0.11136454977470622
# 0.11136454977470622
# attempts loop
# check value is: 0.041200 and target value is: 0.11136454977470622
# successfully moved device HexZ
# [5.108889, 5.076822, 5.112478, 3.039678, 5.067689, 2.232356, 5.131744, 5.082522, 5.080534, 5.036856, 5.066278, 5.112078, 5.076378, 5.071667, 5.129778, 5.0227, 5.131433, 5.051789, 5.105367, 5.030433]
# step45.1: 14.914790374999939
# step45.2: 14.914856249999957
# step45.3: 14.916158332999885
# step46
# set HexV to 0.5182363310512921
# 0.007294532420516836
# 0.007294532420516836
# attempts loop
# check value is: 0.007300 and target value is: 0.007294532420516836
# successfully moved device HexV
# set HexW to 0.0030928427581947268
# -0.19876286289672213
# -0.19876286289672213
# attempts loop
# check value is: -0.199100 and target value is: -0.19876286289672213
# successfully moved device HexW
# set HexY to 0.30834012911064895
# 17.616680258221297
# 17.616680258221297
# attempts loop
# check value is: 17.616700 and target value is: 17.616680258221297
# successfully moved device HexY
# set HexZ to 0.5615537360055024
# 0.1231074720110048
# 0.1231074720110048
# attempts loop
# check value is: 0.123100 and target value is: 0.1231074720110048
# successfully moved device HexZ
# [5.063833, 5.029533, 5.130556, 5.076334, 5.057544, 5.100467, 5.130355, 5.083567, 5.085433, 5.079245, 5.060411, 5.084811, 5.010745, 5.064078, 5.103933, 5.103933, 5.092878, 5.111011, 5.076644, 5.109289]
# step46.1: 14.672343834000003
# step46.2: 14.672372834000043
# step46.3: 14.67287291699995
# step47
# set HexV to 0.4944114070701038
# -0.002235437171958482
# -0.002235437171958482
# ...
# attempts loop
# step59.1: 4.0718360409998695
# step59.2: 4.071863291
# step59.3: 4.072548332999986
# step60
# set HexV to 0.5461568995812137
# 0.018462759832485492
# 0.018462759832485492
# attempts loop
# socket was busy when requested
# step60.1: 4.015035249999983
# step60.2: 4.015087500000163
# step60.3: 4.016149125000084
# step61
# set HexV to 0.5461623269527258
# 0.018464930781090322
# 0.018464930781090322
# attempts loop
# step61.1: 4.546097375000045
# step61.2: 4.546117916999947
# step61.3: 4.546633292000024
# step62
# set HexV to 0.5461562874741875
# 0.018462514989675022
# 0.018462514989675022
# attempts loop
# socket was busy when requested
# step62.1: 3.9851365000001806
# step62.2: 3.9851664590000837
# step62.3: 3.9857754170000135
# step63
# set HexV to 0.5461520719497879
# 0.018460828779915145
# 0.018460828779915145
# attempts loop
# step63.1: 3.8059845000000223
# step63.2: 3.8060083340001256
# step63.3: 3.8066788339999675
# step64
# set HexV to 0.5461568101111353
# 0.018462724044454093
# 0.018462724044454093
# attempts loop
# socket was busy when requested
# step64.1: 4.0012160829999175
# step64.2: 4.001256540999975
# step64.3: 4.002284665999923
# step65
# set HexV to 0.5461562866609921
# 0.018462514664396856
# 0.018462514664396856
# attempts loop
# step65.1: 3.9861069169999155
# step65.2: 3.9861377919999086
# step65.3: 3.9868112090000523
# step66
# set HexV to 0.5461578872883235
# 0.018463154915329405
# 0.018463154915329405
# attempts loop
# socket was busy when requested
# step66.1: 4.016491374999987
# step66.2: 4.016519041000038
# step66.3: 4.017104374999917
# step67
# set HexV to 0.546156929723163
# 0.018462771889265206
# 0.018462771889265206
# attempts loop
# step67.1: 4.089683958999785
# step67.2: 4.089719124999874
# step67.3: 4.090403917000003
# step68
# set HexV to 0.5461587329390148
# 0.018463493175605944
# 0.018463493175605944
# attempts loop
# socket was busy when requested
# step68.1: 3.87713633400017
# step68.2: 3.8771669590000784
# step68.3: 3.877753542000164
# step69
# set HexV to 0.546156331938024
# 0.018462532775209622
# 0.018462532775209622
# attempts loop
# step69.1: 4.1004526660001375
# step69.2: 4.100476250000156
# step69.3: 4.101017958000057
# step70
# set HexV to 0.5461589856154017
# 0.018463594246160675
# 0.018463594246160675
# attempts loop
# socket was busy when requested
# step70.1: 4.0195240830000785
# step70.2: 4.019551332999981
# step70.3: 4.0202087919999485
# step71
# set HexV to 0.5461593184875513
# 0.0184637273950205
# 0.0184637273950205
# attempts loop
# step71.1: 3.993820790999962
# step71.2: 3.9938405830000647
# step71.3: 3.9943603330000315
# step72
# set HexV to 0.5461566820777329
# 0.01846267283109318
# 0.01846267283109318
# attempts loop
# socket was busy when requested
# step72.1: 4.003996666000148
# step72.2: 4.004027250000036
# step72.3: 4.0046647500000745
# step73
# set HexV to 0.5461571218863625
# 0.018462848754544986
# 0.018462848754544986
# attempts loop
# step73.1: 4.609501333000026
# step73.2: 4.6095277500000975
# step73.3: 4.61012083300011
# step74
# set HexV to 0.5461583382171603
# 0.018463335286864113
# 0.018463335286864113
# attempts loop
# socket was busy when requested
# step74.1: 4.070127834000004
# step74.2: 4.0701530000001185
# step74.3: 4.070700708999993
# step75
# set HexV to 0.5461580711114173
# 0.018463228444566937
# 0.018463228444566937
# attempts loop
# step75.1: 3.947067041000082
# step75.2: 3.9470874579999418
# step75.3: 3.9476100829999723
# step76
# set HexV to 0.5461582331605668
# 0.018463293264226716
# 0.018463293264226716
# attempts loop
# socket was busy when requested
# step76.1: 4.056890374999966
# step76.2: 4.056909874999974
# step76.3: 4.057450625000001
# step77
# set HexV to 0.546157711321795
# 0.018463084528718005
# 0.018463084528718005
# attempts loop
# step77.1: 3.9683361249999507
# step77.2: 3.968377417000056
# step77.3: 3.9693698329999734
# step78
# set HexV to 0.5461572575519613
# 0.018462903020784516
# 0.018462903020784516
# attempts loop
# socket was busy when requested
# step78.1: 3.992037375000109
# step78.2: 3.9920615000000907
# step78.3: 3.992576916999951
# step79
# set HexV to 0.5461593107247774
# 0.01846372428991097
# 0.01846372428991097
# attempts loop
# step79.1: 4.1006234590001895
# step79.2: 4.100648042000103
# step79.3: 4.101157750000084
# step80
# set HexV to 0.5461572210392414
# 0.018462888415696543
# 0.018462888415696543
# attempts loop
# socket was busy when requested
# step80.1: 4.0984970000001795
# step80.2: 4.098526333000109
# step80.3: 4.099069583000073
# step81
# set HexV to 0.5461565834198734
# 0.018462633367949344
# 0.018462633367949344
# attempts loop
# step81.1: 3.691539333000037
# step81.2: 3.6915653329999714
# step81.3: 3.6921148750000157
# step82
# set HexV to 0.5461579034445639
# 0.018463161377825582
# 0.018463161377825582
# attempts loop
# socket was busy when requested
# step82.1: 3.5865095839999412
# step82.2: 3.5865391249999448
# step82.3: 3.5870604589999857
# step83
# set HexV to 0.5461574223127098
# 0.018462968925083922
# 0.018462968925083922
# attempts loop
# step83.1: 3.676680124999848
# step83.2: 3.6767028340002526
# step83.3: 3.6772359590001997
# step84
# set HexV to 0.5461566144669214
# 0.018462645786768567
# 0.018462645786768567
# attempts loop
# socket was busy when requested
# step84.1: 3.871684499999901
# step84.2: 3.871712374999788
# step84.3: 3.872260666999864
# step85
# set HexV to 0.5461576954811017
# 0.018463078192440696
# 0.018463078192440696
# attempts loop
# step85.1: 4.283471208999799
# step85.2: 4.283497334000003
# step85.3: 4.284044500000164
# step86
# set HexV to 0.5461570307169966
# 0.018462812286798636
# 0.018462812286798636
# attempts loop
# socket was busy when requested
# step86.1: 3.6996745840001495
# step86.2: 3.6997329589999026
# step86.3: 3.7008235839998633
# step87
# set HexV to 0.5461586361117858
# 0.01846345444471434
# 0.01846345444471434
# attempts loop
# step87.1: 3.7468633329999648
# step87.2: 3.746885707999809
# step87.3: 3.747300707999784
# step88
# set HexV to 0.5461574925863839
# 0.018462997034553563
# 0.018462997034553563
# attempts loop
# socket was busy when requested
# step88.1: 3.7208266249999724
# step88.2: 3.7208419589996993
# step88.3: 3.7213187919996926
# step89
# set HexV to 0.546157876438302
# 0.01846315057532083
# 0.01846315057532083
# attempts loop
# step89.1: 3.8936606250003933
# step89.2: 3.8936917080000057
# step89.3: 3.894695416000104
# step90
# set HexV to 0.5461577695228943
# 0.01846310780915772
# 0.01846310780915772
# attempts loop
# socket was busy when requested
# step90.1: 3.776483458000257
# step90.2: 3.776535542000147
# step90.3: 3.777613250000286
# step91
# set HexV to 0.5461587196140559
# 0.01846348784562238
# 0.01846348784562238
# attempts loop
# step91.1: 3.703643207999903
# step91.2: 3.7036749170001713
# step91.3: 3.7043217919999734
# step92
# set HexV to 0.5461554154152266
# 0.018462166166090643
# 0.018462166166090643
# attempts loop
# socket was busy when requested
# step92.1: 3.665587166000023
# step92.2: 3.665654416000052
# step92.3: 3.666867291000017
# step93
# set HexV to 0.546158314225596
# 0.018463325690238397
# 0.018463325690238397
# attempts loop
# step93.1: 3.6809065000002192
# step93.2: 3.6809652080000888
# step93.3: 3.682068291000178
# step94
# set HexV to 0.5461580747714796
# 0.01846322990859184
# 0.01846322990859184
# attempts loop
# socket was busy when requested
# step94.1: 3.6908252910002375
# step94.2: 3.690861708000284
# step94.3: 3.691495791000307
# step95
# set HexV to 0.5461580833841387
# 0.01846323335365549
# 0.01846323335365549
# attempts loop
# step95.1: 4.0879809580001165
# step95.2: 4.088007583000035
# step95.3: 4.088561666999794
# step96
# set HexV to 0.546156792363261
# 0.01846271694530438
# 0.01846271694530438
# attempts loop
# socket was busy when requested
# step96.1: 3.7992653330002213
# step96.2: 3.7993198750000374
# step96.3: 3.800384208000196
# step97
# set HexV to 0.5461579981202385
# 0.01846319924809539
# 0.01846319924809539
# attempts loop
# step97.1: 5.8852889159998085
# step97.2: 5.885310999000012
# step97.3: 5.885802457999944
# step98
# set HexV to 0.5461557543262683
# 0.018462301730507308
# 0.018462301730507308
# attempts loop
# socket was busy when requested
# step98.1: 4.150681916999929
# step98.2: 4.150703541999974
# step98.3: 4.15119658399999
# step99
# set HexV to 0.5461565325764436
# 0.018462613030577446
# 0.018462613030577446
# attempts loop
# step99.1: 4.030766083000344
# step99.2: 4.03079333300002
# step99.3: 4.031321165999998
# step100
# set HexV to 0.5461583602323461
# 0.018463344092938427
# 0.018463344092938427
# attempts loop
# socket was busy when requested
# step100.1: 3.933328000000074
# step100.2: 3.933353458000056
# step100.3: 3.933852417000253
# step101
# set HexV to 0.546155689263163
# 0.018462275705265208
# 0.018462275705265208
# attempts loop
# step101.1: 4.344004167000094
# step101.2: 4.344028583000181
# step101.3: 4.344540916999904
# step102
# set HexV to 0.5461560486641531
# 0.01846241946566124
# 0.01846241946566124
# attempts loop
# socket was busy when requested
# step102.1: 4.020224833999691
# step102.2: 4.020254583999758
# step102.3: 4.0208142090000365
# step103
# set HexV to 0.5461571205442186
# 0.018462848217687455
# 0.018462848217687455
# attempts loop
# step103.1: 3.9148047079997923
# step103.2: 3.9148248749997947
# step103.3: 3.9153003329997773
# step104
# set HexV to 0.5461581419094425
# 0.01846325676377697
# 0.01846325676377697
# attempts loop
# socket was busy when requested
# step104.1: 4.0137475420001465
# step104.2: 4.013775208000425
# step104.3: 4.014425500000016
# step105
# set HexV to 0.5461567104274858
# 0.018462684170994337
# 0.018462684170994337
# attempts loop
# step105.1: 3.7254909999996926
# step105.2: 3.7255220829997597
# step105.3: 3.7260687499997402
# step106
# set HexV to 0.5461585765987972
# 0.018463430639518885
# 0.018463430639518885
# attempts loop
# socket was busy when requested
# step106.1: 4.334632292000151
# step106.2: 4.334660375000112
# step106.3: 4.335205500000029
# step107
# set HexV to 0.5461611304146387
# 0.01846445216585546
# 0.01846445216585546
# attempts loop
# step107.1: 4.1774472079996485
# step107.2: 4.177470624999842
# step107.3: 4.177967165999689
# step108
# set HexV to 0.5461569704856724
# 0.018462788194268942
# 0.018462788194268942
# attempts loop
# socket was busy when requested
# step108.1: 3.9863492910003515
# step108.2: 3.986378708000302
# step108.3: 3.9869289160001244
# step109
# set HexV to 0.5461576844650563
# 0.01846307378602252
# 0.01846307378602252
# attempts loop
# step109.1: 3.8803932079999868
# step109.2: 3.8804197499998736
# step109.3: 3.8809396669998932
# step110
# set HexV to 0.5461601035962084
# 0.018464041438483347
# 0.018464041438483347
# attempts loop
# socket was busy when requested
# step110.1: 4.147181499999988
# step110.2: 4.147208416000012
# step110.3: 4.147711290999723
# step111
# set HexV to 0.5461581928514773
# 0.0184632771405909
# 0.0184632771405909
# attempts loop
# step111.1: 3.96880287499971
# step111.2: 3.968829249999999
# step111.3: 3.969336999999996
# step112
# set HexV to 0.546156329213321
# 0.01846253168532841
# 0.01846253168532841
# attempts loop
# socket was busy when requested
# step112.1: 4.061528416999863
# step112.2: 4.06155224999975
# step112.3: 4.062046083000041
# step113
# set HexV to 0.54615646163583
# 0.01846258465433198
# 0.01846258465433198
# attempts loop
# step113.1: 3.9999174589997892
# step113.2: 3.9999464170000465
# step113.3: 4.000502333999975
# step114
# set HexV to 0.5461561895432541
# 0.01846247581730162
# 0.01846247581730162
# attempts loop
# socket was busy when requested
# step114.1: 3.8421179160000065
# step114.2: 3.842143125000348
# step114.3: 3.842677625000306
# step115
# set HexV to 0.5461567689162357
# 0.018462707566494263
# 0.018462707566494263
# attempts loop
# step115.1: 3.7493982080000023
# step115.2: 3.7494252500000584
# step115.3: 3.7500345419998666
# step116
# set HexV to 0.5461567707791721
# 0.018462708311668852
# 0.018462708311668852
# attempts loop
# socket was busy when requested
# step116.1: 3.80355095799996
# step116.2: 3.8035765829999946
# step116.3: 3.8040752080000857
# step117
# set HexV to 0.5461561921950826
# 0.01846247687803304
# 0.01846247687803304
# attempts loop
# step117.1: 3.820008250000228
# step117.2: 3.820037875000253
# step117.3: 3.8205931249999594
# step118
# set HexV to 0.5461593512640412
# 0.0184637405056165
# 0.0184637405056165
# attempts loop
# socket was busy when requested
# step118.1: 3.857378124999741
# step118.2: 3.8573982919997434
# step118.3: 3.8578910419996646
# step119
# set HexV to 0.5461564452735133
# 0.018462578109405298
# 0.018462578109405298
# attempts loop
# step119.1: 3.6918826249998347
# step119.2: 3.691911665999669
# step119.3: 3.692454041000019
# step120
# set HexV to 0.5461578086618037
# 0.01846312346472151
# 0.01846312346472151
# attempts loop
# socket was busy when requested
# step120.1: 3.765120166000088
# step120.2: 3.7651459999997314
# step120.3: 3.7657197079997786
# step121
# set HexV to 0.5461564909105502
# 0.01846259636422007
# 0.01846259636422007
# attempts loop
# step121.1: 3.810173500000019
# step121.2: 3.8101982910002334
# step121.3: 3.8107009160003145
# step122
# set HexV to 0.5461575029066352
# 0.01846300116265409
# 0.01846300116265409
# attempts loop
# socket was busy when requested
# step122.1: 3.953501917000267
# step122.2: 3.9535314170002493
# step122.3: 3.954036458000246
# step123
# set HexV to 0.5461554407422216
# 0.01846217629688862
# 0.01846217629688862
# attempts loop
# step123.1: 4.179373499999656
# step123.2: 4.179402958000082
# step123.3: 4.179977374999908
# step124
# set HexV to 0.5461563565484424
# 0.018462542619376965
# 0.018462542619376965
# attempts loop
# socket was busy when requested
# step124.1: 4.1998051659998055
# step124.2: 4.1998307079998085
# step124.3: 4.2003347079999
# step125
# set HexV to 0.5461600880726081
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/xopt/utils.py in safe_call(func, *args, **kwargs)
#     128     try:
# --> 129         result = func(*args, **kwargs)
#     130         outputs["exception"] = None
#
# /var/folders/nw/9r6cgfp912gbw8jl8fq0wsjc0000gn/T/ipykernel_3427/1236545089.py in geecs_measurement(input_dict)
#      22         print('set '+str(i)+' to '+str(set_val))
# ---> 23         time.sleep(1.1)
#      24         set_only(i,float(set_val))
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# /var/folders/nw/9r6cgfp912gbw8jl8fq0wsjc0000gn/T/ipykernel_3427/1152320329.py in <module>
#       9     print('step'+str(i))
#      10     t0=time.monotonic()
# ---> 11     X.step()
#      12     t1=time.monotonic()
#      13     print('step'+str(i)+".1: "+str(t1-t0))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/xopt/base.py in step(self)
#     232         else:
#     233             # Evaluate data
# --> 234             self.evaluate_data(new_samples)
#     235
#     236         # dump data to file if specified
#
# ~/opt/anaconda3/lib/python3.9/site-packages/xopt/base.py in evaluate_data(self, input_data)
#     132         logger.debug(f"Evaluating {len(input_data)} inputs")
#     133         input_data = self.prepare_input_data(input_data)
# --> 134         output_data = self.evaluator.evaluate_data(input_data)
#     135
#     136         if self.options.strict:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/xopt/evaluator.py in evaluate_data(self, input_data)
#     122             )
#     123
# --> 124         return pd.DataFrame(output_data, index=input_data.index)
#     125
#     126     def safe_function(self, *args, **kwargs):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     708                     data = np.asarray(data)
#     709                 else:
# --> 710                     data = list(data)
#     711             if len(data) > 0:
#     712                 if is_dataclass(data[0]):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/xopt/evaluator.py in safe_function1_for_map(function, inputs, kwargs)
#     173     Safely call the function, handling exceptions.
#     174     """
# --> 175     return safe_function(function, inputs, **kwargs)
#     176
#     177
#
# ~/opt/anaconda3/lib/python3.9/site-packages/xopt/evaluator.py in safe_function(function, *args, **kwargs)
#     177
#     178 def safe_function(function, *args, **kwargs):
# --> 179     safe_outputs = safe_call(function, *args, **kwargs)
#     180     return process_safe_outputs(safe_outputs)
#     181
#
# ~/opt/anaconda3/lib/python3.9/site-packages/xopt/utils.py in safe_call(func, *args, **kwargs)
#     138         outputs["traceback"] = error_str
#     139     finally:
# --> 140         outputs["result"] = result
#     141         outputs["runtime"] = time.perf_counter() - t
#     142     return outputs
#
# UnboundLocalError: local variable 'result' referenced before assignment

# %%
# access the collected data
X.data
# Out:
#          HexY      HexZ      HexV      HexW         f  xopt_runtime  \
# 1    0.500000  0.400000  0.400000  0.400000  3.885845     12.869196
# 2    0.400000  0.500000  0.500000  0.500000  4.184062     14.086437
# 3    0.392447  0.768048  0.507553  0.768047  2.916283     12.851995
# 4    0.364972  0.213388  0.535029  0.644537  2.892105     12.860277
# 5    0.357336  0.573350  0.542664  0.274422  4.711039     12.816549
# ..        ...       ...       ...       ...       ...           ...
# 123  0.303934  0.564072  0.546158  0.000000       NaN      2.212820
# 124  0.303947  0.563993  0.546156  0.000000       NaN      2.214038
# 125  0.303937  0.564053  0.546158  0.000000       NaN      2.212003
# 126  0.303958  0.563931  0.546155  0.000000       NaN      2.211712
# 127  0.303949  0.563983  0.546156  0.000000       NaN      2.210890
#
#      xopt_error                                     xopt_error_str
# 1         False                                                NaN
# 2         False                                                NaN
# 3         False                                                NaN
# 4         False                                                NaN
# 5         False                                                NaN
# ..          ...                                                ...
# 123        True  Traceback (most recent call last):\n  File "/U...
# 124        True  Traceback (most recent call last):\n  File "/U...
# 125        True  Traceback (most recent call last):\n  File "/U...
# 126        True  Traceback (most recent call last):\n  File "/U...
# 127        True  Traceback (most recent call last):\n  File "/U...
#
# [127 rows x 8 columns]

# %% [markdown]
# ## Getting the optimization result
# To get the ideal point (without evaluating the point) we ask the generator to
# generate a new point.

# %%
X.generator.generate(1)
# Out:
#        HexV  HexW      HexY      HexZ
# 0  0.546158   0.0  0.303932  0.564085

# %% [raw]
# X.evaluate_data(pd.DataFrame({"HexV":[.546158],"HexW":[0.0],"HexY":[0.3039],'HexZ':[0.564085]}))

# %% [markdown]
# ## Customizing optimization
# Each generator has a set of options that can be modified to effect optimization behavior

# %%
X.generator.options.dict()

# %%
# example: add a Gamma(1.0,10.0) prior to the noise hyperparameter to reduce model noise
# (good for optimizing noise-free simulations)
X.generator.options.model.kwargs.use_low_noise_prior = True
